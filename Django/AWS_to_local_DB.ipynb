# %%
import FinanceDataReader as fdr
import datetime
import pymysql
import warnings
# import MySQLdb
from sqlalchemy import create_engine
import sqlalchemy
warnings.filterwarnings(action='ignore')
import pandas as pd

# %% [markdown]
# # YouTube

# %%
youtube_table = ['youtube_hk_000660',
 'youtube_hk_005380',
 'youtube_hk_005930',
 'youtube_hk_051910',
  'youtube_hk_068270',               
 'youtube_sampro_000660',
 'youtube_sampro_005380',
 'youtube_sampro_005930',
 'youtube_sampro_051910',
  'youtube_sampro_068270',
 'youtube_suka_000660',
 'youtube_suka_005380',
 'youtube_suka_005930',
 'youtube_suka_051910',
 'youtube_suka_068270']


####
# AWS DB
mysqldb = pymysql.connect(user='root',password='1234',host='3.35.70.166', db='proj',charset='utf8')
curs = mysqldb.cursor()
for cd in youtube_table:
    ########### DB에서 칼럼만 뽑기 ###################
    query1 = 'show full columns from {}'.format(cd)
    curs.execute(query1)
    select = pd.DataFrame(curs.fetchall())
    ############ 칼럼 리스트 만들기 ##################
    col = list()
    for i in select[0]:
        col.append(i)
    mysqldb.commit()
    ############ DB에서 데이터 가져오기 ################
    curs = mysqldb.cursor()
    query2 = 'select * from {}'.format(cd)
    curs.execute(query2)

    globals()['{}'.format(cd)] = pd.DataFrame(curs.fetchall(), columns=col)
    globals()['{}'.format(cd)].drop_duplicates(['title','length'],inplace=True)
mysqldb.commit()
mysqldb.close()
pymysql.install_as_MySQLdb()


#### 로컬 스키마 설정 부분 
#engine = create_engine("mysql+mysqldb://root:"+"1234"+"@3.35.70.166/proj", encoding='utf-8')
engine = create_engine("mysql+mysqldb://root:"+"1234"+"@localhost/proj", encoding='utf-8')
conn = engine.connect()
for cd in youtube_table:
    
    globals()['{}'.format(cd)].to_sql(name=cd, con=engine, if_exists='append',index = False,dtype = {
        'st_n':sqlalchemy.types.VARCHAR(10),
        'st_cd':sqlalchemy.types.VARCHAR(10),
        'ch_nm':sqlalchemy.types.VARCHAR(30),
        'date':sqlalchemy.types.VARCHAR(10),
        'title' : sqlalchemy.types.TEXT(),
        'text' : sqlalchemy.types.TEXT(),
        'views':sqlalchemy.types.INT(),
        'length':sqlalchemy.types.INT(),
        'description':sqlalchemy.types.TEXT(),
        'url':sqlalchemy.types.TEXT()
        
    })

# %% [markdown]
# # news

# %%
news_table= ['asia_news_craw_000660',
'asia_news_craw_005380',
'asia_news_craw_005930', 
'asia_news_craw_051910',
 'asia_news_craw_068270'            ,
'maeil_news_craw_000660', 
'maeil_news_craw_005930',
'maeil_news_craw_005380', 
'maeil_news_craw_051910',
 'maeil_news_craw_068270' 
            ]
# AWS DB
#mysqldb = pymysql.connect(user='root',password='1234',host='localhost', db='you',charset='utf8')
mysqldb = pymysql.connect(user='root',password='1234',host='3.35.70.166', db='proj',charset='utf8')
curs = mysqldb.cursor()
for cd in news_table:
    ########### DB에서 칼럼만 뽑기 ###################
    query1 = 'show full columns from {}'.format(cd)
    curs.execute(query1)
    select = pd.DataFrame(curs.fetchall())
    ############ 칼럼 리스트 만들기 ##################
    col = list()
    for i in select[0]:
        col.append(i)
    mysqldb.commit()
    ############ DB에서 데이터 가져오기 ################
    curs = mysqldb.cursor()
    query2 = 'select * from {}'.format(cd)
    curs.execute(query2)

    globals()['{}'.format(cd)] = pd.DataFrame(curs.fetchall(), columns=col)
mysqldb.commit()
mysqldb.close()
for cd in news_table:
    pymysql.install_as_MySQLdb()
### 로컬 DB 
    #engine = create_engine("mysql+mysqldb://root:"+"1234"+"@3.35.70.166/proj", encoding='utf-8')
    engine = create_engine("mysql+mysqldb://root:"+"1234"+"@localhost/proj", encoding='utf-8')
    conn = engine.connect()
    
    globals()['{}'.format(cd)].to_sql(name=cd, con=engine, if_exists='append',index = False,dtype = {
    'st_n':sqlalchemy.types.VARCHAR(10),
    'st_cd':sqlalchemy.types.VARCHAR(10),
    'news': sqlalchemy.types.TEXT(),
    'date':sqlalchemy.types.VARCHAR(20),
    'title' : sqlalchemy.types.TEXT(), 
    'url' :sqlalchemy.types.TEXT(),
    'text' : sqlalchemy.types.TEXT()

    })
