# %% [markdown]
# <a href="https://colab.research.google.com/github/chaerui7967/stock_predict_news_and_youtube/blob/master/youtube_%EC%9E%90%EB%A7%89.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install youtube_transcript_api

# %%
from youtube_transcript_api import YouTubeTranscriptApi
YouTubeTranscriptApi.get_transcript(video_id="MH5M2Crn6Ag") # 영어자막만 가능

# %% [markdown]
# --------- youtube__ 자막가져오기--

# %%
! pip install pytube
# Out:
# ...
#      |████████████████████████████████| 56 kB 3.8 MB/s
# ...

# %%
from pytube import YouTube

# %%
video_url = 'https://www.youtube.com/watch?v=f84hATMEdWk'
yt = YouTube(video_url)

# %%
print("[영상 제목]", yt.title)  # 영상제목
print("[영상 게시자]", yt.author) # 영상 게시자
print("[조회수]", yt.views)
print("[평균평점]", yt.rating) # 평균 평점
print("[영상길이(초)]", yt.length)
print("[연령제한여부]", yt.age_restricted)
print("[영상 설명]", yt.description) # 영상 설명
print("[썸네일URL]", yt.thumbnail_url) # 썸네일 url 주소
# Out:
# [영상 제목] NC소프트 충격적인 주식 손실, 분노의 주주들
# [영상 게시자] 슈카월드
# [조회수] 442648
# [평균평점] 4.904557
# [영상길이(초)] 1897
# [연령제한여부] False
# [영상 설명] 0:00 ~ 1:27  선사과문
# 1:27 ~ 25:43  엔씨소프트 충격의 하락과 엄청난 손실
# 25:43 ~ 31:37 주주의 입장에서
#
# 어렵고 딱딱한 경제,시사,금융 이야기를
# 쉽고 유쾌하게 풀어내는
# 경제/시사/이슈/잡썰 토크방송입니다.
#
# #블소2 #리니지W
# [썸네일URL] https://i.ytimg.com/vi/f84hATMEdWk/sddefault.jpg

# %%
yt.captions.all()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated function all (This object can be treated as a dictionary).
#   """Entry point for launching an IPython kernel.
# [<Caption lang="Korean (auto-generated)" code="a.ko">]

# %%
caption = yt.captions.get_by_language_code('a.ko')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   """Entry point for launching an IPython kernel.

# %%
caption.xml_captions
# Out:
# '<?xml version="1.0" encoding="utf-8" ?><timedtext format="3">\n<head>\n<ws id="0"/>\n<ws id="1" mh="2" ju="0" sd="3"/>\n<wp id="0"/>\n<wp id="1" ap="6" ah="20" av="100" rc="2" cc="40"/>\n</head>\n<body>\n<w t="0" id="1" wp="1" ws="1"/>\n<p t="0" d="2000" w="1"><s ac="232">아</s></p>\n<p t="4269" w="1" a="1">\n</p>\n<p t="4279" d="4940" w="1"><s ac="220">wr</s></p>\n<p t="6870" d="2349" w="1" a="1">\n</p>\n<p t="6880" d="4740" w="1"><s ac="252">그</s><s t="120" ac="237"> 오해가</s><s t="990" ac="255"> 전</s><s t="1320" ac="126"> 맨날</s><s t="1589" ac="201"> 이제</s><s t="1770" ac="227"> 방송하면</s></p>\n<p t="9209" d="2411" w="1" a="1">\n</p>\n<p t="9219" d="4771" w="1"><s ac="248">일단</s><s t="391" ac="239"> 타과</s><s t="781" ac="250"> 를</s><s t="1021" ac="208"> 해야</s><s t="1141" ac="208"> 되는데</s><s t="1531" ac="152"> 노홍철이</s></p>\n<p t="11610" d="2380" w="1" a="1">\n</p>\n<p t="11620" d="4439" w="1"><s ac="200">그</s><s t="179" ac="255"> 보셨죠</s><s t="750" ac="210"> 너는</s><s t="1320" ac="166"> 어도<
# ...

# %%
ord('가')
# Out:
# 44032

# %%
import re

# %%
def cleanhtml(raw_html):
  cleanr = re.compile('<.*?>|&([a-z0-9]+|#[0-9]{1,6}|#x[0-9a-f]{1,6});')
  cleantext = re.sub(cleanr, '', raw_html)
  return cleantext

# %%
aa =str(caption.xml_captions)

# %%
text=str(cleanhtml(aa)).replace('\n','')
