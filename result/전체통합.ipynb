# %% [markdown]
# <a href="https://colab.research.google.com/github/chaerui7967/stock_predict_news_and_youtube/blob/master/%EC%A0%84%EC%B2%B4%ED%86%B5%ED%95%A9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
path = '/content/drive/My Drive/Final PJT - 업빛투/최종 결과 테이블/'

# %%
# 기본 테이블
samsung = pd.read_csv(path + '삼성전자/total_table.csv')
lg = pd.read_csv(path + 'lg화학/total_table.csv')
sk = pd.read_csv(path + 'sk하이닉스/total_table.csv')
hun = pd.read_csv(path + '현대차/total_table.csv')
cell = pd.read_csv(path + '셀트리온/total_table.csv')

total = pd.concat([samsung,lg,sk,hun,cell])
total
# Out:
#     code        date           lstm  ...  suka_youtube   close    change
# 0   5930  2021-09-15   75635.242676  ...      0.508731   77000       NaN
# 1   5930  2021-09-16   75637.329590  ...      0.508731   76100       NaN
# 2   5930  2021-09-17   76096.152832  ...      0.508731   77200       NaN
# 3   5930  2021-09-23   76369.526611  ...      0.508731   77400       NaN
# 4   5930  2021-09-24   76418.150635  ...      0.508731   77300       NaN
# 5   5930  2021-09-27   76359.406738  ...      0.508731   77700       NaN
# 6   5930  2021-09-28   76422.000000  ...      0.508731   76300       NaN
# 7   5930  2021-09-29   76854.091064  ...      0.508731   74100       NaN
# 8   5930  2021-09-30   76312.112305  ...      0.508731   74100       NaN
# 9   5930  2021-10-01   75350.940186  ...      0.508731   73200       NaN
# 0  51910  2021-09-15  733916.571140  ...      0.508730  718000 -0.021798
# 1  51910  2021-09-16  730745.079160  ...      0.508730  716000 -0.002786
# ...

# %%
# ud 테이블
samsung_ud = pd.read_csv(path + '삼성전자/samsung_table_ud.csv')
lg_ud = pd.read_csv(path + 'lg화학/lg_table_ud.csv')
sk_ud = pd.read_csv(path + 'sk하이닉스/hy_table_ud.csv')
hun_ud = pd.read_csv(path + '현대차/hun_table_ud.csv')
cell_ud = pd.read_csv(path + '셀트리온/cel_table_ud.csv')

total_ud = pd.concat([samsung_ud,lg_ud,sk_ud,hun_ud,cell_ud])
total_ud
# Out:
#     code        date       lstm  ...  hk_youtube  suka_youtube  change
# 0   5930  2021-09-15   75550.37  ...           1             1       1
# 1   5930  2021-09-16       1.00  ...           1             1      -1
# 2   5930  2021-09-17       1.00  ...           1             1       1
# 3   5930  2021-09-23       1.00  ...           1             1       0
# 4   5930  2021-09-24       1.00  ...          -1             1       0
# 5   5930  2021-09-27      -1.00  ...          -1             1       1
# 6   5930  2021-09-28       1.00  ...          -1             1      -1
# 7   5930  2021-09-29       1.00  ...          -1             1      -1
# 8   5930  2021-09-30      -1.00  ...           1             1       0
# 9   5930  2021-10-01      -1.00  ...           1             1      -1
# 0  51910  2021-09-15  733916.57  ...           0             1      -1
# 1  51910  2021-09-16      -1.00  ...           1             1       0
# ...

# %%
total.to_csv('./total.csv', index=False)
total_ud.to_csv('./total_ud.csv', index=False)
