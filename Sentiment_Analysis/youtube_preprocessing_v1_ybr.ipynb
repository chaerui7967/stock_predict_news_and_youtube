# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# DB 연결
import pymysql

# 실시간 주식가격 데이터
import FinanceDataReader as fdr

# 텍스트 분석
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

from konlpy.tag import Okt
from gensim import models

# from wordcloud import WordCloud

# 모델 학습 및 평가
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, roc_auc_score, precision_score, recall_score

# 기타
import datetime
from collections import Counter
import sys
import warnings
warnings.filterwarnings('ignore')

# %%
df_all_lgc = pd.read_csv('./data/전처리 전 데이터/df_youtube_삼프로LG화학.csv')

# %%
df_all_lgc.head()
# Out:
#    st_n  st_cd          ch_nm        date  \
# 0  LG화학  51910  삼프로TV_경제의신과함께  2021053100
# 1  LG화학  51910  삼프로TV_경제의신과함께  2020091700
# 2  LG화학  51910  삼프로TV_경제의신과함께  2020091700
# 3  LG화학  51910  삼프로TV_경제의신과함께  2020101200
# 4  LG화학  51910  삼프로TV_경제의신과함께  2021011100
#
#                                                title  \
# 0  매도 리포트에 흔들리는 LG화학.. 현실적 판단 VS 가치 훼손?_오늘아침 page...
# 1           LG화학 물적분할.. 그룹가치 상승이냐 주주가치 하락이냐 f.염승환 차장
# 2          LG화학의 물적분할.. 주가 하락을 걱정하는 이유는? f.김현수 선임연구원
# 3  '배터리 셀 분리막 결함' 발표.. 현대차 VS LG화학 전쟁 발발하나? f.권순우 기자
# 4  LG화학의 '2차 전지 IPO'.. 생각보다 이른 시기에 상장할 수도 있다? f.이...
#
#                                                 text   views  length  \
# 0  으[음악]tera term[음악]으 으 으 으 으[음악]이름은 하나인데 직업은 서먹...  302650    7335
# 1  구독과 좋아요는 사람입니다자 염치 염치 영차 차 우리 염성 안 차장에 보시겠습니다 ...   97309    2117
# 2  좋아요 구독 눌러주세요자 그럼 오늘 첫 번째 뉴스 부터 시작을 해 봐야죠먼저 뭐 미...   52967    1321
# 3  자 그러면 오늘 노려 일이니까요 발칙하게 한번 가보겠습니다뭐 리토의 방송에 건수를 ...   31501    1988
# 4  산업을 이해하고 기업을 이해해야 돈의 흐름이 보입니다리서치 명과 메리츠 증권과 3%...  369589    2155
#
#                                          description  \
# 0  삼프로TV 주식대학 '봄학기'\n? 염블리의 친절한 주식 기초 교육 / 미주미 장우...
# 1  ■page2 강의 신청하기\n- 사경인의 실전투자 아카데미 '리마스터'\nhttps...
# 2  ■page2 강의 신청하기\n- 사경인의 실전투자 아카데미 '리마스터'\nhttps...
# 3  ■ [삼프로TV 시청자 자문단 1기 응모 양식] 링크\nhttps://forms.g...
# 4  ■삼프로TV가 준비한 다양한 프리미엄 콘텐츠\n\n- 삼프로 TV 주식대학 "업종 ...
#
#                                            url
# 0  https://www.youtube.com/watch?v=rz_knoIe-fQ
# 1  https://www.youtube.com/watch?v=BrR0O6KQ5P0
# 2  https://www.youtube.com/watch?v=bXAbIIeVD0U
# 3  https://www.youtube.com/watch?v=3cHrONGe5gs
# 4  https://www.youtube.com/watch?v=0HFXP_rtYPw

# %%
df_all_lgc[df_all_lgc['date'] == 2020091700]
# Out:
#      st_n  st_cd          ch_nm        date  \
# 1    LG화학  51910  삼프로TV_경제의신과함께  2020091700
# 2    LG화학  51910  삼프로TV_경제의신과함께  2020091700
# 26   LG화학  51910  삼프로TV_경제의신과함께  2020091700
# 54   LG화학  51910  삼프로TV_경제의신과함께  2020091700
# 58   LG화학  51910  삼프로TV_경제의신과함께  2020091700
# 133  LG화학  51910  삼프로TV_경제의신과함께  2020091700
# 149  LG화학  51910  삼프로TV_경제의신과함께  2020091700
#
#                                                  title  \
# 1             LG화학 물적분할.. 그룹가치 상승이냐 주주가치 하락이냐 f.염승환 차장
# 2            LG화학의 물적분할.. 주가 하락을 걱정하는 이유는? f.김현수 선임연구원
# 26   연준, AIT 도입 결정 후 첫 FOMC 회의.. 내용은 무난했다?_오늘아침 pag...
# 54           시장에 대한 연준의 솔직한 고백.. "우리는 잠들지 않아" f.이효석 팀장
# 58         이효석 팀장에게 듣는 9월 FOMC 미리보기_퇴근길 page2_이효석, 김현겸
# 133  골드만삭스가 말하는 10%이상 성장할 10가지 종목_글로벌 라이브_박광남, 김철중,...
# 149                         과거 디스플레이 사례로 보는 배터리 산업의 미래
#
#                                                   text   views  length  \
# 1    구독과 좋아요는 사람입니다자 염치 염치 영차 차 우리 염성 안 차장에 보시겠습니다 ...   97309    2117
# 2    좋아요 구독 눌러주세요자 그럼 오늘 첫 번째 뉴스 부터 시작을 해 봐야죠먼저 뭐 미...   52967    1321
# 26   놈 5으 으[음악]김과장 경기가 불어날 때 어떻게 투자해이럴땐 든 들은 안전 자산의...  154462    6554
# 54   좋아요 구독 눌러주세요하도 채팅 장 의 lg 화학이에 대한 에 뭐라고 할까요 송 토...   29601    2636
# 58   으222[음악]으 으 으 으 으 으[음악]김과장 경기가 불안할 때 어떻게 투자해이럴...  103802    4172
# 133  [음악][박수][음악]내 안녕하십니까 아 투자 공부를 빙자한 온라인 해외 치가 입니...   97621    5805
# 149  아 김철중 한국이란 모시고 배터리 이야기좀 들어보겠습니다어서 오십시오 안녕하세요 4...   30063    2107
#
#                                            description  \
# 1    ■page2 강의 신청하기\n- 사경인의 실전투자 아카데미 '리마스터'\nhttps...
# 2    ■page2 강의 신청하기\n- 사경인의 실전투자 아카데미 '리마스터'\nhttps...
# 26   00:00 오프닝\n\n06:06 뉴스3 (긴급 인터뷰 - 김현수 선임연구원)\nL...
# 54   ■page2 강의 신청하기\n- 사경인의 실전투자 아카데미 '리마스터'\nhttps...
# 58   00:00 오프닝\n\n03:59  증시 셔터맨 (김현겸 과장)\n상승에 대한 피로...
# 133  00:00 오프닝\n\n04:18 글로벌 마켓 브리핑 - 미래에셋대우 박광남 선임연...
# 149  ■page2 강의 신청하기\n- 사경인의 실전투자 아카데미 '리마스터'\nhttps...
#
#                                              url
# 1    https://www.youtube.com/watch?v=BrR0O6KQ5P0
# 2    https://www.youtube.com/watch?v=bXAbIIeVD0U
# 26   https://www.youtube.com/watch?v=8G1254oRO3g
# 54   https://www.youtube.com/watch?v=iVYZ9fe23IY
# 58   https://www.youtube.com/watch?v=vzGoEhru_5M
# 133  https://www.youtube.com/watch?v=Zmn0D5MqggM
# 149  https://www.youtube.com/watch?v=sOW1CiuDsEg

# %%
df_all_lgc[df_all_lgc['date'] == 2020091700].shape
# Out:
# (7, 10)

# %%
# description, url 제외
df_lgc = df_all_lgc.iloc[:, :8]

# %%
df_lgc.head()
# Out:
#    st_n  st_cd          ch_nm        date  \
# 0  LG화학  51910  삼프로TV_경제의신과함께  2021053100
# 1  LG화학  51910  삼프로TV_경제의신과함께  2020091700
# 2  LG화학  51910  삼프로TV_경제의신과함께  2020091700
# 3  LG화학  51910  삼프로TV_경제의신과함께  2020101200
# 4  LG화학  51910  삼프로TV_경제의신과함께  2021011100
#
#                                                title  \
# 0  매도 리포트에 흔들리는 LG화학.. 현실적 판단 VS 가치 훼손?_오늘아침 page...
# 1           LG화학 물적분할.. 그룹가치 상승이냐 주주가치 하락이냐 f.염승환 차장
# 2          LG화학의 물적분할.. 주가 하락을 걱정하는 이유는? f.김현수 선임연구원
# 3  '배터리 셀 분리막 결함' 발표.. 현대차 VS LG화학 전쟁 발발하나? f.권순우 기자
# 4  LG화학의 '2차 전지 IPO'.. 생각보다 이른 시기에 상장할 수도 있다? f.이...
#
#                                                 text   views  length
# 0  으[음악]tera term[음악]으 으 으 으 으[음악]이름은 하나인데 직업은 서먹...  302650    7335
# 1  구독과 좋아요는 사람입니다자 염치 염치 영차 차 우리 염성 안 차장에 보시겠습니다 ...   97309    2117
# 2  좋아요 구독 눌러주세요자 그럼 오늘 첫 번째 뉴스 부터 시작을 해 봐야죠먼저 뭐 미...   52967    1321
# 3  자 그러면 오늘 노려 일이니까요 발칙하게 한번 가보겠습니다뭐 리토의 방송에 건수를 ...   31501    1988
# 4  산업을 이해하고 기업을 이해해야 돈의 흐름이 보입니다리서치 명과 메리츠 증권과 3%...  369589    2155

# %%
# 출처 '자체제작 감성어휘사전 모듈_ver2.ipynb'

def set_data(df,com_num = 0):  # panda, numpy, datetime, FinanceDataReader, konlpy, Counter
    # 일, 시간 나누기
    df['date'] = df['date'].astype(str)
    df['date_d'] = df['date'].str[:-2]
    df['date_h'] = df['date'].str[-2:]
    # 타입을 데이트 타입으로 만듬
    df['date_d'] = pd.to_datetime(df['date_d'])
    
    df = df.sort_values(by='date_d') # 일기준으로 오름차순 정렬
    
    if com_num != 0:
    #     통합 데이터 활용시 업종코드 지정
        df = df[df['st_cd'] == com_num] # 해당 회사만 추출
        num = str(com_num).zfill(6) # 종목코드를 6자리로 만들어줌
        
    else:
        # 특정 업종만 할 때
        num = str(df['st_cd'].iloc[0]).zfill(6)
    
    # 널값 제거
    df = df.dropna()
    
    # ============== 날짜 조정
    ## 전일 15시 ~ 금일 15시로 날짜 조정
    after_market = ['15', '16', '17', '18', '19', '20', '21', '22', '23']
    
    for i in range(len(df)):
        if df['date_h'].iloc[i] in after_market:
            df['date_d'].iloc[i] += datetime.timedelta(1)
    
    # 주말 및 공휴일 데이터
    ### Holidays
    try:
        # 서버가 열려있을 때
        db = pymysql.connect(user='root',
                             passwd='1234',
                             host='3.35.70.166',
                             db='proj',
                             charset='utf8')

        cursor = db.cursor(pymysql.cursors.DictCursor)

        sql = "select * from holidays"
        cursor.execute(sql)
        result = cursor.fetchall()
    
        # DataFrame으로 변경
        holi = pd.DataFrame(result)
        # db 닫기 --> 안하면 메모리 잡아먹음
        db.close()
    except:
        # 서버 없을 때 깃허브에서 바로 가져옴
        db_holi = 'https://raw.githubusercontent.com/chaerui7967/stock_predict_news_and_youtube/master/감성분석/data/holidays.csv'
        holi = pd.read_csv(db_holi)
    
    # date 컬럼을 날짜 형식으로 변경
    holi['date'] = pd.to_datetime(holi['date'])
    
    
    ### ===================주말 및 공휴일 제외
    
    ## 주말 및 공휴일만 추출
    market_closed = holi[holi['holiday']=="O"].reset_index(drop=True)
    
    ## 휴장일 List 생성
    market_closed_list = list(market_closed['date'])
    
    # 주말 및 공휴일 제외
    while len(df[df['date_d'].isin(market_closed_list)]['date_d']) !=0:
        for i in df[df['date_d'].isin(market_closed_list)]['date_d'].index:
            df['date_d'][i] += datetime.timedelta(1)
     
    
    
    # 주식 데이터 가져오기
    start_date = str(df['date_d'].iloc[0])[:10].replace('-', '')
    end_date = str(df['date_d'].iloc[-1])[:10].replace('-', '')  # 뉴스 데이터 기준 최근 값까지의 주식 데이터
    
    stock = fdr.DataReader(num, start = start_date, end = end_date)
    
    # change 컬럼 판단 기준 close에서 수수료 보다 많은 비율이 올랐으면 1, 떨어졌으면 -1, 그 사이 0
    point = stock['Close'] * stock['Change']
    spli = stock['Close'] * 0.001  # 수수료가 0.1 % 라고 할 때
    
    stock['ud'] = np.where( point > spli, 1,
                          np.where(point < spli, -1, 0))
    
    stock = stock.reset_index() # 날짜 컬럼 가져오기
    
    s_1 = stock[['Date','ud']] # 필요한 컬럼만 가져오기
    
    s_1.columns = ['date_d','ud'] # 컬럼 명 초기화
    
    # 뉴스데이터와 주식데이터 merge
    df_1 = pd.merge(df,s_1,on='date_d')  # 영향받는 컬럼 기준으로 inner 조인 
    
    return df_1

# %%
dataSet = set_data(df_lgc)
dataSet.head()
# Out:
#    st_n  st_cd          ch_nm        date  \
# 0  LG화학  51910  삼프로TV_경제의신과함께  2019090100
# 1  LG화학  51910  삼프로TV_경제의신과함께  2019090300
# 2  LG화학  51910  삼프로TV_경제의신과함께  2019110300
# 3  LG화학  51910  삼프로TV_경제의신과함께  2019110800
# 4  LG화학  51910  삼프로TV_경제의신과함께  2020011800
#
#                                                title  \
# 0          주식 투자자가 버려야 할 7가지!  [최준철 대표의 주식 FM가이드 #3]
# 1      누가 마지막까지 투자하는가!_19.09.03_김효진,곽상준 [오늘아침 Page2]
# 2  주식 포트폴리오 운용 방법! 경마 분석법(?) [최준철 대표의 주식 FM가이드 05-1]
# 3  삼성의 스마트폰 전략, 변화의 이유는? _19.11.07_박종일,박제영 [퇴근길 P...
# 4                       [심층인터뷰] 반복되는 4분기 '어닝쇼크' 이유는?
#
#                                                 text  views  length  \
# 0  [음악]최진철 테스의 주식 fm 가이드세번째 시간이 시작됐습니다 반갑습니다 점프로 ...  38118    4364
# 1  4[음악]깊이가 나는 경제 컨텐츠 오늘 아침 페이지 투 정용진 김도완 입니다[음악]...  13446    4244
# 2  5 으주식 시장의 야전사령관 최준철 대표 함께하는 주식 sm 카이드 다섯번째시간이 ...  26233    3240
# 3  깨알 페이지 투4 안녕하십니까 11월 7일 퇴근 낄 페이지 툰 관세 장벽을 일부 허...  11245    4587
# 4  [음악]오늘 어또 손님 한번 보셔서 공부해야 줘 요 한테 증권의 김광현 선임 년 무...   6132    1307
#
#       date_d date_h  ud
# 0 2019-09-02     00  -1
# 1 2019-09-03     00   1
# 2 2019-11-04     00   1
# 3 2019-11-08     00   1
# 4 2020-01-20     00   1

# %%
dataSet.title[0]
# Out:
# '주식 투자자가 버려야 할 7가지!  [최준철 대표의 주식 FM가이드 #3]'

# %%
len(dataSet.text[0])
# Out:
# 32302

# %%
dataSet.text[0]
# Out:
# '[음악]최진철 테스의 주식 fm 가이드세번째 시간이 시작됐습니다 반갑습니다 점프로 구요 4 2% 입니다불탄 fm 과 이때도 뭔지 아는 거예요아 마켓의 있어 잘라서 야짤 이것 역시 를 거는 2분야 뭐 하하 빠른거아냐 그거아 그렇게 좀 출연자들에게 가만 있지 못하니까아 빌라도 지원 얘기가 계속 나오네요 우정을 하루 4시간으로는 세번째 씨가 에 방문으로 이제 두 번째가 그 정 그런거는 정프로가 알아서 합니다 어제 그제 위 제로 생각했네그거 해 가지 안 하면 아 여튼 밝았습니다 우리 처지 설 대표님예 스탐 장장 하셔서 예뻐 같습니다 4 우리조 주식fm 가이드 이란 게 이제 쉴드 매뉴얼 뭐그날 조범 이렇게 챙겨 범 될지도 모르겠소 서울 fm 에fm 이라는 가족용 아 왜 음 저는 그xls 아니겠습니까 그러다 보니까 야전 믿은 게 없어요그래 예 군 테 전 이제 공부 내는딜도 매뉴얼 이런 게 없었어요 사실 에 했는데 전 프로가 모르 거지당신은 저 할 줄 안다고 15 줄이 저촉 뭐 요분들도 총무가 있나 4 있는거예요아 지금 고은비 하시게 달 초 어떻게 7 금 특기가 있어요 은 총무는무슨 이래요공군 총무 유천은 식당에도 좀 있었구요그 다음에 줘 식당에서 부분이 되요 boq 관사 관리도 식당에서 밥 앞에쭉 류큐 관리 병 이로써 이렇게도 관리하고 야 아 내 표기 있었잖아적이며 안되니까 장교 숙소 비어캔 204 하겠어 아주 이야기가 잠겨서결과 아니에요 그 이 빚자 그 독신자 단테 줘 아 아 아 그래요에바 텔러 에어 q 로 뭐야 도대체 그 q 는 뭘까야 우리 세 글자 주기 아마 예 아 오늘 노브 겠지4 여사해 떠오르게 딱히 뭐 하고 이제 우체국에서 들음 있었고 그 만큼그 생각하면서 이렇게 여러분들이 있었다구요그래서 되게 여러분들 이발 됐어 심지어 이 발병 에 등 단기적 못했구나1 제가 고용 안되겠네가요 내 사랑 합니다 아 알투비 르 베제라 운영 등 병장 정말 재고인드라 굿은 많이 하셨네너를 데려가 열매 작업이 싸게 입이 부서져 고서 에서 그 굉장히 그치 아된경 계획 아직 으그래서 이제 그 쉴드 매뉴얼은 야 전교 겁니다 그걸 오늘 처음 알았습니다어 에 자드 야 전교 봄을 우리가 하게 된 이유는아 요즘 사실 주식 시장이 굉장히 좀 어렵고 어 투자를 해야 되나 말아야되나 이 고민을 좀 그러니까 어떻게 해야 되는 둘째치고 해야되나 말아야도의 고민들도 많이 하고 있거든요이럴 때 아 적어도 이런 어려운 시기를 여러 차례 겪어본 4 실전으로겪어본 이런 분들을 모시고 이럴땐 어떻게 하는게 좋을까 좀 답을 내려달라 이런 컨셉의 상승 하시고 498 교문 제안한 마음가짐으로 해야그렇죠예그래서 그 주식투자를 대하는 우리의 자세음 자 그렇게 우리 쉔이 설 대표님을 모시고 좀 오늘도 이야기를나눠보도록 하겠습니다오늘은 4 5월 방송 1조 쉽진 않을 거에요 지난번 하고 달 으 이라고우리 둘이 진짜 예 아 대단히 순조로워 쓸텐데 캠프로 정토 둘이 하는방송은 정말 물 흐르듯이 어쩜 그렇게 마음가짐을 단단히 먹어야 될 겁니다그렇군요예 모든 일에 딴지를 거는 무리겠죠아기를 갖 성기 1종 가축 현재 신이 필요하실 거에요5 겸재 따뜻해 같아 않고 모든 여기에부동산 난지 이야기 에 들어갈 꿈 세상 모든 일 잘 이해가 안가그리고 87% 가 불만이야 해봤자 오늘 어떤 얘기 하니까지난번에는 제가 의 태풍 의 빗대서 결국은 태풍은 좀 지나 갈 거다언젠지 모르지만 결국에 매치다 갈 거다 라는 좀 희망적이고 낙천적인 그런얘기를 했다고 하며 는 이번에는 좀 입에는 쓰지만 몸에는 좋은 그런 또필드 매뉴얼에 대해서 얘기를 좀 드리고 자아 입에는 쓰지만 몸에는 약이되는 아주 본 얘기네요 예 i 그름은 어떤혹시 점프로 님은 치뤄 지 약 이라는 말이 들어 줘야 겠네요어쩔 거지 약도 알고 플러스 3불 것까지 알고 있어 그건 뭔가요아 끝일 거지야 그 아내가 나에게 뭔가를 잘못했을 때이제 쫓아낼 수 있는 에서 왕들이 잖아요 악하고 이제 3불 거는그럼에도 불구하고 이 아내를 쫓아낼 수 없는 세 가지가 또 있어요뭔가 전세 3 작 할 수 있는 요청에 그 아니하면 일 어 2아내가 나의 어려운 시절 부터 같이 했던 다 내다 조그만 수로 나실 때너의 녹은 내가 의 검호 2 아버지니까 뭐 시아버지 시부모의 그 상3년을 같이 했다이름 교회 전체가 지 경우도 있어요 그래 뭐 3불 모든 거기서 더 그7가지 사항이 그러면은 에 문제는 그 뭐 아들 못 낳고 예 뭐 전부 단자모르는데 질투하는 것이다 질투하는 거예요 왜 투기의 제가 제일 큰거 g마트 지만 전에 2그리고 바다와 서있다는 뭐 막은 투기 이런거 말고그래서 아니라 세우면 안 된다고 못해서 아 그래요 많음 한다 그리고 뭐전염병 같은게 있으면 은 아 글러브 더 많이 해서도 안 된다 이런 연핑크가 있으며 안되지4 92분 좀 노동자 야한 거 아닙니까 그거는 내가 위치도 안걸리는 만들수 있는게 아닌데 좀 털어 논 특별히 와주시면 4 아아아 r사실 이게 뭐 훔치는 것도 있고 말을 하지 못하는거 이런건 사실 지금으로봐서는 좀 그 사대부들의 좀 꼰대 적인 그렇죠예 마인드에서 좀 나온건데 제가 이 7 거지야 에서 힌트를 얻어 가지고요그 최종 철의 주식 투자자들을 위한 7 거지 약을 한번 제 나름대로만들어 온 어 그렇습니까 가데나 재밌겠다 하려면 아예뭐 내용이 똑같지는 않고 요일 6 일단 7가지로 거 아니에요 잠깐만 이리들어가나 언젠가 전소 철을주식투자를 위한 7 거지 약이 독창적인 겁니까 아니면 어디서 그런 얘기를들어서 그 처절 만 바꾼 겁니까 아 새가 그칠 거 자 말곤 있었는데 이게샤워 하다가 문득 떠올라 가죠 음 선교 이런 샤워 하다 말고 나와서 얼른이제 메모를 하고 거기에 제 7가지를 추가로 생각해서 한번 처음으로 제가만들어봤습니다원래 난 5가지 얻는데 2개는 먹지도 느낌 있을까요 스런 아 이건 뭐 한번트로 오실때 달 핵 에르 때가 올 아아 마음에 드시지 않을 것 같은데러보고 어찌 도는게 뭔 점차 자 봅시다 얘기죠아 영혼의 좋고 무리가 17 여기서 7 거요 는 이제 그 쫓아내는 7가지이유 인데 어느 이제 주식 투자를 하면 주 시장에서 이제 쫓겨날 수밖에없는 그런 악들과 알아야 애가 4반대로 얘기하면 오늘은 주식시장에서 쫓겨나는 나지 않을 수 있는이제 정신 상태를 만드는 그런 정식 군대로 치면 정웅 교육과 같은 그렇지아니라 5 비율로 아직 5종 규정 헌병은 안 했어요 점프로 정운 병도잠깐 했었어요 아이 완화시키고 그러면 우리 전연령 이었구나 내가 볼 때당신은 전투기 모르고 말씀하여 타고 1 에 뭘 시켜도 적응을 못한 일을우리가따라서 음 전체를 돌리실 수 있구요 완성하실 시작해진짜 우리 공부 내는 그 노마드 다중 tmi 기는데 노마드 듣기 라고있어요노마드 그 특기가 이제 각기 자의 뭐 육군 포병 2011 꾼 적이있잖아요노마드 듣기가 있어요 예 요건도 있는지 모르겠네 그래서 그 친구는한 1년 반 동안 모든 특기 교육을 다 받아요음을 다 받아서 운전도 하고 뭐 또 와 같은 그래서 모든 걸 다 할 수있는도마도 특기 가진 헌금 만의 독특한 장점이 있죠자 그래서 팩 하지만 해야될 거1 국가 중에 첫 번째 문양 만들어 갈까요 제가 이제 7가지를 만들었다고했는데 그 원래 칠거지악 중에서 제가 만든 거랑 유일하게 딱 하나 겹치는항목이 있습니다이게 이제 질투를 버리는 겁니다 투기 때 투기 옛날 말로 이제 투기를하는 거죠표 14 에서 질투 면 나오다 2 수인을 높은 사람들 질투하는 거 수익률높은 사람 혹은 뭐 주식으로 돈을 벌었다는 얘기특히나 종 가까운 사람 그리고 가까운 사람 중에서도 나보다 조 못하다고생각하는 사람 2회 주식으로 돈을 벌어 때 더라그러던 어제 그리고 오늘 뉴스에 뭐 급등주 가 나왔는데 그 급등주를 갖고있는 사람에 대한 질투 뭐 이런것들을 다 포괄하는 질투를 가지는게 굉장히안 좋은 결과로 이어지는 데 이어 어쩔 수가 없는게 한국인의 dna입니다 오죽하면 은 이제사촌이 땅을 사면 배가 아프다 라는 수많은 격언 들 중에서도 상당히 이제만 많이 이용되고 많이들 또 공감 하는 그런 속담이 있을 정도로 그래서한국인들이 굉장히 이게 좀 심한 편이거든요이게 이제 주식투자를 하면서 더 나타나는게 이게 이제 문제 씨앗이 됩니다아 그렇습니까 래 쌈 잘되는거 가 특히 더 배 아파 는 그런 유전자를갖고 있는 거야 ...

# %%
dataSet.shape
# Out:
# (507, 11)

# %%
sample = dataSet.head()
sample
# Out:
#    st_n  st_cd          ch_nm        date  \
# 0  LG화학  51910  삼프로TV_경제의신과함께  2019090100
# 1  LG화학  51910  삼프로TV_경제의신과함께  2019090300
# 2  LG화학  51910  삼프로TV_경제의신과함께  2019110300
# 3  LG화학  51910  삼프로TV_경제의신과함께  2019110800
# 4  LG화학  51910  삼프로TV_경제의신과함께  2020011800
#
#                                                title  \
# 0          주식 투자자가 버려야 할 7가지!  [최준철 대표의 주식 FM가이드 #3]
# 1      누가 마지막까지 투자하는가!_19.09.03_김효진,곽상준 [오늘아침 Page2]
# 2  주식 포트폴리오 운용 방법! 경마 분석법(?) [최준철 대표의 주식 FM가이드 05-1]
# 3  삼성의 스마트폰 전략, 변화의 이유는? _19.11.07_박종일,박제영 [퇴근길 P...
# 4                       [심층인터뷰] 반복되는 4분기 '어닝쇼크' 이유는?
#
#                                                 text  views  length  \
# 0  [음악]최진철 테스의 주식 fm 가이드세번째 시간이 시작됐습니다 반갑습니다 점프로 ...  38118    4364
# 1  4[음악]깊이가 나는 경제 컨텐츠 오늘 아침 페이지 투 정용진 김도완 입니다[음악]...  13446    4244
# 2  5 으주식 시장의 야전사령관 최준철 대표 함께하는 주식 sm 카이드 다섯번째시간이 ...  26233    3240
# 3  깨알 페이지 투4 안녕하십니까 11월 7일 퇴근 낄 페이지 툰 관세 장벽을 일부 허...  11245    4587
# 4  [음악]오늘 어또 손님 한번 보셔서 공부해야 줘 요 한테 증권의 김광현 선임 년 무...   6132    1307
#
#       date_d date_h  ud
# 0 2019-09-02     00  -1
# 1 2019-09-03     00   1
# 2 2019-11-04     00   1
# 3 2019-11-08     00   1
# 4 2020-01-20     00   1

# %% [markdown]
# ## Stop Words List

# %%
# Update 계속 하는 중!
media = ['오늘', '년도', '이제', '요즘', '지금', '우리나라', '한번', '사실',  \
         '증시', '개장', '얘기', '이렇다', '참고', '없다', '때문', \
         '아니다', '어서', '오십', '시오', '모습', '내용', '정도', '그렇다', '어쨌든', '어떻다', \
         '박지영', '미래에셋', '어머님', '음악']

# %%
# 출처 '자체제작 감성어휘사전 모듈_ver2.ipynb' > def giro_dic
##표시 수정 부분

def youtube_pre(df,num = 0):
    
## media 전역 변수 선언
#     global media
    
    df = set_data(df, num)
    print('데이터 셋 구성 완료')
    
    okt = Okt()
    print('okt 모듈 활성')
    
    
    # 데이터 전처리
    # =================== nlp
    # 1. 제목, 텍스트 --> 명사, 형용사 추출
    # 태그 삭제        
    # \n \t 삭제
    df['text'] = df['text'].str.replace('[\n|\t|\r]','')
#     df['text'] = df['text'].str.replace('\s','')
    df['text'] = df['text'].str.replace('[^a-zA-Z0-9가-힣]','')
    
    # 토큰화 및 품사 태깅
    df['Contents_input'] = df['text'].apply(lambda x: okt.pos(x, norm=True, stem=True))
    print('태그 삭제 및 품사 태깅 완료')
    
    # 명사, 형용사 추출
    for k in range(len(df['Contents_input'])):
        wordList = []
        for j in range(len(df['Contents_input'][k])):
            if df['Contents_input'][k][j][1] == 'Noun' or df['Contents_input'][k][j][1] == 'Adjective':
                wordList.append(df['Contents_input'][k][j][0])         
        df['Contents_input'][k] = wordList
    print('명사, 형용사 추출')
    
    # 2. 불용어 처리
    # 불용어 사전 로딩
##     url = 'https://raw.githubusercontent.com/chaerui7967/stock_predict_news_and_youtube/master/%EA%B0%90%EC%84%B1%EB%B6%84%EC%84%9D/data/stopwords_ver1.txt'
    url = 'https://raw.githubusercontent.com/yoonkt200/FastCampusDataset/master/korean_stopwords.txt'
    stopwords = list(pd.read_csv(url, header=None)[0])
##     media = ['매일경제','mkcokr','무단전재및재배포금지','무단전재','재배포금지']
#     media = ['오늘', '년도', '이제', '요즘', '지금', '우리나라', '한번', '사실', '처럼', \
#              '증시', '개장', '얘기', '이렇다', '참고', '없다', '때문', '아니다', \
#              '안녕하십니까', '안녕하세요우', '안녕하다', '어서', '오십', '시오', '모습', '내용', '정도', \
#              '그렇다', '어쨌든', '어떻다', '박지영', '미래에셋', '어머님', '음악']
    print('불용어 사전 로딩..')
    
    
    for i in range(len(df['Contents_input'])):
        for word in df['Contents_input'][i]:
            if word in stopwords:
                df['Contents_input'][i].remove(word)
            if word in media:
                df['Contents_input'][i].remove(word) 
    print('불용어 처리 완료')
    
    # 단어길이가 1이하인 단어 제거
    for index, wordList in enumerate(df['Contents_input']):
#         if len(df['Contents_input'][index]) == 0:
#             continue
        try:
            for word in wordList:
                if len(word) <= 1:
                    df['Contents_input'][index].remove(word)
        except:
            continue
            
    print('단어 길이 1이하인 단어 제거')

    return df

# %%
'''
# 단어 길이 1 이하 제거 안 되는 경우가 있음

for index, wordList in enumerate(sample_clean['Contents_input']):
    print(index, wordList)
    if len(sample_clean['Contents_input'][index]) == 0:
        continue
    for word in wordList:
        if len(word) <= 1:
            sample_clean['Contents_input'][index].remove(word)

sample_clean['Contents_input'][1] # 1 index '말'
'''

# %% [markdown]
# ## Text-Preprocessing

# %%
# df_clean = youtube_pre(df)
# df_clean.head()

# %% [markdown]
# ### Sample

# %%
# %%time 

# 5개 샘플 데이터
sample_clean = youtube_pre(sample)
# Out:
# 데이터 셋 구성 완료
# okt 모듈 활성
# 태그 삭제 및 품사 태깅 완료
# 명사, 형용사 추출
# 불용어 사전 로딩..
# 불용어 처리 완료
# 단어 길이 1이하인 단어 제거
# Wall time: 10min 24s

# %%
sample_clean
# Out:
#    st_n  st_cd          ch_nm        date  \
# 0  LG화학  51910  삼프로TV_경제의신과함께  2019090100
# 1  LG화학  51910  삼프로TV_경제의신과함께  2019090300
# 2  LG화학  51910  삼프로TV_경제의신과함께  2019110300
# 3  LG화학  51910  삼프로TV_경제의신과함께  2019110800
# 4  LG화학  51910  삼프로TV_경제의신과함께  2020011800
#
#                                                title  \
# 0          주식 투자자가 버려야 할 7가지!  [최준철 대표의 주식 FM가이드 #3]
# 1      누가 마지막까지 투자하는가!_19.09.03_김효진,곽상준 [오늘아침 Page2]
# 2  주식 포트폴리오 운용 방법! 경마 분석법(?) [최준철 대표의 주식 FM가이드 05-1]
# 3  삼성의 스마트폰 전략, 변화의 이유는? _19.11.07_박종일,박제영 [퇴근길 P...
# 4                       [심층인터뷰] 반복되는 4분기 '어닝쇼크' 이유는?
#
#                                                 text  views  length  \
# 0  음악최진철테스의주식fm가이드세번째시간이시작됐습니다반갑습니다점프로구요42입니다불탄fm...  38118    4364
# 1  4음악깊이가나는경제컨텐츠오늘아침페이지투정용진김도완입니다음악49월3일화요일아침오너스페...  13446    4244
# 2  5으주식시장의야전사령관최준철대표함께하는주식sm카이드다섯번째시간이시작되었습니다안녕하세...  26233    3240
# 3  깨알페이지투4안녕하십니까11월7일퇴근낄페이지툰관세장벽을일부허무는합의가도출됐다는속보가...  11245    4587
# 4  음악오늘어또손님한번보셔서공부해야줘요한테증권의김광현선임년무한을모시고오늘은4분기실적에대...   6132    1307
#
#       date_d date_h  ud_x  ud_y  \
# 0 2019-09-02     00    -1    -1
# 1 2019-09-03     00     1     1
# 2 2019-11-04     00     1     1
# 3 2019-11-08     00     1     1
# 4 2020-01-20     00     1     1
#
#                                       Contents_input
# 0  [최진철, 테스, 주식, 가이드, 세번, 시작, 반갑다, 점프, 이다, 불타다, 마...
# 1  [깊이, 가나, 경제, 컨텐츠, 오늘아침, 페이지, 정용진, 완, 이다, 오른쪽, ...
# 2  [주식시장, 야전, 사령관, 최준, 대표, 주식, 이드, 시간, 시작, 안녕하다, ...
# 3  [깨알, 페이지, 안녕하십니까, 국가, 식품, 클러스터, 스품, 관련, 스타트업, ...
# 4  [손님, 공부, 증권, 김광현, 선임, 무한, 모시, 주저, 잠정, 실적, 발표, ...

# %%
sample_clean.Contents_input[0]
# Out:
# ['최진철',
#  '테스',
#  '주식',
#  '가이드',
#  '세번',
#  '시작',
#  '반갑다',
#  '점프',
#  '이다',
#  '불타다',
#  '마켓',
#  '라서',
#  '역시',
#  '주식',
#  '가이드',
#  '게이',
#  '쉴드',
#  '매뉴얼',
#  '그날',
#  '조범',
#  '서울',
#  '가족',
#  '왜음',
#  '야전',
#  '전이',
#  '제공',
#  '부내',
#  '딜도',
#  '매뉴얼',
#  '프로',
#  '저촉',
#  '뭐요',
#  '총무',
#  '아지',
#  '금고',
#  '은비',
#  '달초',
#  '특기',
#  '은총',
#  '공군',
#  '총무',
#  '유천',
#  '식당',
#  '좋다',
#  '그다음',
#  '식당',
#  '부분',
#  '관사',
#  '관리',
#  '식당',
#  '밥앞',
#  '류큐',
#  '관리',
#  '관리',
#  '아내',
#  '표기',
#  '안되다',
#  '장교',
#  '숙소',
#  '비어',
#  '이야기',
#  '결과',
#  '독신자',
#  '에바',
#  '텔러',
#  '에어',
#  '로뭐',
#  '도대체',
#  '리세',
#  '글자',
#  '노브',
#  '여사하다',
#  '딱하다',
#  '우체국',
#  '생각',
#  '이발',
#  '발병',
#  '등단',
#  '기적',
#  '고용',
#  '안되다',
#  '사랑',
#  '알투',
#  '비르',
#  '제라',
#  '운영',
#  '병장',
#  '정말',
#  '재고',
#  '인드라',
#  '열매',
#  '작업',
#  '굉',
#  '장하다',
#  '치아',
#  '계획',
#  '래서',
#  '쉴드',
#  '매뉴얼',
#  '전교',
#  '처음',
#  '자드',
#  '전교',
#  '이유',
#  '주식시장',
#  '굉장하다',
#  '어렵다',
#  '투자',
#  '나이',
#  '고민',
#  '둘째',
#  '도의',
#  '고민',
#  '어렵다',
#  '시기',
#  '차례',
#  '실전',
#  '모시',
#  '좋다',
#  '좋다',
#  '달라',
#  '컨셉',
#  '상승',
#  '교문',
#  '제안',
#  '마음가짐',
#  '래서',
#  '주식',
#  '투자',
#  '대하',
#  '자세',
#  '쉔',
#  '이설',
#  '대표',
#  '모시',
#  '이야기',
#  '종가',
#  '현재',
#  '필요하다',
#  '겸재',
#  '따뜻하다',
#  '부동산',
#  '이야기',
#  '상모',
#  '이해',
#  '가안',
#  '가불',
#  '지난번',
#  '가의',
#  '태풍',
#  '태풍',
#  '다언',
#  '매치',
#  '희망',
#  '낙천',
#  '좀입',
#  '좋다',
#  '필드',
#  '매뉴얼',
#  '대해',
#  '자아',
#  '름',
#  '시점',
#  '프로',
#  '거지',
#  '약도',
#  '플러스',
#  '가요',
#  '끝일',
#  '거지',
#  '아내',
#  '가나',
#  '뭔가',
#  '잘못',
#  '악하다',
#  '불구',
#  '아내',
#  '뭔가',
#  '전세',
#  '요청',
#  '일어',
#  '아내',
#  '가나',
#  '어렵다',
#  '시절',
#  '조그맣다',
#  '때너',
#  '검호',
#  '아버지',
#  '시아버지',
#  '시부모',
#  '불모',
#  '거기',
#  '가지',
#  '사항',
#  '부단',
#  '질투',
#  '질투',
#  '투기',
#  '의제',
#  '제일',
#  '마트',
#  '만전',
#  '바다',
#  '투기',
#  '안되다',
#  '많다',
#  '전염병',
#  '글러브',
#  '안되다',
#  '핑크',
#  '안되다',
#  '아아',
#  '사대부',
#  '좀꼰',
#  '대적',
#  '마인드',
#  '거지',
#  '힌트',
#  '최종철',
#  '주식',
#  '투자자',
#  '거지',
#  '나름',
#  '가데나',
#  '재밌다',
#  '아예',
#  '용이',
#  '똑같다',
#  '요일',
#  '가지',
#  '로거',
#  '전소',
#  '주식',
#  '투자',
#  '거지',
#  '독창',
#  '처절',
#  '샤워',
#  '다가',
#  '문득',
#  '좋다',
#  '선교',
#  '샤워',
#  '다말',
#  '얼른',
#  '메모',
#  '가지',
#  '추가',
#  '생각',
#  '처음',
#  '원래',
#  '가지',
#  '스럽다',
#  '번트',
#  '때달핵',
#  '에르',
#  '마음',
#  '보고',
#  '점차',
#  '좋다',
#  '영혼',
#  '좋다',
#  '무리',
#  '거요',
#  '아내',
#  '가지',
#  '이유',
#  '제주',
#  '투자',
#  '시장',
#  '애가',
#  '반대',
#  '주식시장',
#  '정신',
#  '상태',
#  '정식',
#  '치면',
#  '정웅',
#  '교육',
#  '비율',
#  '규정',
#  '헌병',
#  '점프',
#  '정운',
#  '완화',
#  '리전',
#  '연령',
#  '당신',
#  '전투기',
#  '말씀',
#  '타고',
#  '적응',
#  '한일',
#  '전체',
#  '완성',
#  '시작',
#  '해진',
#  '부내',
#  '노마드',
#  '다중',
#  '노마드',
#  '듣기',
#  '노마드',
#  '특기',
#  '육군',
#  '포병',
#  '노마드',
#  '요건',
#  '친구',
#  '국가',
#  '양',
#  '요제',
#  '가지',
#  '원래',
#  '칠거지악',
#  '유일하다',
#  '항목',
#  '게이',
#  '질투',
#  '투기',
#  '옛날',
#  '말로',
#  '투기',
#  '질투',
#  '수인',
#  '높다',
#  '사람',
#  '질투',
#  '수익률',
#  '높다',
#  '사람',
#  '주식',
#  '기특하다',
#  '종가',
#  '까운',
#  '사람',
#  '가깝다',
#  '사람',
#  '도나',
#  '좋다',
#  '생각',
#  '사람',
#  '이다',
#  '오죽하다',
#  '사촌',
#  '을사',
#  '면배',
#  '아프다',
#  '수많다',
#  '격언',
#  '상당하다',
#  '제만',
#  '이용',
#  '공감',
#  '속담',
#  '한국인',
#  '굉장하다',
#  '심하다',
#  '편이',
#  '게이',
#  '제주',
#  '투자',
#  '게이',
#  '문제',
#  '씨앗',
#  '배아',
#  '유전자',
#  '그것',
#  '사면',
#  '보수',
#  '불로소득',
#  '로또',
#  '당첨',
#  '예주',
#  '을해',
#  '아파트',
#  '현대',
#  '자본주의',
#  '많다',
#  '질투',
#  '유발',
#  '대표',
#  '요인',
#  '되다',
#  '도참',
#  '짜증나다',
#  '안되다',
#  '좋다',
#  '아따',
#  '아프다',
#  '불안',
#  '좀비',
#  '자체',
#  '아기',
#  '아예',
#  '진짜',
#  '우수하다',
#  '글씨',
#  '진짜',
#  '신나다',
#  '네온',
#  '방향',
#  '어그',
#  '위기',
#  '시리즈',
#  '유가',
#  '여름',
#  '고생',
#  '해자',
#  '학교',
#  '출신',
#  '고못',
#  '데즉',
#  '친구',
#  '노두',
#  '갑자기',
#  '모마',
#  '가지',
#  '사업',
#  '회소',
#  '볼흠왜',
#  '할부',
#  '위로',
#  '정배',
#  '아프다',
#  '공부',
#  '애가',
#  '면제',
#  '회사',
#  '누라',
#  '저주',
#  '식사',
#  '면제',
#  '아프다',
#  '그다음',
#  '며칠',
#  '어머',
#  '상표',
#  '그것',
#  '훌륭하다',
#  '목사',
#  '사람',
#  '솔직하다',
#  '부하',
#  '마음',
#  '실제',
#  '장모님',
#  '사위',
#  '주식',
#  '주식',
#  '초반',
#  '경험',
#  '주식',
#  '시작',
#  '학부형',
#  '표현',
#  '교사',
#  '그거',
#  '고학',
#  '부용',
#  '아들',
#  '보통',
#  '합병',
#  '친구',
#  '도아',
#  '사이',
#  '애매하다',
#  '관계',
#  '아들',
#  '친구',
#  '엄마',
#  '는달',
#  '친구',
#  '자식',
#  '통해',
#  '데뷔전',
#  '도하',
#  '관계',
#  '거기',
#  '제자',
#  '시작',
#  '아대',
#  '부분',
#  '출발점',
#  '질투',
#  '시작',
#  '노래',
#  '어제',
#  '소파',
#  '그냥',
#  '방송',
#  '예해',
#  '야합',
#  '다그',
#  '래서',
#  '걸이',
#  '제보',
#  '은주',
#  '시작',
#  '잘못',
#  '모주',
#  '사랑',
#  '사람',
#  '아프다',
#  '좋다',
#  '태도',
#  '시작',
#  '만듭',
#  '다대',
#  '표적',
#  '주식',
#  '만만하다',
#  '보고',
#  '시작',
#  '만듭',
#  '다그',
#  '사람',
#  '전문가',
#  '도아',
#  '고솔',
#  '직하다',
#  '지적',
#  '생각',
#  '사람',
#  '이주식',
#  '가노',
#  '결과',
#  '색깔',
#  '노력',
#  '사람',
#  '오니',
#  '가못',
#  '덜하다',
#  '생각',
#  '접근',
#  '시작',
#  '거치',
#  '공부',
#  '시작',
#  '케이스',
#  '보지',
#  '그게',
#  '문제',
#  '투자',
#  '출발',
#  '질투',
#  '시작',
#  '보통',
#  '상적',
#  '오류',
#  '거구',
#  '지그',
#  '이후',
#  '주식',
#  '여러가지',
#  '부류',
#  '뭐제',
#  '좋아하다',
#  '배당',
#  '주도',
#  '주도',
#  '화제',
#  '급등',
#  '급등',
#  '기본',
#  '결과',
#  '깝습',
#  '최근',
#  '의미',
#  '오른',
#  '종목',
#  '더위',
#  '험하다',
#  '리스크',
#  '좀점증',
#  '가격',
#  '측면',
#  '데이',
#  '등주',
#  '서나',
#  '동주',
#  '리좀',
#  '부러',
#  '사람',
#  '도버',
#  '동참',
#  '마음',
#  '시기심',
#  '생기',
#  '보통',
#  '시작',
#  '주식',
#  '길다',
#  '주식',
#  '등주',
#  '기억',
#  '많다',
#  '이보',
#  '충분하다',
#  '순',
#  '꾸준하다',
#  '성공하다',
#  '어렵다',
#  '비슷하다',
#  '질투',
#  '구조',
#  '주식',
#  '시작',
#  '당연하다',
#  '주식',
#  '기본',
#  '생각',
#  '제이',
#  '시작',
#  '통상',
#  '시작',
#  '많다',
#  '고민',
#  '주로',
#  '오류',
#  '이면',
#  '시작',
#  '거나',
#  '또뭐',
#  '등주',
#  '기웃',
#  '거리',
#  '부분',
#  '찬찬하다',
#  '좋다',
#  '다솔',
#  '실제',
#  '어렵다',
#  '과정',
#  '을제',
#  '하루',
#  '뭐책몇곳',
#  '보시',
#  '투자',
#  '질투',
#  '시기',
#  '심은하',
#  '굉장하다',
#  '독립',
#  '사고',
#  '사람',
#  '이기',
#  '사람',
#  '성적',
#  '사람',
#  '보고',
#  '의몫',
#  '여경',
#  '다르다',
#  '명확하다',
#  '이제선',
#  '버피',
#  '경우',
#  '인생',
#  '전체',
#  '확실하다',
#  '다른사람',
#  '이올린',
#  '실적',
#  '수익률',
#  '민감하다',
#  '반응',
#  '영어',
#  '단단하다',
#  '마음',
#  '질투',
#  '다른사람',
#  '분리',
#  '생각',
#  '오롯',
#  '방법',
#  '투자',
#  '주식',
#  '집중',
#  '성공',
#  '케이스',
#  '보시',
#  '이제선',
#  '악의',
#  '좋다',
#  '뭐내',
#  '마고',
#  '잘나다',
#  '사람',
#  '게다',
#  '질투',
#  '생각',
#  '그게',
#  '안좋다',
#  '결과',
#  '명문',
#  '도나',
#  '질투',
#  '바지',
#  '파이프',
#  '비롯',
#  '듯좀',
#  '서로',
#  '검색',
#  '칠거지악',
#  '질투',
#  '영적',
#  '남자',
#  '이만',
#  '애가',
#  '고오',
#  '신생활',
#  '여자',
#  '뭔가',
#  '썸씽',
#  '이의',
#  '제기',
#  '아라하',
#  '시트',
#  '정말',
#  '이일',
#  '아따',
#  '경우',
#  '환영',
#  '올해',
#  '아깝다',
#  '자판',
#  '오디',
#  '나라',
#  '아앙',
#  '파랑색',
#  '야하다',
#  '새롭다',
#  '자식',
#  '되다',
#  '배아',
#  '좋아하다',
#  '투자',
#  '방법',
#  '나이트',
#  '좋다',
#  '질투',
#  '라이거',
#  '이성',
#  '번은',
#  '탐욕',
#  '욕심',
#  '이아',
#  '좋다',
#  '나쁘다',
#  '자본주의',
#  '사회',
#  '욕심',
#  '억지로',
#  '제거',
#  '려고',
#  '필요',
#  '거기',
#  '탐욕',
#  '표현',
#  '욕심',
#  '비해',
#  '욕심',
#  '다예',
#  '머릿속',
#  '여러가지',
#  '대감',
#  '상상',
#  '사업',
#  '투자',
#  '일이',
#  '현실',
#  '현실',
#  '기본',
#  '제약',
#  '조건',
#  '가중',
#  '기기',
#  '점프',
#  '기껏',
#  '마이클',
#  '조던',
#  '가면',
#  '좀더',
#  '제일',
#  '프로',
#  '시대',
#  '단말',
#  '중령',
#  '금리',
#  '기본',
#  '자산',
#  '가격',
#  '결정',
#  '중력',
#  '생각',
#  '밉다',
#  '제기',
#  '본적',
#  '벤치마크',
#  '로마니',
#  '금리',
#  '종목',
#  '모건',
#  '종목',
#  '일대',
#  '기면',
#  '그게',
#  '수이',
#  '아예',
#  '수익',
#  '요것',
#  '춤철',
#  '프로',
#  '파격',
#  '우려',
#  '돼지',
#  '그게',
#  '안되다',
#  '말씀',
#  '탐욕',
#  '거리',
#  '분산',
#  '탐욕',
#  '신분',
#  '부산하다',
#  '섀도우',
#  '헌터',
#  '신용',
#  '극단',
#  '케이스',
#  '합력',
#  '거구',
#  '분산',
#  '을해',
#  '옳다',
#  '합리',
#  '인기',
#  '생각',
#  '열정',
#  '도제',
#  '땐좀',
#  '탐욕',
#  '요건',
#  '타자',
#  '목표',
#  '건좀',
#  '탐험',
#  '흔하다',
#  '결과',
#  '프로',
#  '열정',
#  '사람',
#  '이아',
#  '열정',
#  '다지',
#  '금답',
#  '못골',
#  '그거',
#  '탐욕',
#  '막상',
#  '거지',
#  '종목',
#  '된거',
#  '안텍',
#  '가요',
#  '전력',
#  '최초',
#  '어원',
#  '주식',
#  '종목',
#  '이안',
#  '프로',
#  '수익',
#  '라가',
#  '덥다',
#  '가깝다',
#  '그냥',
#  '예심',
#  '때뭘',
#  '열정',
#  '나타',
#  '잘못',
#  '생각',
#  '수익',
#  '퍼센트',
#  '가중',
#  '요한',
#  '회사',
#  '중요하다',
#  '후루',
#  '가주',
#  '의하다',
#  '시작',
#  '이익',
#  '집중',
#  '택시',
#  '회사',
#  '회사',
#  '만원',
#  '나중',
#  '전혀',
#  '아깝다',
#  '정답',
#  '보유',
#  '종목',
#  '연일',
#  '예더',
#  '가든',
#  '결정',
#  '문제',
#  '는고',
#  '스톱',
#  '서고',
#  '휴대',
#  '키스',
#  '고모',
#  '데이',
#  '말씀',
#  '상태',
#  '좋아하다',
#  '걸좀',
#  '가깝다',
#  '기본',
#  '펀더',
#  '멘털',
#  '기준',
#  '가지',
#  '카페',
#  '내폐',
#  '종합',
#  '고려',
#  '음고',
#  '말거',
#  '결정',
#  '건데',
#  '대부분',
#  '안타깝다',
#  '패가',
#  '탭',
#  '대당',
#  '시멘트',
#  '배당',
#  '경우',
#  '제해',
#  '고온',
#  '경우',
#  '배시',
#  '색깔',
#  '좌측',
#  '짧다',
#  '전하',
#  '쌀거',
#  '아주',
#  '심각하다',
#  '질병',
#  '금은',
#  '기본',
#  '좋다',
#  '회사',
#  '이다',
#  '경우',
#  '라든지',
#  '회사',
#  '간의',
#  '가치',
#  '상승',
#  '마트',
#  '메일',
#  '디마',
#  '배당',
#  '수익률',
#  '축가',
#  '배당',
#  '종목',
#  '리가',
#  '팔고',
#  '저걸',
#  '살수',
#  '더하다',
#  '복잡하다',
#  '하나로',
#  '좀뭐',
#  '최소한',
#  '자의',
#  '근거',
#  '대한',
#  '그게',
#  '가치투자',
#  '일수',
#  '레이더',
#  '수도',
#  '수급',
#  '경우',
#  '인간',
#  '탐욕',
#  '판단',
#  '가치투자',
#  '작다',
#  ...]

# %%
sample_clean.Contents_input[1] # 한 글자 안 지워짐
# Out:
# ['깊이',
#  '가나',
#  '경제',
#  '컨텐츠',
#  '오늘아침',
#  '페이지',
#  '정용진',
#  '완',
#  '이다',
#  '오른쪽',
#  '어스',
#  '페이지',
#  '라이브',
#  '일이',
#  '항상',
#  '오지',
#  '김효진',
#  '연구원',
#  '흥미롭다',
#  '주제',
#  '계속',
#  '해주시',
#  '어제',
#  '새벽',
#  '새벽',
#  '좋다',
#  '자정',
#  '뭐총',
#  '문화',
#  '제도',
#  '광고',
#  '뉴스',
#  '시작',
#  '도록',
#  '히터',
#  '아빠',
#  '발던밥',
#  '두껍다',
#  '새콤',
#  '뉴스',
#  '잠좀',
#  '먼저',
#  '국내',
#  '배터리',
#  '업계',
#  '화주',
#  '화학',
#  '이노베이션',
#  '송전',
#  '사이',
#  '중국',
#  '배터리',
#  '업계',
#  '무섭다',
#  '약진',
#  '고합',
#  '역시',
#  '삼성',
#  '라든지',
#  '업체',
#  '종교',
#  '배터리',
#  '관련',
#  '전기자동차',
#  '배터리',
#  '에너지',
#  '저장장치',
#  '배터리',
#  '중국',
#  '업체',
#  '시장점유율',
#  '확대',
#  '상황',
#  '문제',
#  '배터리',
#  '업체',
#  '선반',
#  '업체',
#  '가어',
#  '화학',
#  '그다음',
#  '참석',
#  '고서',
#  '이노베이션',
#  '데이',
#  '사가',
#  '큰손',
#  '요한',
#  '변호사비용',
#  '이세',
#  '송정',
#  '데이',
#  '문제',
#  '발단',
#  '화학',
#  '이노베이션',
#  '이직',
#  '화학',
#  '친구',
#  '영업비밀',
#  '유출',
#  '보고',
#  '영업비밀',
#  '침해',
#  '미국',
#  '국제무역',
#  '위원회',
#  '외부',
#  '소송',
#  '제기',
#  '한국어',
#  '지화학',
#  '규명',
#  '입장',
#  '반하다',
#  '이노베이션',
#  '도그마',
#  '소송',
#  '특허',
#  '침해',
#  '이제우',
#  '선반',
#  '업체',
#  '후반',
#  '업체',
#  '게정',
#  '말초',
#  '제소',
#  '전이',
#  '제이',
#  '법적',
#  '문제',
#  '법정',
#  '비용',
#  '국내',
#  '기업',
#  '끼리',
#  '미국',
#  '의소',
#  '성전',
#  '을해',
#  '대해',
#  '그게',
#  '우려',
#  '목소리',
#  '이노베이션',
#  '대화',
#  '좋다',
#  '입장',
#  '가문',
#  '제기',
#  '소송',
#  '국내',
#  '대표',
#  '기억',
#  '대화',
#  '좋다',
#  '입장',
#  '반하다',
#  '정악',
#  '괴뢰',
#  '강경아',
#  '먼저',
#  '사과',
#  '재발',
#  '방지',
#  '보상',
#  '문제',
#  '선결',
#  '화하다',
#  '제소',
#  '먼저',
#  '제기',
#  '한쪽',
#  '당연하다',
#  '입자',
#  '프로',
#  '전기차',
#  '배터리',
#  '배터리',
#  '미래',
#  '먹거리',
#  '로이',
#  '부상',
#  '삼성',
#  '건데',
#  '과정',
#  '필요하다',
#  '특허',
#  '문제',
#  '비밀',
#  '대한',
#  '대출',
#  '문제',
#  '다가',
#  '벌',
#  '보상',
#  '을해',
#  '보상',
#  '을해',
#  '중국',
#  '업체',
#  '뭔가',
#  '또해',
#  '가지',
#  '고이',
#  '그룹',
#  '회사',
#  '슬리',
#  '자가',
#  '중재',
#  '생각',
#  '좀듭',
#  '어차피',
#  '일이',
#  '중재',
#  '설기',
#  '서예',
#  '방송',
#  '통해',
#  '서로',
#  '방법',
#  '섭외',
#  '괜찬',
#  '안되다',
#  '베타',
#  '를좀',
#  '가요',
#  '화이',
#  '이노베이션',
#  '아파트',
#  '두번째',
#  '중국',
#  '외교부',
#  '평양',
#  '착하다',
#  '사회',
#  '북한',
#  '방문',
#  '일정',
#  '시작',
#  '김정은',
#  '위원장',
#  '면담',
#  '할갑다',
#  '다르다',
#  '좋다',
#  '김위',
#  '원장',
#  '방정',
#  '논의',
#  '모이',
#  '실력',
#  '에어',
#  '제도',
#  '박석준',
#  '의원',
#  '많다',
#  '중국',
#  '건국',
#  '주년',
#  '탈',
#  '역사상',
#  '최대',
#  '규모',
#  '열병',
#  '예정',
#  '북중',
#  '수교',
#  '해기',
#  '학년',
#  '김정훈',
#  '위원장',
#  '중국',
#  '당국',
#  '초대',
#  '케냐',
#  '생각',
#  '이듭',
#  '외교부',
#  '김정훈',
#  '위원장',
#  '방중',
#  '문제',
#  '논의',
#  '기사',
#  '핀',
#  '지속',
#  '강하다',
#  '문제',
#  '생각',
#  '이방',
#  '옛날',
#  '다음',
#  '업계',
#  '외교',
#  '시기',
#  '조율',
#  '해도',
#  '오기',
#  '된거',
#  '호텔',
#  '해프닝',
#  '조절',
#  '상황',
#  '생각',
#  '나비',
#  '내실및',
#  '관속',
#  '방학',
#  '문제',
#  '북한',
#  '사전',
#  '소통',
#  '출원',
#  '기사',
#  '주년',
#  '귀염',
#  '인사',
#  '최대',
#  '열병',
#  '다그',
#  '서열',
#  '병시',
#  '점토',
#  '열병',
#  '박근혜',
#  '전대통령',
#  '크게',
#  '오늘이',
#  '명',
#  '참여',
#  '그게',
#  '드림',
#  '전승',
#  '기념',
#  '행사',
#  '박근혜',
#  '전대통령',
#  '참여',
#  '죽겠네',
#  '민하',
#  '다가',
#  '여러가지',
#  '다가',
#  '참석',
#  '이후',
#  '사드',
#  '배치',
#  '문제',
#  '주목',
#  '관계',
#  '굉장하다',
#  '경색',
#  '일이',
#  '정부',
#  '요청',
#  '부분',
#  '주년',
#  '행사',
#  '준비',
#  '의당',
#  '국자',
#  '홍콩',
#  '소요',
#  '사태',
#  '굉장하다',
#  '성가',
#  '신일',
#  '홍콩',
#  '사태',
#  '단자',
#  '경우',
#  '효율',
#  '사태',
#  '치열',
#  '주가',
#  '소위',
#  '짜증나다',
#  '홍콩',
#  '문제',
#  '조이',
#  '제바',
#  '시작',
#  '내내',
#  '굉장하다',
#  '뜨겁다',
#  '감자',
#  '정치',
#  '이벤트',
#  '이벤트',
#  '원래',
#  '주물',
#  '정부',
#  '입장',
#  '해결',
#  '부분',
#  '위시',
#  '동북아시아',
#  '지정학적',
#  '문제',
#  '관계',
#  '좋다',
#  '생각',
#  '해도',
#  '중국',
#  '초청',
#  '선택',
#  '가면',
#  '준비',
#  '우려',
#  '추가',
#  '약간',
#  '일간',
#  '부채',
#  '미아',
#  '문제',
#  '루뭐',
#  '미국',
#  '국방부',
#  '장관',
#  '국무부',
#  '관우',
#  '말씀',
#  '섭외',
#  '섭섭하다',
#  '우려',
#  '가웃',
#  '상황',
#  '민감하다',
#  '시즌',
#  '생각',
#  '자칫',
#  '미국',
#  '고통',
#  '시가',
#  '상관',
#  '간의',
#  '단순하다',
#  '뉴스',
#  '단계',
#  '북한',
#  '관계',
#  '한미관계',
#  '의아',
#  '설킨것',
#  '뭔가',
#  '초청',
#  '도안',
#  '가수',
#  '힘들다',
#  '무적',
#  '나물',
#  '등거',
#  '리가',
#  '중국',
#  '선임',
#  '그냥',
#  '아차',
#  '경우',
#  '초철',
#  '걱정',
#  '가두',
#  '억제',
#  '걱정',
#  '변수',
#  '서로',
#  '충돌',
#  '중심',
#  '잡고',
#  '광고',
#  '광고',
#  '아앙',
#  '쪽악',
#  '유사',
#  '다시',
#  '눈앞',
#  '실바',
#  '루나',
#  '죄송하다',
#  '뉴스',
#  '주차',
#  '두번째',
#  '주소',
#  '심각하다',
#  '두번째',
#  '인수',
#  '무아',
#  '체이스',
#  '조국',
#  '법무부',
#  '장관',
#  '후보자',
#  '입시',
#  '관련',
#  '의혹',
#  '좋다',
#  '그게',
#  '교육',
#  '관련',
#  '주식',
#  '이호재',
#  '노지',
#  '문제',
#  '문제',
#  '대통령',
#  '조가',
#  '가족',
#  '논란',
#  '논란',
#  '차원',
#  '버디',
#  '대학',
#  '주제',
#  '전반',
#  '좀재',
#  '검토',
#  '대통령',
#  '주문',
#  '이기',
#  '실무',
#  '부처님',
#  '교육부',
#  '대안',
#  '고재',
#  '검토',
#  '요청',
#  '일수',
#  '에전',
#  '반적',
#  '교육',
#  '업계',
#  '분위기',
#  '게뭐',
#  '수시',
#  '현재',
#  '내신',
#  '학생',
#  '종합',
#  '채널',
#  '브라',
#  '밉다',
#  '평가',
#  '위주',
#  '입시',
#  '제도',
#  '제기',
#  '예정',
#  '정리',
#  '시쪽',
#  '왜냐면',
#  '제이',
#  '논란',
#  '멋있다',
#  '자가',
#  '어디가',
#  '인턴',
#  '자체',
#  '은부',
#  '때톡',
#  '적통',
#  '영향',
#  '부모',
#  '스킬',
#  '꿈북',
#  '사람',
#  '은탄환',
#  '강남',
#  '의미',
#  '물때',
#  '논술',
#  '시작',
#  '당나귀',
#  '진행',
#  '씬',
#  '플랫',
#  '하루',
#  '결정',
#  '론',
#  '제입',
#  '시제',
#  '이제선',
#  '진국',
#  '일반',
#  '직항',
#  '건데',
#  '부자',
#  '정시',
#  '비중',
#  '확대',
#  '정치',
#  '선예',
#  '염두',
#  '돈거',
#  '정시',
#  '비중',
#  '업체',
#  '안주',
#  '인강',
#  '업체',
#  '시험',
#  '이주',
#  '야단',
#  '바닥',
#  '인터넷',
#  '강의',
#  '업체',
#  '어제',
#  '가치',
#  '수시',
#  '비중',
#  '지아',
#  '아이템',
#  '학교',
#  '교육',
#  '애매하다',
#  '과열',
#  '비판',
#  '강사',
#  '탄사',
#  '가수',
#  '마디',
#  '오예',
#  '가지',
#  '뭐배',
#  '스타',
#  '드리머',
#  '뉴스',
#  '야우리',
#  '입시',
#  '제노',
#  '된거',
#  '학령',
#  '이임',
#  '박하다',
#  '이그',
#  '인터넷',
#  '강의',
#  '업체',
#  '교육',
#  '업체',
#  '시작',
#  '럼',
#  '술상',
#  '해주',
#  '불구',
#  '러',
#  '시장',
#  '중요하다',
#  '구루',
#  '아크',
#  '더돈',
#  '명',
#  '얜',
#  '경우',
#  '리나',
#  '거지',
#  '현상',
#  '니까야',
#  '이후',
#  '사교육',
#  '시장',
#  '대해',
#  '가뒤',
#  '파악',
#  '필요',
#  '인식',
#  '더하다',
#  '질서',
#  '시장',
#  '아주',
#  '교육',
#  '크게',
#  '소식',
#  '좋다',
#  '대표',
#  '생각',
#  '고아',
#  '어제',
#  '저녁때',
#  '마음',
#  '아프다',
#  '음예애',
#  '개월',
#  '주식',
#  '무릎',
#  '리가',
#  '정책',
#  '이슈',
#  '대해',
#  '반응',
#  '좋다',
#  '전반',
#  '그것',
#  '방향',
#  '뿐더러',
#  '고저',
#  '취약',
#  '연령',
#  '상영',
#  '구가',
#  '감안',
#  '생각',
#  '권해',
#  '추적',
#  '대단하다',
#  '괴',
#  '또음',
#  '가격',
#  '추측',
#  '도참',
#  '대단하다',
#  '이름',
#  '블레스',
#  '장기',
#  '투자',
#  '까비',
#  '자발',
#  '장기',
#  '뉴스',
#  '뉴스',
#  '김효진',
#  '연구',
#  '광고',
#  '검색',
#  '코르크',
#  '요코',
#  '루코',
#  '이다',
#  '친환경',
#  '가죽',
#  '가죽',
#  '애매하다',
#  '코르크',
#  '동물',
#  '가죽',
#  '코르크',
#  '나무',
#  '원료',
#  '로만',
#  '컷코',
#  '제품',
#  '볼펜',
#  '지갑',
#  '가방',
#  '신발',
#  '모든',
#  '의주',
#  '생활',
#  '허리',
#  '안전',
#  '우주',
#  '띠것',
#  '케틀벨',
#  '명함',
#  '지갑',
#  '건어물',
#  '뭔가',
#  '당당하다',
#  '당당하다',
#  '생각',
#  '사람',
#  '실제',
#  '생각',
#  '교체',
#  '자진',
#  '푸른',
#  '이미라',
#  '폐지',
#  '화요일',
#  '서비스',
#  '관리',
#  '시작',
#  '증권',
#  '김효진',
#  '연구원',
#  '반갑다',
#  '야자',
#  '연구원',
#  '달',
#  '백질',
#  '게살',
#  '용이',
#  '인더스',
#  '트리',
#  '왜봐',
#  '야하다',
#  '쉬엄',
#  '산업',
#  '마지막',
#  '입',
#  '짧다',
#  '투자',
#  '음제',
#  '이야기',
#  '발전',
#  '생각',
#  '폭락',
#  '바람',
#  '누가',
#  '화녀',
#  '자꾸',
#  '정아',
#  '최근',
#  '에지',
#  '기관',
#  '투자자',
#  '개인',
#  '투자자',
#  '만난',
#  '내년',
#  '주식',
#  '힘들다',
#  '질문',
#  '투잡',
#  '아들',
#  '테픽',
#  '완투',
#  '자작',
#  '개인',
#  '투자자',
#  '내년',
#  '힘들다',
#  '보수',
#  '투자',
#  '투자',
#  '연기금',
#  '마찬가지',
#  '컨틴',
#  '플랜',
#  '마무리',
#  '파리',
#  '기둥',
#  '힘들다',
#  '모주',
#  '자신감',
#  '요예',
#  '내년',
#  '글로벌',
#  '주식',
#  '한국',
#  '주식',
#  '방향',
#  '아래',
#  '호르',
#  '댓글',
#  '생각',
#  '그게',
#  '질문',
#  '가장',
#  '보고',
#  '도조',
#  '터얘',
#  '예제',
#  '아만',
#  '달',
#  '정도전',
#  '에어',
#  '진입',
#  '글로벌',
#  '혼자',
#  '하위',
#  '커플링',
#  '미국',
#  '때못',
#  '글로벌',
#  '미국증시',
#  '굉장하다',
#  '어렵다',
#  '조건',
#  '설비',
#  '투자',
#  '경제',
#  '섯옆',
#  '가기',
#  '시작',
#  '안정화',
#  '효과',
#  '영업',
#  '이익',
#  '숫자',
#  '작년',
#  '뻥튀기',
#  '숫자',
#  '인하다',
#  '외국인투자',
#  '입장',
#  '이후',
#  '대손',
#  '어제',
#  '영화',
#  '백조',
#  '내년',
#  '안착',
#  '굉장하다',
#  '중요하다',
#  '올해',
#  '내년',
#  '패칸',
#  '좋다',
#  '표시',
#  '올해',
#  '백조',
#  '하양',
#  '가능성',
#  '방',
#  '와썹',
#  '작년',
#  '삼성',
#  '영업',
#  '중반',
#  '철학',
#  '우린',
#  '기업',
#  '단위',
#  '아아',
#  '백조',
#  '바텀라인',
#  '설정',
#  '굉장하다',
#  '관문',
#  '다데',
#  '중요하다',
#  '포인트',
#  '라라',
#  '생각',
#  '최근',
#  '잘맞다',
#  '작년',
#  '겨울',
#  '피하',
#  '좋다',
#  '밸류',
#  '에이',
#  '션툴',
#  '도보',
#  '도보',
#  '작동',
#  '어렵다',
#  '수준',
#  '계속',
#  '올해',
#  '조정',
#  '도하',
#  '내년',
#  '백조',
#  '요게',
#  '바텀라인',
#  '사람',
#  '인정',
#  '다라',
#  '고하',
#  '비싸다',
#  '이야기',
#  '상황',
#  '상황',
#  '계속',
#  '고해',
#  '한국',
#  '주식',
#  '마음',
#  '돼지',
#  '어렵다',
#  '그거',
#  '업무',
#  '전대',
#  '그게',
#  '굉장하다',
#  '중요하다',
#  '가능하다',
#  '생각',
#  '가능하다',
#  '생각',
#  '한국',
#  '수출',
#  '기업',
#  '많다',
#  '수출',
#  '데이터',
#  '가지',
#  '이야기',
#  '보호무역',
#  '정치',
#  '불확실',
#  '내년',
#  '다행하다',
#  '수준',
#  '는가',
#  '크게',
#  '편하다',
#  '환율',
#  '생각',
#  '작년',
#  '참배',
#  '세로',
#  '또늘',
#  '좋다',
#  '가물',
#  '량의물량',
#  '제안',
#  ...]

# %%
count = Counter(sample_clean.Contents_input[0])
words = dict(count.most_common())
words
# Out:
# {'사람': 57,
#  '주식': 49,
#  '생각': 39,
#  '그렇다': 38,
#  '좋다': 32,
#  '투자': 29,
#  '가지': 28,
#  '많다': 24,
#  '시작': 22,
#  '공부': 21,
#  '종목': 21,
#  '이제': 21,
#  '정말': 18,
#  '도박': 18,
#  '굉장하다': 17,
#  '안되다': 16,
#  '질투': 16,
#  '경우': 16,
#  '뭐': 16,
#  '어렵다': 14,
#  '그게': 14,
#  '탐욕': 14,
#  '시장': 13,
#  '있다': 13,
#  '잘못': 12,
#  '투자자': 12,
#  '뭔가': 11,
#  '거기': 11,
#  '정보': 11,
#  '얘기': 11,
#  '거지': 10,
#  '친구': 10,
#  '그것': 10,
#  '진짜': 10,
#  '좀더': 10,
#  '거래': 10,
#  '게이': 9,
#  '프로': 9,
#  '부분': 9,
#  '대표': 9,
#  '대해': 9,
#  '보고': 9,
#  '회사': 9,
#  '그냥': 9,
#  '좋아하다': 9,
#  '나쁘다': 9,
#  '아니다': 9,
#  '주주': 9,
#  '조급하다': 9,
#  '같다': 9,
#  '그다음': 8,
#  '아예': 8,
#  '마음': 8,
#  '말씀': 8,
#  '높다': 8,
#  '방법': 8,
#  '욕심': 8,
#  '실수': 8,
#  '쉽다': 8,
#  '계속': 8,
#  '상승': 7,
#  '문제': 7,
#  '그거': 7,
#  '기본': 7,
#  '가격': 7,
#  '수익': 7,
#  '가치투자': 7,
#  '없다': 7,
#  '결과': 6,
#  '래서': 6,
#  '이유': 6,
#  '나름': 6,
#  '애가': 6,
#  '교육': 6,
#  '실제': 6,
#  '사고': 6,
#  '자산': 6,
#  '체크': 6,
#  '테마주': 6,
#  '반복': 6,
#  '주가': 6,
#  '저희': 6,
#  '때문': 6,
#  '게': 6,
#  '심리': 6,
#  '이렇다': 6,
#  '이다': 5,
#  '쉴드': 5,
#  '아내': 5,
#  '제안': 5,
#  '투기': 5,
#  '칠거지악': 5,
#  '옛날': 5,
#  '가깝다': 5,
#  '아프다': 5,
#  '보통': 5,
#  '도하': 5,
#  '케이스': 5,
#  '배당': 5,
#  '보시': 5,
#  '야하다': 5,
#  '일이': 5,
#  '결정': 5,
#  '대부분': 5,
#  '인간': 5,
#  '위험하다': 5,
#  '상황': 5,
#  '면서': 5,
#  '스스로': 5,
#  '오늘': 5,
#  '원칙': 5,
#  '가이드': 4,
#  '매뉴얼': 4,
#  '처음': 4,
#  '고민': 4,
#  '필드': 4,
#  '가나': 4,
#  '제일': 4,
#  '노마드': 4,
#  '수익률': 4,
#  '을해': 4,
#  '사업': 4,
#  '경험': 4,
#  '방송': 4,
#  '급등': 4,
#  '리스크': 4,
#  '당연하다': 4,
#  '거나': 4,
#  '다른사람': 4,
#  '집중': 4,
#  '아깝다': 4,
#  '이아': 4,
#  '현실': 4,
#  '열정': 4,
#  '살수': 4,
#  '더하다': 4,
#  '레이더': 4,
#  '판단': 4,
#  '무조건': 4,
#  '이그': 4,
#  '먼저': 4,
#  '에이': 4,
#  '선택': 4,
#  '대선': 4,
#  '본인': 4,
#  '테마': 4,
#  '개인': 4,
#  '메뉴얼': 4,
#  '매도': 4,
#  '가장': 4,
#  '군중': 4,
#  '일본': 4,
#  '소수': 4,
#  '우리': 4,
#  '사실': 4,
#  '느긋하다': 4,
#  '말': 4,
#  '최진철': 3,
#  '세번': 3,
#  '점프': 3,
#  '식당': 3,
#  '관리': 3,
#  '이야기': 3,
#  '작업': 3,
#  '대하': 3,
#  '종가': 3,
#  '필요하다': 3,
#  '이해': 3,
#  '아아': 3,
#  '원래': 3,
#  '제주': 3,
#  '전체': 3,
#  '완성': 3,
#  '도나': 3,
#  '되다': 3,
#  '아기': 3,
#  '아들': 3,
#  '어제': 3,
#  '노력': 3,
#  '상적': 3,
#  '오류': 3,
#  '여러가지': 3,
#  '주도': 3,
#  '최근': 3,
#  '데이': 3,
#  '등주': 3,
#  '동참': 3,
#  '생기': 3,
#  '충분하다': 3,
#  '성공하다': 3,
#  '구조': 3,
#  '제이': 3,
#  '하루': 3,
#  '독립': 3,
#  '이기': 3,
#  '성공': 3,
#  '게다': 3,
#  '안좋다': 3,
#  '남자': 3,
#  '사회': 3,
#  '제약': 3,
#  '신분': 3,
#  '중요하다': 3,
#  '짧다': 3,
#  '일부러': 3,
#  '장': 3,
#  '두번째': 3,
#  '일반': 3,
#  '기법': 3,
#  '기전': 3,
#  '궁금하다': 3,
#  '확인': 3,
#  '파워': 3,
#  '반영': 3,
#  '완전하다': 3,
#  '마르다': 3,
#  '느낌': 3,
#  '게으름': 3,
#  '속삭임': 3,
#  '예뭐': 3,
#  '기업': 3,
#  '재미': 3,
#  '장점': 3,
#  '해도': 3,
#  '선생님': 3,
#  '외부': 3,
#  '뭘': 3,
#  '절대': 3,
#  '반성': 3,
#  '사서': 3,
#  '좀덜': 3,
#  '힘들다': 3,
#  '서남': 3,
#  '예': 3,
#  '바보': 3,
#  '얼음판': 3,
#  '거': 3,
#  '점': 3,
#  '외롭다': 3,
#  '고저': 3,
#  '낮다': 3,
#  '어떻다': 3,
#  '자신': 3,
#  '도': 3,
#  '좀': 3,
#  '트럼프': 3,
#  '그날': 2,
#  '부내': 2,
#  '총무': 2,
#  '특기': 2,
#  '딱하다': 2,
#  '사랑': 2,
#  '전교': 2,
#  '주식시장': 2,
#  '시기': 2,
#  '모시': 2,
#  '달라': 2,
#  '자세': 2,
#  '지난번': 2,
#  '태풍': 2,
#  '희망': 2,
#  '가요': 2,
#  '아버지': 2,
#  '의제': 2,
#  '마트': 2,
#  '샤워': 2,
#  '다가': 2,
#  '점차': 2,
#  '반대': 2,
#  '상태': 2,
#  '요건': 2,
#  '수많다': 2,
#  '상당하다': 2,
#  '배아': 2,
#  '자본주의': 2,
#  '요인': 2,
#  '아따': 2,
#  '자체': 2,
#  '유가': 2,
#  '갑자기': 2,
#  '면제': 2,
#  '식사': 2,
#  '며칠': 2,
#  '훌륭하다': 2,
#  '표현': 2,
#  '도아': 2,
#  '관계': 2,
#  '는달': 2,
#  '자식': 2,
#  '다그': 2,
#  '걸이': 2,
#  '태도': 2,
#  '만듭': 2,
#  '지적': 2,
#  '이주식': 2,
#  '색깔': 2,
#  '거구': 2,
#  '측면': 2,
#  '길다': 2,
#  '기억': 2,
#  '꾸준하다': 2,
#  '이면': 2,
#  '거리': 2,
#  '과정': 2,
#  '성적': 2,
#  '다르다': 2,
#  '이제선': 2,
#  '버피': 2,
#  '확실하다': 2,
#  '반응': 2,
#  '영어': 2,
#  '뭐내': 2,
#  '서로': 2,
#  '검색': 2,
#  '제기': 2,
#  '올해': 2,
#  '새롭다': 2,
#  '이성': 2,
#  '려고': 2,
#  '다예': 2,
#  '조건': 2,
#  '가중': 2,
#  '가면': 2,
#  '금리': 2,
#  '수이': 2,
#  '분산': 2,
#  '도제': 2,
#  '타자': 2,
#  '목표': 2,
#  '덥다': 2,
#  '퍼센트': 2,
#  '가주': 2,
#  '전혀': 2,
#  '고려': 2,
#  '안타깝다': 2,
#  '패가': 2,
#  '아주': 2,
#  '리가': 2,
#  '팔고': 2,
#  '복잡하다': 2,
#  '좀뭐': 2,
#  '근거': 2,
#  '대한': 2,
#  '수도': 2,
#  '제어': 2,
#  '환경': 2,
#  '바퀴': 2,
#  '요가': 2,
#  '도안': 2,
#  '이구': 2,
#  '산다': 2,
#  '이제정': 2,
#  '은결': 2,
#  '경향': 2,
#  '참신': 2,
#  '기한': 2,
#  '매력': 2,
#  '왜냐면': 2,
#  '능력': 2,
#  '자꾸': 2,
#  '대상': 2,
#  '매매': 2,
#  '상한': 2,
#  '사업가': 2,
#  '얘': 2,
#  '종종': 2,
#  '가가': 2,
#  '배정': 2,
#  '종류': 2,
#  '고아': 2,
#  '몇개': 2,
#  '판다': 2,
#  '웬만하다': 2,
#  '정치': 2,
#  '우리나라': 2,
#  '비중': 2,
#  '라면': 2,
#  '기회': 2,
#  '배짱': 2,
#  '사전': 2,
#  '신기하다': 2,
#  '만사': 2,
#  '분석': 2,
#  '제남': 2,
#  '교정': 2,
#  '대충': 2,
#  '이슈': 2,
#  '요런': 2,
#  '그대': 2,
#  '독점': 2,
#  '가능성': 2,
#  '정책': 2,
#  '정작': 2,
#  '실패': 2,
#  '의원': 2,
#  '남탓': 2,
#  '과거': 2,
#  '기도': 2,
#  '길': 2,
#  '발전': 2,
#  '도보': 2,
#  '당하다': 2,
#  '추천': 2,
#  '대단하다': 2,
#  '아빠': 2,
#  '크게': 2,
#  '작가': 2,
#  '서하': 2,
#  '트리': 2,
#  '대안': 2,
#  '어요': 2,
#  '대가': 2,
#  '예측': 2,
#  '항상': 2,
#  '안전': 2,
#  '세대': 2,
#  '사이클': 2,
#  '교훈': 2,
#  '매수': 2,
#  '일단': 2,
#  '보기': 2,
#  '고요': 2,
#  '실물': 2,
#  '지고': 2,
#  '면대': 2,
#  '믿음': 2,
#  '최대': 2,
#  '가우리': 2,
#  '나야': 2,
#  '수가': 2,
#  '제다': 2,
#  '세계': 2,
#  '개념': 2,
#  '미국': 2,
#  '고마': 2,
#  '의견': 2,
#  '안내': 2,
#  '펀드매니저': 2,
#  '영향': 2,
#  '특징': 2,
#  '돈버': 2,
#  '산시': 2,
#  '역설': 2,
#  '물리학': 2,
#  '약간': 2,
#  '트랙': 2,
#  '대체로': 2,
#  '확률': 2,
#  '살때': 2,
#  '사기': 2,
#  '불안하다': 2,
#  '그': 2,
#  '헤드': 2,
#  '가죽': 2,
#  '소위': 2,
#  '정도': 2,
#  '모자': 2,
#  '낙관': 2,
#  '수영': 2,
#  '한번': 2,
#  '번': 2,
#  '부자': 2,
#  '는': 2,
#  '사냥': 2,
#  '취미': 2,
#  '농사': 2,
#  '끝': 2,
#  '버핏': 2,
#  '그때': 2,
#  '마지막': 2,
#  '제': 2,
#  '거래소': 2,
#  '분필': 2,
#  '여기': 2,
#  '쾌감': 2,
#  '아드레날린': 2,
#  '분비': 2,
#  '요': 2,
#  '하우스': 2,
#  '정리': 2,
#  '다음': 2,
#  '취약점': 2,
#  '테스': 1,
#  '반갑다': 1,
#  '불타다': 1,
#  '마켓': 1,
#  '라서': 1,
#  '역시': 1,
#  '조범': 1,
#  '서울': 1,
#  '가족': 1,
#  '왜음': 1,
#  '야전': 1,
#  '전이': 1,
#  '제공': 1,
#  '딜도': 1,
#  '저촉': 1,
#  '뭐요': 1,
#  '아지': 1,
#  '금고': 1,
#  '은비': 1,
#  '달초': 1,
#  '은총': 1,
#  '공군': 1,
#  '유천': 1,
#  '관사': 1,
#  '밥앞': 1,
#  '류큐': 1,
#  '표기': 1,
#  '장교': 1,
#  '숙소': 1,
#  '비어': 1,
#  '독신자': 1,
#  '에바': 1,
#  '텔러': 1,
#  '에어': 1,
#  '로뭐': 1,
#  '도대체': 1,
#  '리세': 1,
#  '글자': 1,
#  '노브': 1,
#  '여사하다': 1,
#  '우체국': 1,
#  '이발': 1,
#  '발병': 1,
#  '등단': 1,
#  '기적': 1,
#  '고용': 1,
#  '알투': 1,
#  '비르': 1,
#  '제라': 1,
#  '운영': 1,
#  '병장': 1,
#  '재고': 1,
#  '인드라': 1,
#  '열매': 1,
#  '굉': 1,
#  '장하다': 1,
#  '치아': 1,
#  '계획': 1,
#  '자드': 1,
#  '나이': 1,
#  '둘째': 1,
#  '도의': 1,
#  '차례': 1,
#  '실전': 1,
#  '컨셉': 1,
#  '교문': 1,
#  '마음가짐': 1,
#  '쉔': 1,
#  '이설': 1,
#  '현재': 1,
#  '겸재': 1,
#  '따뜻하다': 1,
#  '부동산': 1,
#  '상모': 1,
#  '가안': 1,
#  '가불': 1,
#  '가의': 1,
#  '다언': 1,
#  '매치': 1,
#  '낙천': 1,
#  '좀입': 1,
#  '자아': 1,
#  '름': 1,
#  '시점': 1,
#  '약도': 1,
#  '플러스': 1,
#  '끝일': 1,
#  '악하다': 1,
#  '불구': 1,
#  '전세': 1,
#  '요청': 1,
#  '일어': 1,
#  '시절': 1,
#  '조그맣다': 1,
#  '때너': 1,
#  '검호': 1,
#  '시아버지': 1,
#  '시부모': 1,
#  '불모': 1,
#  '사항': 1,
#  '부단': 1,
#  '만전': 1,
#  '바다': 1,
#  '전염병': 1,
#  '글러브': 1,
#  '핑크': 1,
#  '사대부': 1,
#  '좀꼰': 1,
#  '대적': 1,
#  '마인드': 1,
#  '힌트': 1,
#  '최종철': 1,
#  '가데나': 1,
#  '재밌다': 1,
#  '용이': 1,
#  '똑같다': 1,
#  '요일': 1,
#  '로거': 1,
#  '전소': 1,
#  '독창': 1,
#  '처절': 1,
#  '문득': 1,
#  '선교': 1,
#  '다말': 1,
#  '얼른': 1,
#  '메모': 1,
#  '추가': 1,
#  '스럽다': 1,
#  '번트': 1,
#  '때달핵': 1,
#  '에르': 1,
#  '영혼': 1,
#  '무리': 1,
#  '거요': 1,
#  '정신': 1,
#  '정식': 1,
#  '치면': 1,
#  '정웅': 1,
#  '비율': 1,
#  '규정': 1,
#  '헌병': 1,
#  '정운': 1,
#  '완화': 1,
#  '리전': 1,
#  '연령': 1,
#  '당신': 1,
#  '전투기': 1,
#  '타고': 1,
#  '적응': 1,
#  '한일': 1,
#  '해진': 1,
#  '다중': 1,
#  '듣기': 1,
#  '육군': 1,
#  '포병': 1,
#  '국가': 1,
#  '양': 1,
#  '요제': 1,
#  '유일하다': 1,
#  '항목': 1,
#  '말로': 1,
#  '수인': 1,
#  '기특하다': 1,
#  '까운': 1,
#  '오죽하다': 1,
#  '사촌': 1,
#  '을사': 1,
#  '면배': 1,
#  '격언': 1,
#  '제만': 1,
#  '이용': 1,
#  '공감': 1,
#  '속담': 1,
#  '한국인': 1,
#  '심하다': 1,
#  '편이': 1,
#  '씨앗': 1,
#  '유전자': 1,
#  '사면': 1,
#  '보수': 1,
#  '불로소득': 1,
#  '로또': 1,
#  '당첨': 1,
#  '예주': 1,
#  '아파트': 1,
#  '현대': 1,
#  '유발': 1,
#  '도참': 1,
#  '짜증나다': 1,
#  '불안': 1,
#  '좀비': 1,
#  '우수하다': 1,
#  '글씨': 1,
#  '신나다': 1,
#  '네온': 1,
#  '방향': 1,
#  '어그': 1,
#  '위기': 1,
#  '시리즈': 1,
#  '여름': 1,
#  '고생': 1,
#  '해자': 1,
#  '학교': 1,
#  '출신': 1,
#  '고못': 1,
#  '데즉': 1,
#  '노두': 1,
#  '모마': 1,
#  '회소': 1,
#  '볼흠왜': 1,
#  '할부': 1,
#  '위로': 1,
#  '정배': 1,
#  '누라': 1,
#  '저주': 1,
#  '어머': 1,
#  '상표': 1,
#  '목사': 1,
#  '솔직하다': 1,
#  '부하': 1,
#  '장모님': 1,
#  '사위': 1,
#  '초반': 1,
#  '학부형': 1,
#  '교사': 1,
#  '고학': 1,
#  '부용': 1,
#  '합병': 1,
#  '사이': 1,
#  '애매하다': 1,
#  '엄마': 1,
#  '통해': 1,
#  '데뷔전': 1,
#  '제자': 1,
#  '아대': 1,
#  '출발점': 1,
#  '노래': 1,
#  '소파': 1,
#  '예해': 1,
#  '야합': 1,
#  '제보': 1,
#  '은주': 1,
#  '모주': 1,
#  '다대': 1,
#  '표적': 1,
#  '만만하다': 1,
#  '전문가': 1,
#  '고솔': 1,
#  '직하다': 1,
#  '가노': 1,
#  '오니': 1,
#  '가못': 1,
#  '덜하다': 1,
#  '접근': 1,
#  '거치': 1,
#  '보지': 1,
#  '출발': 1,
#  '지그': 1,
#  '이후': 1,
#  '부류': 1,
#  '뭐제': 1,
#  '화제': 1,
#  '깝습': 1,
#  '의미': 1,
#  '오른': 1,
#  '더위': 1,
#  '험하다': 1,
#  '좀점증': 1,
#  '서나': 1,
#  '동주': 1,
#  '리좀': 1,
#  '부러': 1,
#  '도버': 1,
#  '시기심': 1,
#  '이보': 1,
#  '순': 1,
#  '비슷하다': 1,
#  '통상': 1,
#  '주로': 1,
#  '또뭐': 1,
#  '기웃': 1,
#  '찬찬하다': 1,
#  '다솔': 1,
#  '을제': 1,
#  '뭐책몇곳': 1,
#  '심은하': 1,
#  '의몫': 1,
#  '여경': 1,
#  '명확하다': 1,
#  '인생': 1,
#  '이올린': 1,
#  '실적': 1,
#  '민감하다': 1,
#  '단단하다': 1,
#  '분리': 1,
#  '오롯': 1,
#  '악의': 1,
#  '마고': 1,
#  '잘나다': 1,
#  '명문': 1,
#  '바지': 1,
#  '파이프': 1,
#  '비롯': 1,
#  '듯좀': 1,
#  '영적': 1,
#  '이만': 1,
#  '고오': 1,
#  '신생활': 1,
#  '여자': 1,
#  '썸씽': 1,
#  '이의': 1,
#  '아라하': 1,
#  '시트': 1,
#  '이일': 1,
#  '환영': 1,
#  '자판': 1,
#  '오디': 1,
#  '나라': 1,
#  '아앙': 1,
#  '파랑색': 1,
#  '나이트': 1,
#  '라이거': 1,
#  '번은': 1,
#  '억지로': 1,
#  '제거': 1,
#  '필요': 1,
#  '비해': 1,
#  '머릿속': 1,
#  '대감': 1,
#  '상상': 1,
#  '기기': 1,
#  '기껏': 1,
#  '마이클': 1,
#  '조던': 1,
#  '시대': 1,
#  '단말': 1,
#  '중령': 1,
#  '중력': 1,
#  '밉다': 1,
#  '본적': 1,
#  '벤치마크': 1,
#  '로마니': 1,
#  '모건': 1,
#  '일대': 1,
#  '기면': 1,
#  '요것': 1,
#  '춤철': 1,
#  '파격': 1,
#  '우려': 1,
#  '돼지': 1,
#  '부산하다': 1,
#  '섀도우': 1,
#  '헌터': 1,
#  '신용': 1,
#  '극단': 1,
#  '합력': 1,
#  '옳다': 1,
#  '합리': 1,
#  '인기': 1,
#  '땐좀': 1,
#  '건좀': 1,
#  '탐험': 1,
#  '흔하다': 1,
#  '다지': 1,
#  '금답': 1,
#  '못골': 1,
#  '막상': 1,
#  '된거': 1,
#  '안텍': 1,
#  '전력': 1,
#  '최초': 1,
#  '어원': 1,
#  '이안': 1,
#  '라가': 1,
#  '예심': 1,
#  '때뭘': 1,
#  '나타': 1,
#  '요한': 1,
#  '후루': 1,
#  '의하다': 1,
#  '이익': 1,
#  '택시': 1,
#  '만원': 1,
#  '나중': 1,
#  '정답': 1,
#  '보유': 1,
#  '연일': 1,
#  '예더': 1,
#  '가든': 1,
#  '는고': 1,
#  '스톱': 1,
#  '서고': 1,
#  '휴대': 1,
#  '키스': 1,
#  '고모': 1,
#  '걸좀': 1,
#  '펀더': 1,
#  '멘털': 1,
#  '기준': 1,
#  '카페': 1,
#  '내폐': 1,
#  '종합': 1,
#  '음고': 1,
#  '말거': 1,
#  '건데': 1,
#  '탭': 1,
#  '대당': 1,
#  '시멘트': 1,
#  '제해': 1,
#  '고온': 1,
#  '배시': 1,
#  '좌측': 1,
#  '전하': 1,
#  '쌀거': 1,
#  '심각하다': 1,
#  '질병': 1,
#  '금은': 1,
#  '라든지': 1,
#  '간의': 1,
#  '가치': 1,
#  '메일': 1,
#  '디마': 1,
#  '축가': 1,
#  '저걸': 1,
#  '하나로': 1,
#  '최소한': 1,
#  '자의': 1,
#  '일수': 1,
#  '수급': 1,
#  '작다': 1,
#  '올바르다': 1,
#  '로트': 1,
#  '장치': 1,
#  '듭': 1,
#  '관심': 1,
#  '뉴스': 1,
#  '모니터': 1,
#  '포인트': 1,
#  '여태': 1,
#  '자제': 1,
#  '해당': 1,
#  '막연': 1,
#  '기대하다': 1,
#  '외신': 1,
#  '지금동': 1,
#  '스펠': 1,
#  '고루': 1,
#  '외치': 1,
#  '부양': 1,
#  '점수': 1,
#  '벌때': 1,
#  '위용': 1,
#  '장혁': 1,
#  '막싹': 1,
#  '장상': 1,
#  '관계도': 1,
#  '막또죽': 1,
#  '괴담': 1,
#  '쑥쫄': 1,
#  '태아': 1,
#  '가야': 1,
#  '또예': 1,
#  '부리': 1,
#  '마찬가지': 1,
#  '이러하다': 1,
#  '리턴': 1,
#  '디스크': 1,
#  '덤프': 1,
#  '트럭': 1,
#  '다리': 1,
#  '하노': 1,
#  '리지': 1,
#  '터닝건데': 1,
#  '너머': 1,
#  '보이': 1,
#  '가점': 1,
#  '문제점': 1,
#  '고합': 1,
#  '길이': 1,
#  '계림': 1,
#  '거가': 1,
#  '착실하다': 1,
#  '내지': 1,
#  '지름길': 1,
#  '좀남': 1,
#  '단순하다': 1,
#  '화학': 1,
#  '오신': 1,
#  '편안하다': 1,
#  '언론': 1,
#  '곳': 1,
#  '패스': 1,
#  '전화하다': 1,
#  '결코': 1,
#  '잠깐': 1,
#  '펌프': 1,
#  '미련': 1,
#  '고막': 1,
#  '도속': 1,
#  '등식': 1,
#  '싸움': 1,
#  '관성': 1,
#  '법칙': 1,
#  '거폭': 1,
#  '넓다': 1,
#  '피어': 1,
#  '재기': 1,
#  '재료': 1,
#  '상가': 1,
#  '아침': 1,
#  '뭐너': 1,
#  '기어': 1,
#  '수주': 1,
#  '회계': 1,
#  '편하다': 1,
#  '자고': 1,
#  '수유': 1,
#  '제상': 1,
#  ...}

# %%
words_df = pd.DataFrame.from_dict([words]).T.reset_index()
words_df.columns = ['words', 'freq']

# %%
words_df
# Out:
#      words  freq
# 0       사람    57
# 1       주식    49
# 2       생각    39
# 3      그렇다    38
# 4       좋다    32
# ...    ...   ...
# 1764    운용     1
# 1765     해     1
# 1766    최준     1
# 1767   고맙다     1
# 1768   뭐삼덕     1
#
# [1769 rows x 2 columns]

# %%
words_df.to_csv('sample_wc.csv', header=True, index=False, encoding = 'utf-8-sig')

# %% [markdown]
# ### 날짜별 버전

# %%
# lg chemical [날짜] before

# lgc_210908_bf = dataSet[dataSet['date_d'] == '2021-09-08']
# lgc_210908_bf
# Out:
#    st_n  st_cd          ch_nm        date  \
# 0  LG화학  51910  삼프로TV_경제의신과함께  2021090800
# 1  LG화학  51910  삼프로TV_경제의신과함께  2021090800
# 2  LG화학  51910  삼프로TV_경제의신과함께  2021090800
# 3  LG화학  51910  삼프로TV_경제의신과함께  2021090800
# 4  LG화학  51910  삼프로TV_경제의신과함께  2021090800
# 5  LG화학  51910  삼프로TV_경제의신과함께  2021090800
# 6  LG화학  51910  삼프로TV_경제의신과함께  2021090800
# 7  LG화학  51910  삼프로TV_경제의신과함께  2021090800
#
#                                                title  \
# 0  [증시 염탐정] 약보합으로 출발한 시장.. 대형주의 방향은? f.이베스트투자증권 염...
# 1                  [뉴스3] "美증시 비중축소"…잇단 비관론에 다우 270p↓
# 2  [글로벌마켓 브리핑] 스가 총리 퇴진 발표 이후, 일본 증시 상승 랠리! f. 미래...
# 3  [증시 셔터맨] 외인과 기관은 왜 삼성전자와 카카오뱅크를 매도할까? f. 한국투자증...
# 4  [증시 셔터맨] 외인과 기관은 왜 삼성전자와 카카오뱅크를 매도할까? f. 한국투자증...
# 5  [글로벌마켓 브리핑] 스가 총리 퇴진 발표 이후, 일본 증시 상승 랠리! f. 미래...
# 6  [증시 염탐정] 약보합으로 출발한 시장.. 대형주의 방향은? f.이베스트투자증권 염...
# 7                  [뉴스3] "美증시 비중축소"…잇단 비관론에 다우 270p↓
#
#                                                 text   views  length  \
# 0  자 그러면 오늘 또 증시 개장 상 1정리 해 주시아 염수 아니라 니모 지겠습니다 어...  100475    1813
# 1  자 오늘 9월 8일 수요일 순서와먼저 뉴스 3부터 내 무게 좀 정리를해 드릴 텐데 ...   15483    1348
# 2  여러분 안녕하세요 광고 보고 왔습니다오늘 힘차게 한번 시작해 보도록하겠습니다 언제나...    7231    1711
# 3  4 아 오늘한국투자증권 에서 오셨죠 우리박지영 차장을 모시겠습니다 어서오십시오 네 ...   21472    1511
# 4  4 아 오늘한국투자증권 에서 오셨죠 우리박지영 차장을 모시겠습니다 어서오십시오 네 ...   21472    1511
# 5  여러분 안녕하세요 광고 보고 왔습니다오늘 힘차게 한번 시작해 보도록하겠습니다 언제나...    7231    1711
# 6  자 그러면 오늘 또 증시 개장 상 1정리 해 주시아 염수 아니라 니모 지겠습니다 어...  100475    1813
# 7  자 오늘 9월 8일 수요일 순서와먼저 뉴스 3부터 내 무게 좀 정리를해 드릴 텐데 ...   15483    1348
#
#       date_d date_h  ud
# 0 2021-09-08     00  -1
# 1 2021-09-08     00  -1
# 2 2021-09-08     00  -1
# 3 2021-09-08     00  -1
# 4 2021-09-08     00  -1
# 5 2021-09-08     00  -1
# 6 2021-09-08     00  -1
# 7 2021-09-08     00  -1

# %%
## test

print(lgc_210908['Contents_input'][2][:20])

for i in range(len(lgc_210908['Contents_input'])):
    
    media = ['오늘', '년도', '이제', '요즘', '지금', '우리나라', '한번', '사실', '처럼', \
             '증시', '개장', '얘기', '이렇다', '참고', '없다', '때문', '아니다', \
             '안녕하십니까', '안녕하세요우', '안녕하다', '어서', '오십', '시오', '모습', '내용', '정도', \
             '그렇다', '어쨌든', '어떻다', '박지영', '미래에셋', '어머님', '음악']

    for word in lgc_210908['Contents_input'][i]:
#             if word in stopwords:
#                 lgc_210908['Contents_input'][i].remove(word)
        if word in media:
            lgc_210908['Contents_input'][i].remove(word)
                
print(lgc_210908['Contents_input'][2][:20])
# Out:
# ['광고', '힘차다', '시작', '증권', '의장', '선임', '전이', '매년', '안녕하세요우', '난수', '간이', '럼또뭡', '사과', '감히', '방소', '점점', '덥다', '고합', '다정', '말로']
# ['광고', '힘차다', '시작', '증권', '의장', '선임', '전이', '매년', '난수', '간이', '럼또뭡', '사과', '감히', '방소', '점점', '덥다', '고합', '다정', '말로', '사과']

# %%
# %%time

lgc_210908 = youtube_pre(lgc_210908_bf)
# Out:
# 데이터 셋 구성 완료
# okt 모듈 활성
# 태그 삭제 및 품사 태깅 완료
# 명사, 형용사 추출
# 불용어 사전 로딩..
# 불용어 처리 완료
# 단어 길이 1이하인 단어 제거
# Wall time: 2min 31s

# %%
print(lgc_210908['Contents_input'][2][:20])
# Out:
# ['광고', '힘차다', '시작', '미래에셋', '증권', '의장', '선임', '전이', '매년', '안녕하다', '안녕하세요우', '난수', '간이', '럼또뭡', '사과', '감히', '방소', '점점', '덥다', '고합']

# %%
lgc_210908.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-90422d2960cb> in <module>
# ----> 1 lgc_210908.head()
#
# NameError: name 'lgc_210908' is not defined

# %%
lgc_210908.Contents_input
# Out:
# 0    [정리, 염수, 니모, 오십, 네마, 하든, 일로, 모습, 모집, 노래, 아이오와,...
# 1    [무게, 정리, 미국, 소식, 주너, 미국, 시장, 음소, 간밤, 진행, 좋다, 아...
# 2    [안녕하다, 광고, 힘차다, 시작, 처럼, 증권, 의장, 선임, 전이, 매년, 안녕...
# 3    [한국, 투자, 증권, 박지영, 차장, 시오, 안녕하십니까, 한국, 투자, 증권, ...
# 4    [한국, 투자, 증권, 박지영, 차장, 시오, 안녕하십니까, 한국, 투자, 증권, ...
# 5    [안녕하다, 광고, 힘차다, 시작, 처럼, 증권, 의장, 선임, 전이, 매년, 안녕...
# 6    [정리, 염수, 니모, 오십, 네마, 하든, 일로, 모습, 모집, 노래, 아이오와,...
# 7    [무게, 정리, 미국, 소식, 주너, 미국, 시장, 음소, 간밤, 진행, 좋다, 아...
# Name: Contents_input, dtype: object

# %%
lgc_210908.Contents_input[0]
# Out:
# ['정리',
#  '염수',
#  '니모',
#  '오십',
#  '네마',
#  '하든',
#  '일로',
#  '모습',
#  '모집',
#  '노래',
#  '아이오와',
#  '따갑다',
#  '달라',
#  '위험부담',
#  '예맥',
#  '강하다',
#  '요청',
#  '김택진',
#  '진영',
#  '머신',
#  '매트',
#  '개장',
#  '상황',
#  '은행',
#  '관심',
#  '좋다',
#  '금융',
#  '재정',
#  '옥애널',
#  '리스트',
#  '은행',
#  '업종',
#  '간격',
#  '보고',
#  '간단',
#  '월동',
#  '외국인',
#  '매도',
#  '계속',
#  '코스피',
#  '은행',
#  '수급',
#  '무료',
#  '좋다',
#  '목요일',
#  '그다음',
#  '긴축',
#  '속도',
#  '경기',
#  '확장',
#  '북면',
#  '연장',
#  '가능성',
#  '다시',
#  '경기',
#  '금리',
#  '베팅',
#  '실적',
#  '상황',
#  '서주',
#  '당대',
#  '금도',
#  '가능성',
#  '투자',
#  '수요',
#  '증가',
#  '가능성',
#  '고합',
#  '다그',
#  '래서',
#  '변경',
#  '은행',
#  '전체',
#  '순위',
#  '좋다',
#  '작년',
#  '대비',
#  '가내',
#  '순위',
#  '증가',
#  '예상',
#  '그다음',
#  '올해',
#  '예상',
#  '배당',
#  '수익률',
#  '투자',
#  '행주',
#  '연말',
#  '은행',
#  '대해',
#  '관심',
#  '좀뭐',
#  '리스크',
#  '만화',
#  '접근',
#  '요좀',
#  '해주시',
#  '좋다',
#  '그다음',
#  '증권',
#  '재운',
#  '이분',
#  '굉장하다',
#  '피트',
#  '코인',
#  '보고서',
#  '비트코인',
#  '가기',
#  '급락',
#  '최근',
#  '설번',
#  '거기',
#  '법정',
#  '놈',
#  '개널',
#  '비트코인',
#  '법정',
#  '통화',
#  '채택',
#  '예고',
#  '살바도르',
#  '달러',
#  '버팔로',
#  '서치',
#  '인정',
#  '시작',
#  '제품',
#  '구매',
#  '세금',
#  '납부',
#  '비트코인',
#  '자국',
#  '국민',
#  '혼란',
#  '위해',
#  '비트코인',
#  '달러',
#  '변환',
#  '위해',
#  '별로',
#  '기금',
#  '조성',
#  '국민',
#  '피트',
#  '코인',
#  '직업',
#  '인치',
#  '보라',
#  '비트코인',
#  '비트',
#  '가게',
#  '가능',
#  '자기',
#  '본인',
#  '매물',
#  '앞',
#  '급락',
#  '예술',
#  '매물',
#  '기점',
#  '회사',
#  '도로',
#  '정부',
#  '제이',
#  '법정',
#  '통화',
#  '인하다',
#  '인정',
#  '이제우',
#  '리가',
#  '무녀',
#  '계발',
#  '그것',
#  '가지',
#  '수수료',
#  '문제',
#  '좋다',
#  '은비',
#  '수수료',
#  '경제',
#  '국민소득',
#  '높다',
#  '살바',
#  '도로',
#  '국민',
#  '입장',
#  '부담',
#  '수수료',
#  '자체',
#  '자체',
#  '제거',
#  '수로',
#  '좀비',
#  '고합',
#  '대안',
#  '대디',
#  '데온',
#  '라이트',
#  '행',
#  '네트워크',
#  '비트코인',
#  '경우',
#  '거래',
#  '속도',
#  '느리다',
#  '속도',
#  '높다',
#  '전정',
#  '수수료',
#  '좋다',
#  '해결',
#  '솔루션',
#  '라이트닝',
#  '네트워크',
#  '걸이',
#  '보통',
#  '비트',
#  '그림',
#  '경우',
#  '블록',
#  '체인',
#  '네모',
#  '장하다',
#  '오프라인',
#  '별도',
#  '기록',
#  '을해',
#  '방식',
#  '요게',
#  '확장',
#  '문제',
#  '거래',
#  '수수료',
#  '게이',
#  '기술',
#  '엘살바도르',
#  '거래',
#  '거래',
#  '수로',
#  '확장',
#  '요런',
#  '온것',
#  '빨',
#  '리좀',
#  '확산',
#  '부분',
#  '라이트닝',
#  '네트워크',
#  '솔루션',
#  '채택',
#  '따라서',
#  '알라',
#  '생각',
#  '좋다',
#  '알바',
#  '장먼',
#  '비트코인',
#  '채택',
#  '제물',
#  '가가',
#  '수수료',
#  '라이트닝',
#  '네트웍',
#  '꼬이다',
#  '해결',
#  '쌀바',
#  '도로',
#  '비트코인',
#  '흐름',
#  '흥미롭다',
#  '보고서',
#  '참고',
#  '해주시',
#  '좋다',
#  '나예',
#  '제한',
#  '공개',
#  '미국',
#  '경제',
#  '평가',
#  '저녁',
#  '체크',
#  '신안',
#  '증권',
#  '최대',
#  '가무',
#  '삼성',
#  '워낙',
#  '주주',
#  '많다',
#  '답답하다',
#  '긍정',
#  '보고서',
#  '삼성',
#  '자크',
#  '넓다',
#  '좀볼때',
#  '단기',
#  '메모리',
#  '업황',
#  '우려',
#  '무좀',
#  '시선',
#  '집중',
#  '나쁘다',
#  '필요없다',
#  '메모리',
#  '여파',
#  '우려',
#  '수요',
#  '감소',
#  '코렐',
#  '그로',
#  '공급망',
#  '판단',
#  '최근',
#  '말레이시아',
#  '확',
#  '진자',
#  '모습',
#  '실제',
#  '예고',
#  '모습',
#  '긍정',
#  '고협',
#  '현물',
#  '가격',
#  '하락',
#  '세도',
#  '완만',
#  '시작',
#  '메모리',
#  '업황',
#  '프라',
#  '실성',
#  '가능성',
#  '현저',
#  '두번째',
#  '폴더',
#  '확산',
#  '효과',
#  '좋다',
#  '풀돌픈',
#  '자체',
#  '부분',
#  '라이',
#  '부품',
#  '당연하다',
#  '좋다',
#  '거기',
#  '반도체',
#  '거기',
#  '메모리',
#  '라비',
#  '메모리',
#  '폴더',
#  '불편',
#  '실적',
#  '영향',
#  '크게',
#  '좋다',
#  '모멘텀',
#  '긍정',
#  '전망',
#  '동기',
#  '영업',
#  '좋다',
#  '증가',
#  '전망',
#  '메모리',
#  '단기',
#  '옆방',
#  '우려',
#  '당부',
#  '반영',
#  '단기',
#  '하락',
#  '만회',
#  '주가',
#  '반등',
#  '오지',
#  '뭐애널',
#  '리스트',
#  '보고서',
#  '계획',
#  '참고',
#  '해주시',
#  '좋다',
#  '제의',
#  '장',
#  '상황',
#  '먼저',
#  '느낌',
#  '약골',
#  '벌좀',
#  '네이버',
#  '카카오',
#  '형성',
#  '통해',
#  '면',
#  '급하다',
#  '중계',
#  '한국',
#  '모델',
#  '비상',
#  '기업',
#  '회사',
#  '말뭐',
#  '비교',
#  '해갈',
#  '유리',
#  '의사',
#  '요점',
#  '게또',
#  '일종',
#  '의약',
#  '규제',
#  '신호탄',
#  '무리',
#  '느낌',
#  '어쩌',
#  '주가',
#  '굉장하다',
#  '평가',
#  '기억',
#  '부담',
#  '미국',
#  '테크',
#  '대부분',
#  '이슈',
#  '네이버',
#  '카카오',
#  '출발',
#  '오빠',
#  '웨이브',
#  '양사',
#  '네이버',
#  '카카오',
#  '하락',
#  '세로',
#  '출발',
#  '뿐',
#  '지수',
#  '미국',
#  '다우지수',
#  '영향',
#  '일부',
#  '한국',
#  '네이버',
#  '카코',
#  '영향',
#  '삼성',
#  '변동',
#  '그냥',
#  '보합',
#  '하이닉스',
#  '하락',
#  '네이버',
#  '카카오',
#  '반등',
#  '그래프',
#  '최근',
#  '물량',
#  '부담',
#  '우려',
#  '그이',
#  '배웅',
#  '프터',
#  '반등',
#  '엔씨소프트',
#  '어제',
#  '사주',
#  '매입',
#  '공식',
#  '반등',
#  '대부분',
#  '기업',
#  '약세',
#  '출발',
#  '기업',
#  '아깝다',
#  '신규',
#  '장기',
#  '테크놀로지',
#  '솔루션',
#  '엔씨소프트',
#  '일부',
#  '기업',
#  '반등',
#  '금호',
#  '최근',
#  '강세',
#  '계속',
#  '기억',
#  '거구',
#  '이노',
#  '건',
#  '반등',
#  '이유',
#  '애플',
#  '공개',
#  '언급',
#  '다음주',
#  '공개',
#  '관련',
#  '강세',
#  '하락',
#  '기어',
#  '네이버',
#  '카카오',
#  '가장',
#  '두산',
#  '중공업',
#  '일부',
#  '리퍼',
#  '보시',
#  '좋다',
#  '외모',
#  '정미라',
#  '동국제강',
#  '기업',
#  '어제',
#  '상승세',
#  '좋다',
#  '주중',
#  '대표',
#  '현대',
#  '로템',
#  '좀차익',
#  '매물',
#  '약세',
#  '단오',
#  '전정',
#  '코스닥',
#  '대구',
#  '기업',
#  '부진하다',
#  '상태',
#  '어제',
#  '소재',
#  '제도',
#  '강하다',
#  '좋다',
#  '추가',
#  '상승',
#  '실리콘',
#  '국제',
#  '기업인',
#  '그대',
#  '주전자',
#  '재료',
#  '추가',
#  '로더',
#  '상승',
#  '이제반',
#  '기업',
#  '머티리얼즈',
#  '테스',
#  '반도체',
#  '보장',
#  '기업',
#  '주가',
#  '가약',
#  '날좀',
#  '힘들다',
#  '안정',
#  '빨르다',
#  '아프리카',
#  '식탁',
#  '아마',
#  '요음',
#  '어그',
#  '가지',
#  '거기',
#  '발밑',
#  '염색',
#  '알루미늄',
#  '전기차',
#  '주간동아',
#  '배고프다',
#  '문구',
#  '현재',
#  '약간',
#  '대용',
#  '기업',
#  '주가',
#  '부진',
#  '인하다',
#  '코스피',
#  '포인트',
#  '표시',
#  '덕분',
#  '소스',
#  '어제',
#  '하락',
#  '압력',
#  '조금',
#  '이다',
#  '포인트',
#  '기록',
#  '외국',
#  '오늘이',
#  '투자자',
#  '경우',
#  '어제',
#  '아침',
#  '네일',
#  '방적',
#  '매도',
#  '때문',
#  '아마',
#  '네이버',
#  '카카오',
#  '중심',
#  '외국인',
#  '좋다',
#  '어제',
#  '가장',
#  '철강',
#  '주도',
#  '고색',
#  '토로',
#  '업종',
#  '세포이',
#  '제한',
#  '번더',
#  '정리',
#  '은행',
#  '업종',
#  '파병',
#  '카카오',
#  '게임',
#  '오름',
#  '유일하다',
#  '은행',
#  '업종',
#  '금제',
#  '코스피',
#  '상승',
#  '나머지',
#  '섹터',
#  '일단',
#  '하락',
#  '아깝다',
#  '말씀',
#  '알루미늄',
#  '관련',
#  '주도',
#  '오늘',
#  '알미늄',
#  '조일',
#  '알미늄',
#  '이상',
#  '간등',
#  '오늘',
#  '장비',
#  '회사',
#  '강하다',
#  '소재',
#  '장비',
#  '기업',
#  '일단',
#  '반등',
#  '오늘',
#  '보시',
#  '나머지',
#  '섹터',
#  '하락',
#  '인터넷',
#  '대표',
#  '백화점',
#  '비트코인',
#  '가게',
#  '급락',
#  '나무',
#  '관련',
#  '비트코인',
#  '관련',
#  '오늘',
#  '하락',
#  '압력',
#  '로좀',
#  '한국',
#  '대표',
#  '성장',
#  '기업',
#  '이몸',
#  '어스',
#  '관련',
#  '우주',
#  '항공',
#  '대부분',
#  '낙폭',
#  '국정',
#  '아주',
#  '소수',
#  '부분',
#  '일단',
#  '밀리',
#  '생각',
#  '해주시',
#  '좋다',
#  '무인기',
#  '시기',
#  '머',
#  '굉장하다',
#  '음개',
#  '매수',
#  '난',
#  '행보',
#  '굉장하다',
#  '오르락내리락',
#  '투자',
#  '투자자',
#  '판단',
#  '이심',
#  '조심',
#  '전체',
#  '라이트',
#  '하락',
#  '종목',
#  '많다',
#  '보이',
#  '코스피',
#  '사이',
#  '호정',
#  '오늘',
#  '코스닥',
#  '좀더',
#  '안좋다',
#  '애',
#  '최근',
#  '에코',
#  '스타',
#  '리더',
#  '강하다',
#  '오늘',
#  '조금',
#  '나쁘다',
#  '작다',
#  '어어',
#  '뉴스',
#  '보톡스',
#  '덥다',
#  '말씀',
#  '신앙',
#  '금융',
#  '숙자',
#  '애널',
#  '리스트',
#  '보고서',
#  '신흥',
#  '증시',
#  '희망',
#  '계속',
#  '미국증시',
#  '좋다',
#  '계속',
#  '신흥',
#  '국부',
#  '진하다',
#  '원인',
#  '여러가지',
#  '신흥',
#  '약세',
#  '모텔',
#  '타변',
#  '확산',
#  '중국',
#  '불확실',
#  '원자재',
#  '가격',
#  '조정',
#  '테이퍼링',
#  '우려',
#  '인플레이션',
#  '금리',
#  '인상',
#  '이모',
#  '복합',
#  '작용',
#  '신흥',
#  '안좋다',
#  '은부',
#  '접종',
#  '구비',
#  '정도',
#  '한국',
#  '정부',
#  '총',
#  '집단민원',
#  '코로',
#  '나발',
#  '플러스',
#  '해소',
#  '일단',
#  '보고',
#  '그다음',
#  '경기',
#  '모멘텀',
#  '훼손',
#  '최근',
#  '약간',
#  '경감',
#  '어제',
#  '발표',
#  '중국',
#  '수출',
#  '부분',
#  '약간',
#  '경감',
#  '된거',
#  '미국',
#  '중심',
#  '재정정책',
#  '높다',
#  '때문',
#  '경기',
#  '민감',
#  '주신',
#  '증시',
#  '상대',
#  '국가',
#  '차별',
#  '주목',
#  '을해',
#  '일단',
#  '대만',
#  '마찬가지',
#  '하반기',
#  '이익',
#  '의상대',
#  '의하다',
#  '한국',
#  '과대',
#  '나라',
#  '고단',
#  '우위',
#  '고합',
#  '다그',
#  '래서',
#  '부분',
#  '상대',
#  '매력',
#  '부분',
#  '신흥',
#  '한국',
#  '중국',
#  '좀비',
#  '간단하다',
#  '자위',
#  '번하다',
#  '자세하다',
#  '홈페이지',
#  '보시',
#  '일단',
#  '좋다',
#  '신흥',
#  '증시',
#  '해방',
#  '약속',
#  '위원회',
#  '리포터',
#  '약간',
#  '독특하다',
#  '한국',
#  '투자',
#  '증권',
#  '김성근',
#  '애널',
#  '리스트',
#  '번영',
#  '피해',
#  '약간',
#  '자료',
#  '동문',
#  '그거',
#  '중국',
#  '동부',
#  '요일',
#  '단곡',
#  '극적',
#  '측면',
#  '보고',
#  '최근',
#  '인도',
#  '굉장하다',
#  '인도',
#  '색스',
#  '지수',
#  '포인트',
#  '용해',
#  '로사',
#  '최고',
#  '엄격하다',
#  '중점',
#  '나부',
#  '의거',
#  '핑크',
#  '굉장하다',
#  '가인',
#  '안좋다',
#  '나라',
#  '지수',
#  '장난',
#  '정말',
#  '역대',
#  '최고점',
#  '돌파',
#  '그게',
#  '델타',
#  '이뿌다',
#  '수급',
#  '수도',
#  '보',
#  '지수',
#  '추정',
#  '신흥',
#  '거기',
#  '중국',
#  '미리',
#  '중국',
#  '제외',
#  '펀드',
#  '추정',
#  '데또',
#  '대요',
#  '중국',
#  '제외',
#  '자금',
#  '유입',
#  '이유',
#  '중국',
#  '규제',
#  '리스크',
#  '이제',
#  '자금',
#  '중국',
#  '요금',
#  '중국',
#  '투자',
#  '펀드',
#  '중국',
#  '의상',
#  '부분',
#  '배분',
#  '거나',
#  '본분',
#  '펀드',
#  '태',
#  '시법',
#  '왼쪽',
#  '한국',
#  '나쁘다',
#  '안테나',
#  '왜냐면',
#  '이머징마켓',
#  '지수',
#  '한국',
#  '정도',
#  '비중',
#  '중국',
#  '제외',
#  '교육',
#  '비중',
#  '이제우',
#  '신흥',
#  '비중',
#  '펀드',
#  '이인기',
#  '국도',
#  '좀볼수',
#  '무런',
#  '종이',
#  '용인',
#  '수급',
#  '독특하다',
#  '시각',
#  '개쪽',
#  '만약',
#  '자금',
#  '우리나라',
#  '나쁘다',
#  '요인',
#  '인도네시아',
#  '도가사상',
#  '최고',
#  '팔이',
#  '국도',
#  '수해',
#  '내일',
#  '용이',
#  '제작',
#  '규모',
#  '당연하다',
#  '포항',
#  '결심',
#  '시각',
#  '참고',
#  ...]

# %%
lgc_210908_list = []

for i in lgc_210908.Contents_input:
    for j in i:
        lgc_210908_list.append(j)
    
lgc_210908_list
# Out:
# ['정리',
#  '염수',
#  '니모',
#  '오십',
#  '네마',
#  '하든',
#  '일로',
#  '모습',
#  '모집',
#  '노래',
#  '아이오와',
#  '따갑다',
#  '달라',
#  '위험부담',
#  '예맥',
#  '강하다',
#  '요청',
#  '김택진',
#  '진영',
#  '머신',
#  '매트',
#  '개장',
#  '상황',
#  '은행',
#  '관심',
#  '좋다',
#  '금융',
#  '재정',
#  '옥애널',
#  '리스트',
#  '은행',
#  '업종',
#  '간격',
#  '보고',
#  '간단',
#  '월동',
#  '외국인',
#  '매도',
#  '계속',
#  '코스피',
#  '은행',
#  '수급',
#  '무료',
#  '좋다',
#  '목요일',
#  '그다음',
#  '긴축',
#  '속도',
#  '경기',
#  '확장',
#  '북면',
#  '연장',
#  '가능성',
#  '다시',
#  '경기',
#  '금리',
#  '베팅',
#  '실적',
#  '상황',
#  '서주',
#  '당대',
#  '금도',
#  '가능성',
#  '투자',
#  '수요',
#  '증가',
#  '가능성',
#  '고합',
#  '다그',
#  '래서',
#  '변경',
#  '은행',
#  '전체',
#  '순위',
#  '좋다',
#  '작년',
#  '대비',
#  '가내',
#  '순위',
#  '증가',
#  '예상',
#  '그다음',
#  '올해',
#  '예상',
#  '배당',
#  '수익률',
#  '투자',
#  '행주',
#  '연말',
#  '은행',
#  '대해',
#  '관심',
#  '좀뭐',
#  '리스크',
#  '만화',
#  '접근',
#  '요좀',
#  '해주시',
#  '좋다',
#  '그다음',
#  '증권',
#  '재운',
#  '이분',
#  '굉장하다',
#  '피트',
#  '코인',
#  '보고서',
#  '비트코인',
#  '가기',
#  '급락',
#  '최근',
#  '설번',
#  '거기',
#  '법정',
#  '놈',
#  '개널',
#  '비트코인',
#  '법정',
#  '통화',
#  '채택',
#  '예고',
#  '살바도르',
#  '달러',
#  '버팔로',
#  '서치',
#  '인정',
#  '시작',
#  '제품',
#  '구매',
#  '세금',
#  '납부',
#  '비트코인',
#  '자국',
#  '국민',
#  '혼란',
#  '위해',
#  '비트코인',
#  '달러',
#  '변환',
#  '위해',
#  '별로',
#  '기금',
#  '조성',
#  '국민',
#  '피트',
#  '코인',
#  '직업',
#  '인치',
#  '보라',
#  '비트코인',
#  '비트',
#  '가게',
#  '가능',
#  '자기',
#  '본인',
#  '매물',
#  '앞',
#  '급락',
#  '예술',
#  '매물',
#  '기점',
#  '회사',
#  '도로',
#  '정부',
#  '제이',
#  '법정',
#  '통화',
#  '인하다',
#  '인정',
#  '이제우',
#  '리가',
#  '무녀',
#  '계발',
#  '그것',
#  '가지',
#  '수수료',
#  '문제',
#  '좋다',
#  '은비',
#  '수수료',
#  '경제',
#  '국민소득',
#  '높다',
#  '살바',
#  '도로',
#  '국민',
#  '입장',
#  '부담',
#  '수수료',
#  '자체',
#  '자체',
#  '제거',
#  '수로',
#  '좀비',
#  '고합',
#  '대안',
#  '대디',
#  '데온',
#  '라이트',
#  '행',
#  '네트워크',
#  '비트코인',
#  '경우',
#  '거래',
#  '속도',
#  '느리다',
#  '속도',
#  '높다',
#  '전정',
#  '수수료',
#  '좋다',
#  '해결',
#  '솔루션',
#  '라이트닝',
#  '네트워크',
#  '걸이',
#  '보통',
#  '비트',
#  '그림',
#  '경우',
#  '블록',
#  '체인',
#  '네모',
#  '장하다',
#  '오프라인',
#  '별도',
#  '기록',
#  '을해',
#  '방식',
#  '요게',
#  '확장',
#  '문제',
#  '거래',
#  '수수료',
#  '게이',
#  '기술',
#  '엘살바도르',
#  '거래',
#  '거래',
#  '수로',
#  '확장',
#  '요런',
#  '온것',
#  '빨',
#  '리좀',
#  '확산',
#  '부분',
#  '라이트닝',
#  '네트워크',
#  '솔루션',
#  '채택',
#  '따라서',
#  '알라',
#  '생각',
#  '좋다',
#  '알바',
#  '장먼',
#  '비트코인',
#  '채택',
#  '제물',
#  '가가',
#  '수수료',
#  '라이트닝',
#  '네트웍',
#  '꼬이다',
#  '해결',
#  '쌀바',
#  '도로',
#  '비트코인',
#  '흐름',
#  '흥미롭다',
#  '보고서',
#  '참고',
#  '해주시',
#  '좋다',
#  '나예',
#  '제한',
#  '공개',
#  '미국',
#  '경제',
#  '평가',
#  '저녁',
#  '체크',
#  '신안',
#  '증권',
#  '최대',
#  '가무',
#  '삼성',
#  '워낙',
#  '주주',
#  '많다',
#  '답답하다',
#  '긍정',
#  '보고서',
#  '삼성',
#  '자크',
#  '넓다',
#  '좀볼때',
#  '단기',
#  '메모리',
#  '업황',
#  '우려',
#  '무좀',
#  '시선',
#  '집중',
#  '나쁘다',
#  '필요없다',
#  '메모리',
#  '여파',
#  '우려',
#  '수요',
#  '감소',
#  '코렐',
#  '그로',
#  '공급망',
#  '판단',
#  '최근',
#  '말레이시아',
#  '확',
#  '진자',
#  '모습',
#  '실제',
#  '예고',
#  '모습',
#  '긍정',
#  '고협',
#  '현물',
#  '가격',
#  '하락',
#  '세도',
#  '완만',
#  '시작',
#  '메모리',
#  '업황',
#  '프라',
#  '실성',
#  '가능성',
#  '현저',
#  '두번째',
#  '폴더',
#  '확산',
#  '효과',
#  '좋다',
#  '풀돌픈',
#  '자체',
#  '부분',
#  '라이',
#  '부품',
#  '당연하다',
#  '좋다',
#  '거기',
#  '반도체',
#  '거기',
#  '메모리',
#  '라비',
#  '메모리',
#  '폴더',
#  '불편',
#  '실적',
#  '영향',
#  '크게',
#  '좋다',
#  '모멘텀',
#  '긍정',
#  '전망',
#  '동기',
#  '영업',
#  '좋다',
#  '증가',
#  '전망',
#  '메모리',
#  '단기',
#  '옆방',
#  '우려',
#  '당부',
#  '반영',
#  '단기',
#  '하락',
#  '만회',
#  '주가',
#  '반등',
#  '오지',
#  '뭐애널',
#  '리스트',
#  '보고서',
#  '계획',
#  '참고',
#  '해주시',
#  '좋다',
#  '제의',
#  '장',
#  '상황',
#  '먼저',
#  '느낌',
#  '약골',
#  '벌좀',
#  '네이버',
#  '카카오',
#  '형성',
#  '통해',
#  '면',
#  '급하다',
#  '중계',
#  '한국',
#  '모델',
#  '비상',
#  '기업',
#  '회사',
#  '말뭐',
#  '비교',
#  '해갈',
#  '유리',
#  '의사',
#  '요점',
#  '게또',
#  '일종',
#  '의약',
#  '규제',
#  '신호탄',
#  '무리',
#  '느낌',
#  '어쩌',
#  '주가',
#  '굉장하다',
#  '평가',
#  '기억',
#  '부담',
#  '미국',
#  '테크',
#  '대부분',
#  '이슈',
#  '네이버',
#  '카카오',
#  '출발',
#  '오빠',
#  '웨이브',
#  '양사',
#  '네이버',
#  '카카오',
#  '하락',
#  '세로',
#  '출발',
#  '뿐',
#  '지수',
#  '미국',
#  '다우지수',
#  '영향',
#  '일부',
#  '한국',
#  '네이버',
#  '카코',
#  '영향',
#  '삼성',
#  '변동',
#  '그냥',
#  '보합',
#  '하이닉스',
#  '하락',
#  '네이버',
#  '카카오',
#  '반등',
#  '그래프',
#  '최근',
#  '물량',
#  '부담',
#  '우려',
#  '그이',
#  '배웅',
#  '프터',
#  '반등',
#  '엔씨소프트',
#  '어제',
#  '사주',
#  '매입',
#  '공식',
#  '반등',
#  '대부분',
#  '기업',
#  '약세',
#  '출발',
#  '기업',
#  '아깝다',
#  '신규',
#  '장기',
#  '테크놀로지',
#  '솔루션',
#  '엔씨소프트',
#  '일부',
#  '기업',
#  '반등',
#  '금호',
#  '최근',
#  '강세',
#  '계속',
#  '기억',
#  '거구',
#  '이노',
#  '건',
#  '반등',
#  '이유',
#  '애플',
#  '공개',
#  '언급',
#  '다음주',
#  '공개',
#  '관련',
#  '강세',
#  '하락',
#  '기어',
#  '네이버',
#  '카카오',
#  '가장',
#  '두산',
#  '중공업',
#  '일부',
#  '리퍼',
#  '보시',
#  '좋다',
#  '외모',
#  '정미라',
#  '동국제강',
#  '기업',
#  '어제',
#  '상승세',
#  '좋다',
#  '주중',
#  '대표',
#  '현대',
#  '로템',
#  '좀차익',
#  '매물',
#  '약세',
#  '단오',
#  '전정',
#  '코스닥',
#  '대구',
#  '기업',
#  '부진하다',
#  '상태',
#  '어제',
#  '소재',
#  '제도',
#  '강하다',
#  '좋다',
#  '추가',
#  '상승',
#  '실리콘',
#  '국제',
#  '기업인',
#  '그대',
#  '주전자',
#  '재료',
#  '추가',
#  '로더',
#  '상승',
#  '이제반',
#  '기업',
#  '머티리얼즈',
#  '테스',
#  '반도체',
#  '보장',
#  '기업',
#  '주가',
#  '가약',
#  '날좀',
#  '힘들다',
#  '안정',
#  '빨르다',
#  '아프리카',
#  '식탁',
#  '아마',
#  '요음',
#  '어그',
#  '가지',
#  '거기',
#  '발밑',
#  '염색',
#  '알루미늄',
#  '전기차',
#  '주간동아',
#  '배고프다',
#  '문구',
#  '현재',
#  '약간',
#  '대용',
#  '기업',
#  '주가',
#  '부진',
#  '인하다',
#  '코스피',
#  '포인트',
#  '표시',
#  '덕분',
#  '소스',
#  '어제',
#  '하락',
#  '압력',
#  '조금',
#  '이다',
#  '포인트',
#  '기록',
#  '외국',
#  '오늘이',
#  '투자자',
#  '경우',
#  '어제',
#  '아침',
#  '네일',
#  '방적',
#  '매도',
#  '때문',
#  '아마',
#  '네이버',
#  '카카오',
#  '중심',
#  '외국인',
#  '좋다',
#  '어제',
#  '가장',
#  '철강',
#  '주도',
#  '고색',
#  '토로',
#  '업종',
#  '세포이',
#  '제한',
#  '번더',
#  '정리',
#  '은행',
#  '업종',
#  '파병',
#  '카카오',
#  '게임',
#  '오름',
#  '유일하다',
#  '은행',
#  '업종',
#  '금제',
#  '코스피',
#  '상승',
#  '나머지',
#  '섹터',
#  '일단',
#  '하락',
#  '아깝다',
#  '말씀',
#  '알루미늄',
#  '관련',
#  '주도',
#  '오늘',
#  '알미늄',
#  '조일',
#  '알미늄',
#  '이상',
#  '간등',
#  '오늘',
#  '장비',
#  '회사',
#  '강하다',
#  '소재',
#  '장비',
#  '기업',
#  '일단',
#  '반등',
#  '오늘',
#  '보시',
#  '나머지',
#  '섹터',
#  '하락',
#  '인터넷',
#  '대표',
#  '백화점',
#  '비트코인',
#  '가게',
#  '급락',
#  '나무',
#  '관련',
#  '비트코인',
#  '관련',
#  '오늘',
#  '하락',
#  '압력',
#  '로좀',
#  '한국',
#  '대표',
#  '성장',
#  '기업',
#  '이몸',
#  '어스',
#  '관련',
#  '우주',
#  '항공',
#  '대부분',
#  '낙폭',
#  '국정',
#  '아주',
#  '소수',
#  '부분',
#  '일단',
#  '밀리',
#  '생각',
#  '해주시',
#  '좋다',
#  '무인기',
#  '시기',
#  '머',
#  '굉장하다',
#  '음개',
#  '매수',
#  '난',
#  '행보',
#  '굉장하다',
#  '오르락내리락',
#  '투자',
#  '투자자',
#  '판단',
#  '이심',
#  '조심',
#  '전체',
#  '라이트',
#  '하락',
#  '종목',
#  '많다',
#  '보이',
#  '코스피',
#  '사이',
#  '호정',
#  '오늘',
#  '코스닥',
#  '좀더',
#  '안좋다',
#  '애',
#  '최근',
#  '에코',
#  '스타',
#  '리더',
#  '강하다',
#  '오늘',
#  '조금',
#  '나쁘다',
#  '작다',
#  '어어',
#  '뉴스',
#  '보톡스',
#  '덥다',
#  '말씀',
#  '신앙',
#  '금융',
#  '숙자',
#  '애널',
#  '리스트',
#  '보고서',
#  '신흥',
#  '증시',
#  '희망',
#  '계속',
#  '미국증시',
#  '좋다',
#  '계속',
#  '신흥',
#  '국부',
#  '진하다',
#  '원인',
#  '여러가지',
#  '신흥',
#  '약세',
#  '모텔',
#  '타변',
#  '확산',
#  '중국',
#  '불확실',
#  '원자재',
#  '가격',
#  '조정',
#  '테이퍼링',
#  '우려',
#  '인플레이션',
#  '금리',
#  '인상',
#  '이모',
#  '복합',
#  '작용',
#  '신흥',
#  '안좋다',
#  '은부',
#  '접종',
#  '구비',
#  '정도',
#  '한국',
#  '정부',
#  '총',
#  '집단민원',
#  '코로',
#  '나발',
#  '플러스',
#  '해소',
#  '일단',
#  '보고',
#  '그다음',
#  '경기',
#  '모멘텀',
#  '훼손',
#  '최근',
#  '약간',
#  '경감',
#  '어제',
#  '발표',
#  '중국',
#  '수출',
#  '부분',
#  '약간',
#  '경감',
#  '된거',
#  '미국',
#  '중심',
#  '재정정책',
#  '높다',
#  '때문',
#  '경기',
#  '민감',
#  '주신',
#  '증시',
#  '상대',
#  '국가',
#  '차별',
#  '주목',
#  '을해',
#  '일단',
#  '대만',
#  '마찬가지',
#  '하반기',
#  '이익',
#  '의상대',
#  '의하다',
#  '한국',
#  '과대',
#  '나라',
#  '고단',
#  '우위',
#  '고합',
#  '다그',
#  '래서',
#  '부분',
#  '상대',
#  '매력',
#  '부분',
#  '신흥',
#  '한국',
#  '중국',
#  '좀비',
#  '간단하다',
#  '자위',
#  '번하다',
#  '자세하다',
#  '홈페이지',
#  '보시',
#  '일단',
#  '좋다',
#  '신흥',
#  '증시',
#  '해방',
#  '약속',
#  '위원회',
#  '리포터',
#  '약간',
#  '독특하다',
#  '한국',
#  '투자',
#  '증권',
#  '김성근',
#  '애널',
#  '리스트',
#  '번영',
#  '피해',
#  '약간',
#  '자료',
#  '동문',
#  '그거',
#  '중국',
#  '동부',
#  '요일',
#  '단곡',
#  '극적',
#  '측면',
#  '보고',
#  '최근',
#  '인도',
#  '굉장하다',
#  '인도',
#  '색스',
#  '지수',
#  '포인트',
#  '용해',
#  '로사',
#  '최고',
#  '엄격하다',
#  '중점',
#  '나부',
#  '의거',
#  '핑크',
#  '굉장하다',
#  '가인',
#  '안좋다',
#  '나라',
#  '지수',
#  '장난',
#  '정말',
#  '역대',
#  '최고점',
#  '돌파',
#  '그게',
#  '델타',
#  '이뿌다',
#  '수급',
#  '수도',
#  '보',
#  '지수',
#  '추정',
#  '신흥',
#  '거기',
#  '중국',
#  '미리',
#  '중국',
#  '제외',
#  '펀드',
#  '추정',
#  '데또',
#  '대요',
#  '중국',
#  '제외',
#  '자금',
#  '유입',
#  '이유',
#  '중국',
#  '규제',
#  '리스크',
#  '이제',
#  '자금',
#  '중국',
#  '요금',
#  '중국',
#  '투자',
#  '펀드',
#  '중국',
#  '의상',
#  '부분',
#  '배분',
#  '거나',
#  '본분',
#  '펀드',
#  '태',
#  '시법',
#  '왼쪽',
#  '한국',
#  '나쁘다',
#  '안테나',
#  '왜냐면',
#  '이머징마켓',
#  '지수',
#  '한국',
#  '정도',
#  '비중',
#  '중국',
#  '제외',
#  '교육',
#  '비중',
#  '이제우',
#  '신흥',
#  '비중',
#  '펀드',
#  '이인기',
#  '국도',
#  '좀볼수',
#  '무런',
#  '종이',
#  '용인',
#  '수급',
#  '독특하다',
#  '시각',
#  '개쪽',
#  '만약',
#  '자금',
#  '우리나라',
#  '나쁘다',
#  '요인',
#  '인도네시아',
#  '도가사상',
#  '최고',
#  '팔이',
#  '국도',
#  '수해',
#  '내일',
#  '용이',
#  '제작',
#  '규모',
#  '당연하다',
#  '포항',
#  '결심',
#  '시각',
#  '참고',
#  ...]

# %%
len(lgc_210908_list)
# Out:
# 9458

# %%
count = Counter(lgc_210908_list)
words = dict(count.most_common())

words_df = pd.DataFrame.from_dict([words]).T.reset_index()
words_df.columns = ['words', 'freq']

# %%
words_df
# Out:
#      words  freq
# 0       좋다   124
# 1       중국   102
# 2       이제    78
# 3       기업    56
# 4     굉장하다    54
# ...    ...   ...
# 2246     요     2
# 2247    키스     2
# 2248  깔끔하다     2
# 2249    반값     2
# 2250    수행     2
#
# [2251 rows x 2 columns]

# %%
words_df.to_csv('lgc_210908_wc.csv', header=True, index=False, encoding = 'utf-8-sig')
