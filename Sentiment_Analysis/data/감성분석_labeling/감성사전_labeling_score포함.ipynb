# %%
import codecs

positive = [] 
negative = []
posneg = []
dic = [('./KOSELF_pos.txt', './KOSELF_neg.txt'),
       ("./data/positive_words_self.txt","./data/negative_words_self.txt"),
      ('./data/sum_pos.txt','./data/sum_neg.txt')]

i = int(input('koself : 1, blog : 2, sum : 3 === '))-1


pos = codecs.open(dic[i][0], 'rb', encoding='UTF-8') 

while True: 
    line = pos.readline() 
    line = line.replace('\n', '')
    line = line.replace('\r', '')
    
    if not line: break
        
    positive.append(line) 
    posneg.append(line) 
        
pos.close() 

neg = codecs.open(dic[i][1], 'rb', encoding='UTF-8') 
while True: 
    line = neg.readline() 
    line = line.replace('\n', '')
    line = line.replace('\r', '')
    
    if not line: break
    
    negative.append(line) 
    posneg.append(line) 
    
neg.close()
# Out:
# koself : 1, blog : 2, sum : 3 === 3

# %%
import pandas as pd
import numpy as np
import pymysql
import re

# %%
com_list = {'하이닉스' : '000660',
           '현대차' : '005380',
           '삼성전자' : '005930',
           'LG화학' : '051910',
           '셀트리온' : '068270'}
media_list = {'아시아경제_' : 'asia_',
             '매일경제_': 'maeil_'}

df_list = []

for n,m in media_list.items():
    for i,j in com_list.items():

        db = pymysql.connect(
            user='root', 
            passwd='1234', 
            host='3.35.70.166', 
            db='proj', 
            charset = 'utf8'
        )

        cursor = db.cursor(pymysql.cursors.DictCursor)
        sql = "select * from "+ m +"news_craw_" + j +" where length(date) = 10"
        
        cursor.execute(sql)

        result = cursor.fetchall()

        # 데이터 프레임으로 변경
        globals() ['df_'+ m + j ] = pd.DataFrame(result)
        print('df_'+ m + j)
        df_list.append(globals() ['df_'+ m + j ])
        
        db.close()
# Out:
# df_asia_000660
# df_asia_005380
# df_asia_005930
# df_asia_051910
# df_asia_068270
# df_maeil_000660
# df_maeil_005380
# df_maeil_005930
# df_maeil_051910
# df_maeil_068270

# %%
df_total = pd.concat(df_list)

# %%
df_total
# Out:
#         st_n   st_cd   news        date  \
# 0     sk하이닉스  000660  아시아경제  2018122715
# 1     sk하이닉스  000660  아시아경제  2018123110
# 2     sk하이닉스  000660  아시아경제  2018122816
# 3     sk하이닉스  000660  아시아경제  2018122607
# 4     sk하이닉스  000660  아시아경제  2018122707
# ...      ...     ...    ...         ...
# 3216    셀트리온  068270   매일경제  2021092309
# 3217    셀트리온  068270   매일경제  2021092317
# 3218    셀트리온  068270   매일경제  2021092715
# 3219    셀트리온  068270   매일경제  2021092414
# 3220    셀트리온  068270   매일경제  2021092417
#
#                                           title  \
# 0               SK하이닉스, 우수 엔지니어 60세 넘어도 일할 수 있다
# 1        오션브릿지, SK하이닉스와 12억 규모 반도체 장비제조 공급계약 체결
# 2                        SK하이닉스, 우수 엔지니어 정년 없앤다
# 3     [클릭 e종목]"SK하이닉스, 내년 반도체 수요 증가율 상저하고…목표가↓"
# 4                [클릭 e종목]"SK하이닉스, 4Q영업익 전망치 하향"
# ...                                         ...
# 3216   "미국 중국 동시 악재라니"…동학개미 악소리 난다, 연휴 뒤 코스피 급락
# 3217              디지털 강자 매경, 카카오 블록체인 클레이튼과 손잡다
# 3218   코스피 외국인 기관 쌍끌이 매수…8.40포인트↑, 3133.64 장 마감
# 3219    휴마시스, 셀트리온과 273억원 규모 코로나19 항원진단키트 공급 계약
# 3220                       中헝다 충격 방어주로 떠오르는 바이오
#
#                                                     url  \
# 0     http://view.asiae.co.kr/news/view.htm?idxno=20...
# 1     http://view.asiae.co.kr/news/view.htm?idxno=20...
# 2     http://view.asiae.co.kr/news/view.htm?idxno=20...
# 3     http://view.asiae.co.kr/news/view.htm?idxno=20...
# 4     http://view.asiae.co.kr/news/view.htm?idxno=20...
# ...                                                 ...
# 3216  http://news.mk.co.kr/newsRead.php?no=907885&ye...
# 3217  http://news.mk.co.kr/newsRead.php?no=910365&ye...
# 3218  http://news.mk.co.kr/newsRead.php?no=919526&ye...
# 3219  http://news.mk.co.kr/newsRead.php?no=912835&ye...
# 3220  http://news.mk.co.kr/newsRead.php?no=913623&ye...
#
#                                                    text
# 0     2020년에는 상대평가제도도 폐지…소통강화 위해 호칭도 'TL'로 통일 [아시아경제...
# 1     \r\t\t\t\t\t\t\t[아시아경제 오주연 기자] \r\t\t\t\t\t\t\...
# 2     \r\t\t\t\t\t\t\t인사제도 파격적 개편…최태원 회장의 딥체인지 실현 [아...
# 3     \r\t\t\t\t\t\t\t[아시아경제 송화정 기자]신한금융투자는 26일 \r\t...
# 4     \r\t\t\t\t\t\t\t[아시아경제 오주연 기자] 하나금융투자가 27일 \r\...
# ...                                                 ...
# 3216  \n\n\n[사진 출처 = 연합뉴스]\n 중국 헝다그룹 유동성 위기 등 추석 연휴에...
# 3217  \n\n\n올해로 22회째를 맞은 세계지식포럼에서 로버트 주브린 화성학회 회장이 2...
# 3218  \n\n\n[사진 출처 = 연합뉴스]\n 중국 부동산 재벌 헝다그룹의 파산 우려에도...
# 3219  현장형 신속검사 기업 휴마시스가 셀트리온과 273억원 규모 코로나19 항원진단키트 ...
# 3220  \n\n\n 최근 주가 박스권 흐름에 바이오 업종에 주목할 필요가 있다는 의견이 나...
#
# [70584 rows x 7 columns]

# %%
# test_df = pd.read_csv('./sentiment/2018_lg.csv')
# test_df = test_df[['st_n', 'st_cd', 'news', 'date', 'title', 'Change', 'Tokenization']]

# %%
j = 0
label = [0] * len(df_total)
pos = [0] * len(df_total)
neg = [0] * len(df_total)

my_dic = {"title":[], "label":label, 'pos': pos, 'neg': neg}

titles = df_total.title
titles = titles.str.replace('[-=+,#/\?:^$.@*\"※~&%ㆍ!』\\‘|\(\)\[\]\<\>`\'…\"\“▲》◆▶◇■]','')
titles = titles.str.replace('[\n\r\t\\\]','')
titles = titles.reset_index().drop('index',1).title

for df in range(len(df_total)):    
    txt_data = titles[df]
    
    my_dic['title'].append(txt_data) 
    pos_sum = 0
    neg_sum = 0
    
    for i in range(len(posneg)): 
        posflag = False 
        negflag = False
        
        if i < (len(positive)-1):
            if txt_data.find(posneg[i]) != -1: 
                print("positive?",
                      "테스트 : ",txt_data.find(posneg[i]),"비교단어 : ", posneg[i],
                      "등장 빈도(획득 점수) : ", txt_data.count(posneg[i]),
                      "인덱스 : ", i) 
                pos_sum += txt_data.count(posneg[i])

#             if txt_data.find(posneg[i]) != -1: 
#                 posflag = True 
#                 print(i, "positive?","테스트 : ",txt_data.find(posneg[i]),"비교단어 : ", posneg[i], "인덱스 : ", i) 
#                 break

        if i > (len(positive)-2):
            if txt_data.find(posneg[i]) != -1: 
                print("negative?",
                      "테스트 : ",txt_data.find(posneg[i]), "비교단어 : ", posneg[i],
                      "등장 빈도(획득점수) : ",txt_data.count(posneg[i]),
                      "인덱스 : ", i) 
                neg_sum += txt_data.count(posneg[i])
                
                
#             if txt_data.find(posneg[i]) != -1: 
#                 negflag = True 
#                 print(i, "negative?","테스트 : ",txt_data.find(posneg[i]),"비교단어 : ", posneg[i], "인덱스 : ", i) 
#                 break
    pos[j] = pos_sum
    neg[j] = neg_sum
    
    if pos_sum > neg_sum:
        posflag = True

    elif pos_sum < neg_sum:
        negflag = True    
        

    if posflag == True: 
        label[j] = 1 
        # print("positive", j) 

    elif negflag == True: 
        label[j] = -1 
        # print("negative", j) 

    elif negflag == False and posflag == False: 
        label[j] = 0 
        # print("objective", j) 

    j = j + 1
                
my_dic['label'] = label
my_dic['pos'] = pos
my_dic['neg'] = neg
my_df = pd.DataFrame(my_dic)
# Out:
# positive? 테스트 :  35 비교단어 :  체결 등장 빈도(획득 점수) :  1 인덱스 :  77
# positive? 테스트 :  23 비교단어 :  증가 등장 빈도(획득 점수) :  1 인덱스 :  78
# negative? 테스트 :  15 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  15 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  15 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  13 비교단어 :  우려 등장 빈도(획득점수) :  1 인덱스 :  190
# positive? 테스트 :  15 비교단어 :  개선 등장 빈도(획득 점수) :  1 인덱스 :  3
# positive? 테스트 :  25 비교단어 :  최고 등장 빈도(획득 점수) :  1 인덱스 :  84
# negative? 테스트 :  25 비교단어 :  우려 등장 빈도(획득점수) :  1 인덱스 :  190
# positive? 테스트 :  37 비교단어 :  강세 등장 빈도(획득 점수) :  1 인덱스 :  2
# positive? 테스트 :  28 비교단어 :  체결 등장 빈도(획득 점수) :  1 인덱스 :  77
# negative? 테스트 :  23 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  23 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  23 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  9 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  9 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  9 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  22 비교단어 :  체결 등장 빈도(획득 점수) :  1 인덱스 :  77
# negative? 테스트 :  25 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  25 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  25 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  10 비교단어 :  1위 등장 빈도(획득 점수) :  1 인덱스 :  62
# positive? 테스트 :  23 비교단어 :  성공 등장 빈도(획득 점수) :  1 인덱스 :  18
# positive? 테스트 :  19 비교단어 :  대박 등장 빈도(획득 점수) :  1 인덱스 :  59
# positive? 테스트 :  30 비교단어 :  개선 등장 빈도(획득 점수) :  1 인덱스 :  3
# negative? 테스트 :  26 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  26 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  26 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  11 비교단어 :  호황 등장 빈도(획득 점수) :  1 인덱스 :  44
# negative? 테스트 :  14 비교단어 :  부정적 등장 빈도(획득점수) :  1 인덱스 :  105
# negative? 테스트 :  23 비교단어 :  울상 등장 빈도(획득점수) :  1 인덱스 :  187
# negative? 테스트 :  23 비교단어 :  한숨 등장 빈도(획득점수) :  1 인덱스 :  176
# negative? 테스트 :  20 비교단어 :  급락 등장 빈도(획득점수) :  1 인덱스 :  153
# positive? 테스트 :  9 비교단어 :  호황 등장 빈도(획득 점수) :  2 인덱스 :  44
# negative? 테스트 :  22 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  22 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  22 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  20 비교단어 :  강세 등장 빈도(획득 점수) :  1 인덱스 :  2
# positive? 테스트 :  26 비교단어 :  경신 등장 빈도(획득 점수) :  1 인덱스 :  6
# negative? 테스트 :  15 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  15 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  15 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  21 비교단어 :  경신 등장 빈도(획득 점수) :  1 인덱스 :  6
# negative? 테스트 :  12 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  12 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  12 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  28 비교단어 :  최고 등장 빈도(획득 점수) :  1 인덱스 :  84
# positive? 테스트 :  25 비교단어 :  적극 등장 빈도(획득 점수) :  1 인덱스 :  32
# positive? 테스트 :  35 비교단어 :  증가 등장 빈도(획득 점수) :  1 인덱스 :  78
# positive? 테스트 :  35 비교단어 :  증가 등장 빈도(획득 점수) :  1 인덱스 :  78
# positive? 테스트 :  39 비교단어 :  증가 등장 빈도(획득 점수) :  1 인덱스 :  78
# negative? 테스트 :  28 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  28 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  28 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  27 비교단어 :  충분히 등장 빈도(획득 점수) :  1 인덱스 :  41
# positive? 테스트 :  33 비교단어 :  증가 등장 빈도(획득 점수) :  1 인덱스 :  78
# positive? 테스트 :  23 비교단어 :  수상 등장 빈도(획득 점수) :  1 인덱스 :  54
# negative? 테스트 :  11 비교단어 :  충격 등장 빈도(획득점수) :  1 인덱스 :  132
# negative? 테스트 :  26 비교단어 :  급락 등장 빈도(획득점수) :  1 인덱스 :  153
# negative? 테스트 :  18 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  18 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  18 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  20 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  20 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  20 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  26 비교단어 :  호황 등장 빈도(획득 점수) :  1 인덱스 :  44
# negative? 테스트 :  9 비교단어 :  둔화 등장 빈도(획득점수) :  1 인덱스 :  99
# negative? 테스트 :  15 비교단어 :  둔화 등장 빈도(획득점수) :  1 인덱스 :  99
# negative? 테스트 :  14 비교단어 :  논란 등장 빈도(획득점수) :  1 인덱스 :  142
# positive? 테스트 :  19 비교단어 :  대박 등장 빈도(획득 점수) :  1 인덱스 :  59
# negative? 테스트 :  13 비교단어 :  우려 등장 빈도(획득점수) :  1 인덱스 :  190
# positive? 테스트 :  28 비교단어 :  증가 등장 빈도(획득 점수) :  1 인덱스 :  78
# positive? 테스트 :  24 비교단어 :  경신 등장 빈도(획득 점수) :  1 인덱스 :  6
# positive? 테스트 :  32 비교단어 :  증가 등장 빈도(획득 점수) :  1 인덱스 :  78
# positive? 테스트 :  18 비교단어 :  강세 등장 빈도(획득 점수) :  1 인덱스 :  2
# positive? 테스트 :  4 비교단어 :  호황 등장 빈도(획득 점수) :  1 인덱스 :  44
# positive? 테스트 :  17 비교단어 :  경신 등장 빈도(획득 점수) :  1 인덱스 :  6
# positive? 테스트 :  13 비교단어 :  최고 등장 빈도(획득 점수) :  1 인덱스 :  84
# positive? 테스트 :  28 비교단어 :  성공 등장 빈도(획득 점수) :  1 인덱스 :  18
# positive? 테스트 :  18 비교단어 :  대박 등장 빈도(획득 점수) :  1 인덱스 :  59
# positive? 테스트 :  23 비교단어 :  강세 등장 빈도(획득 점수) :  1 인덱스 :  2
# negative? 테스트 :  31 비교단어 :  우려 등장 빈도(획득점수) :  1 인덱스 :  190
# negative? 테스트 :  18 비교단어 :  소송 등장 빈도(획득점수) :  1 인덱스 :  201
# negative? 테스트 :  0 비교단어 :  의심 등장 빈도(획득점수) :  1 인덱스 :  118
# negative? 테스트 :  13 비교단어 :  우려 등장 빈도(획득점수) :  1 인덱스 :  190
# negative? 테스트 :  10 비교단어 :  실패 등장 빈도(획득점수) :  1 인덱스 :  111
# negative? 테스트 :  32 비교단어 :  울상 등장 빈도(획득점수) :  1 인덱스 :  187
# positive? 테스트 :  25 비교단어 :  중요한 등장 빈도(획득 점수) :  1 인덱스 :  35
# positive? 테스트 :  22 비교단어 :  가치 등장 빈도(획득 점수) :  1 인덱스 :  0
# positive? 테스트 :  28 비교단어 :  명성 등장 빈도(획득 점수) :  1 인덱스 :  13
# positive? 테스트 :  17 비교단어 :  최고점 등장 빈도(획득 점수) :  1 인덱스 :  37
# positive? 테스트 :  17 비교단어 :  최고 등장 빈도(획득 점수) :  1 인덱스 :  84
# negative? 테스트 :  27 비교단어 :  둔화 등장 빈도(획득점수) :  1 인덱스 :  99
# positive? 테스트 :  17 비교단어 :  경신 등장 빈도(획득 점수) :  1 인덱스 :  6
# positive? 테스트 :  13 비교단어 :  최고 등장 빈도(획득 점수) :  1 인덱스 :  84
# negative? 테스트 :  3 비교단어 :  우려 등장 빈도(획득점수) :  1 인덱스 :  190
# positive? 테스트 :  25 비교단어 :  강세 등장 빈도(획득 점수) :  1 인덱스 :  2
# negative? 테스트 :  19 비교단어 :  악화 등장 빈도(획득점수) :  1 인덱스 :  112
# positive? 테스트 :  15 비교단어 :  성공 등장 빈도(획득 점수) :  1 인덱스 :  18
# positive? 테스트 :  36 비교단어 :  강세 등장 빈도(획득 점수) :  1 인덱스 :  2
# positive? 테스트 :  38 비교단어 :  증가 등장 빈도(획득 점수) :  1 인덱스 :  78
# positive? 테스트 :  19 비교단어 :  강세 등장 빈도(획득 점수) :  1 인덱스 :  2
# positive? 테스트 :  12 비교단어 :  강세 등장 빈도(획득 점수) :  1 인덱스 :  2
# positive? 테스트 :  30 비교단어 :  성공 등장 빈도(획득 점수) :  1 인덱스 :  18
# positive? 테스트 :  27 비교단어 :  체결 등장 빈도(획득 점수) :  1 인덱스 :  77
# positive? 테스트 :  22 비교단어 :  증가 등장 빈도(획득 점수) :  1 인덱스 :  78
# positive? 테스트 :  25 비교단어 :  강세 등장 빈도(획득 점수) :  1 인덱스 :  2
# positive? 테스트 :  26 비교단어 :  수혜 등장 빈도(획득 점수) :  1 인덱스 :  19
# positive? 테스트 :  17 비교단어 :  증가 등장 빈도(획득 점수) :  1 인덱스 :  78
# negative? 테스트 :  21 비교단어 :  둔화 등장 빈도(획득점수) :  1 인덱스 :  99
# positive? 테스트 :  24 비교단어 :  체결 등장 빈도(획득 점수) :  1 인덱스 :  77
# negative? 테스트 :  19 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  19 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  19 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  22 비교단어 :  증가 등장 빈도(획득 점수) :  1 인덱스 :  78
# positive? 테스트 :  15 비교단어 :  기부 등장 빈도(획득 점수) :  1 인덱스 :  80
# negative? 테스트 :  25 비교단어 :  둔화 등장 빈도(획득점수) :  1 인덱스 :  99
# negative? 테스트 :  23 비교단어 :  급락 등장 빈도(획득점수) :  1 인덱스 :  153
# positive? 테스트 :  37 비교단어 :  증가 등장 빈도(획득 점수) :  1 인덱스 :  78
# positive? 테스트 :  15 비교단어 :  증가 등장 빈도(획득 점수) :  1 인덱스 :  78
# negative? 테스트 :  21 비교단어 :  부정적 등장 빈도(획득점수) :  1 인덱스 :  105
# positive? 테스트 :  34 비교단어 :  증가 등장 빈도(획득 점수) :  1 인덱스 :  78
# positive? 테스트 :  25 비교단어 :  증가 등장 빈도(획득 점수) :  1 인덱스 :  78
# positive? 테스트 :  33 비교단어 :  증가 등장 빈도(획득 점수) :  1 인덱스 :  78
# negative? 테스트 :  19 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  19 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  19 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  36 비교단어 :  강세 등장 빈도(획득 점수) :  1 인덱스 :  2
# positive? 테스트 :  23 비교단어 :  체결 등장 빈도(획득 점수) :  1 인덱스 :  77
# negative? 테스트 :  17 비교단어 :  급락 등장 빈도(획득점수) :  1 인덱스 :  153
# negative? 테스트 :  23 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  23 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  23 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  27 비교단어 :  강세 등장 빈도(획득 점수) :  1 인덱스 :  2
# positive? 테스트 :  25 비교단어 :  체결 등장 빈도(획득 점수) :  1 인덱스 :  77
# positive? 테스트 :  21 비교단어 :  주목 등장 빈도(획득 점수) :  1 인덱스 :  50
# negative? 테스트 :  22 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  22 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  22 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  29 비교단어 :  급락 등장 빈도(획득점수) :  1 인덱스 :  153
# positive? 테스트 :  19 비교단어 :  강세 등장 빈도(획득 점수) :  1 인덱스 :  2
# negative? 테스트 :  16 비교단어 :  주의 등장 빈도(획득점수) :  1 인덱스 :  125
# positive? 테스트 :  19 비교단어 :  강세 등장 빈도(획득 점수) :  1 인덱스 :  2
# positive? 테스트 :  19 비교단어 :  강세 등장 빈도(획득 점수) :  1 인덱스 :  2
# positive? 테스트 :  13 비교단어 :  가치 등장 빈도(획득 점수) :  1 인덱스 :  0
# positive? 테스트 :  19 비교단어 :  개선 등장 빈도(획득 점수) :  1 인덱스 :  3
# negative? 테스트 :  15 비교단어 :  급락 등장 빈도(획득점수) :  1 인덱스 :  153
# negative? 테스트 :  5 비교단어 :  우려 등장 빈도(획득점수) :  1 인덱스 :  190
# positive? 테스트 :  21 비교단어 :  확보 등장 빈도(획득 점수) :  1 인덱스 :  45
# positive? 테스트 :  26 비교단어 :  강세 등장 빈도(획득 점수) :  1 인덱스 :  2
# negative? 테스트 :  28 비교단어 :  소송 등장 빈도(획득점수) :  1 인덱스 :  201
# positive? 테스트 :  27 비교단어 :  체결 등장 빈도(획득 점수) :  1 인덱스 :  77
# negative? 테스트 :  11 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  11 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  11 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  15 비교단어 :  강세 등장 빈도(획득 점수) :  1 인덱스 :  2
# positive? 테스트 :  24 비교단어 :  체결 등장 빈도(획득 점수) :  1 인덱스 :  77
# positive? 테스트 :  27 비교단어 :  오픈 등장 빈도(획득 점수) :  1 인덱스 :  65
# positive? 테스트 :  20 비교단어 :  새로운 등장 빈도(획득 점수) :  1 인덱스 :  85
# positive? 테스트 :  15 비교단어 :  강세 등장 빈도(획득 점수) :  1 인덱스 :  2
# positive? 테스트 :  21 비교단어 :  호황 등장 빈도(획득 점수) :  1 인덱스 :  44
# positive? 테스트 :  32 비교단어 :  성공 등장 빈도(획득 점수) :  1 인덱스 :  18
# positive? 테스트 :  9 비교단어 :  진출 등장 빈도(획득 점수) :  1 인덱스 :  75
# negative? 테스트 :  9 비교단어 :  우려 등장 빈도(획득점수) :  1 인덱스 :  190
# positive? 테스트 :  24 비교단어 :  체결 등장 빈도(획득 점수) :  1 인덱스 :  77
# positive? 테스트 :  28 비교단어 :  체결 등장 빈도(획득 점수) :  1 인덱스 :  77
# negative? 테스트 :  28 비교단어 :  침해 등장 빈도(획득점수) :  1 인덱스 :  163
# negative? 테스트 :  31 비교단어 :  소송 등장 빈도(획득점수) :  1 인덱스 :  201
# positive? 테스트 :  30 비교단어 :  강세 등장 빈도(획득 점수) :  1 인덱스 :  2
# positive? 테스트 :  25 비교단어 :  체결 등장 빈도(획득 점수) :  1 인덱스 :  77
# positive? 테스트 :  18 비교단어 :  증가 등장 빈도(획득 점수) :  1 인덱스 :  78
# negative? 테스트 :  6 비교단어 :  매각 등장 빈도(획득점수) :  1 인덱스 :  212
# positive? 테스트 :  28 비교단어 :  체결 등장 빈도(획득 점수) :  1 인덱스 :  77
# positive? 테스트 :  18 비교단어 :  MOU 등장 빈도(획득 점수) :  1 인덱스 :  48
# positive? 테스트 :  22 비교단어 :  체결 등장 빈도(획득 점수) :  1 인덱스 :  77
# negative? 테스트 :  7 비교단어 :  소송 등장 빈도(획득점수) :  1 인덱스 :  201
# positive? 테스트 :  30 비교단어 :  제휴 등장 빈도(획득 점수) :  1 인덱스 :  49
# negative? 테스트 :  22 비교단어 :  침해 등장 빈도(획득점수) :  1 인덱스 :  163
# negative? 테스트 :  1 비교단어 :  소송 등장 빈도(획득점수) :  1 인덱스 :  201
# negative? 테스트 :  9 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  9 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  9 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  21 비교단어 :  최고 등장 빈도(획득 점수) :  1 인덱스 :  84
# negative? 테스트 :  28 비교단어 :  피해 등장 빈도(획득점수) :  1 인덱스 :  147
# positive? 테스트 :  11 비교단어 :  가치 등장 빈도(획득 점수) :  2 인덱스 :  0
# positive? 테스트 :  25 비교단어 :  대박 등장 빈도(획득 점수) :  1 인덱스 :  59
# negative? 테스트 :  11 비교단어 :  악화 등장 빈도(획득점수) :  1 인덱스 :  112
# positive? 테스트 :  30 비교단어 :  수상 등장 빈도(획득 점수) :  1 인덱스 :  54
# negative? 테스트 :  22 비교단어 :  둔화 등장 빈도(획득점수) :  1 인덱스 :  99
# positive? 테스트 :  5 비교단어 :  오픈 등장 빈도(획득 점수) :  1 인덱스 :  65
# negative? 테스트 :  23 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  11 비교단어 :  급락 등장 빈도(획득점수) :  1 인덱스 :  153
# negative? 테스트 :  23 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  23 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  19 비교단어 :  우려 등장 빈도(획득점수) :  1 인덱스 :  190
# negative? 테스트 :  14 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  14 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  14 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  12 비교단어 :  한숨 등장 빈도(획득점수) :  1 인덱스 :  176
# negative? 테스트 :  15 비교단어 :  둔화 등장 빈도(획득점수) :  1 인덱스 :  99
# negative? 테스트 :  18 비교단어 :  우려 등장 빈도(획득점수) :  1 인덱스 :  190
# positive? 테스트 :  38 비교단어 :  경신 등장 빈도(획득 점수) :  1 인덱스 :  6
# positive? 테스트 :  24 비교단어 :  증가 등장 빈도(획득 점수) :  1 인덱스 :  78
# positive? 테스트 :  34 비교단어 :  최고 등장 빈도(획득 점수) :  1 인덱스 :  84
# negative? 테스트 :  41 비교단어 :  우려 등장 빈도(획득점수) :  1 인덱스 :  190
# positive? 테스트 :  25 비교단어 :  가치 등장 빈도(획득 점수) :  1 인덱스 :  0
# negative? 테스트 :  16 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  16 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  16 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  13 비교단어 :  신상 등장 빈도(획득 점수) :  1 인덱스 :  83
# negative? 테스트 :  27 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  27 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  27 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  7 비교단어 :  극심한 등장 빈도(획득점수) :  1 인덱스 :  98
# negative? 테스트 :  18 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  18 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  18 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  18 비교단어 :  빨간불 등장 빈도(획득점수) :  1 인덱스 :  164
# positive? 테스트 :  23 비교단어 :  호황 등장 빈도(획득 점수) :  1 인덱스 :  44
# positive? 테스트 :  13 비교단어 :  바닥 등장 빈도(획득 점수) :  1 인덱스 :  14
# negative? 테스트 :  7 비교단어 :  여파 등장 빈도(획득점수) :  1 인덱스 :  115
# negative? 테스트 :  29 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  4 비교단어 :  급락 등장 빈도(획득점수) :  1 인덱스 :  153
# negative? 테스트 :  29 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  7 비교단어 :  여파 등장 빈도(획득점수) :  1 인덱스 :  186
# negative? 테스트 :  29 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  33 비교단어 :  증가 등장 빈도(획득 점수) :  1 인덱스 :  78
# negative? 테스트 :  19 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  19 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  19 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  27 비교단어 :  더 좋은 등장 빈도(획득 점수) :  1 인덱스 :  10
# positive? 테스트 :  15 비교단어 :  1위 등장 빈도(획득 점수) :  1 인덱스 :  62
# positive? 테스트 :  20 비교단어 :  강세 등장 빈도(획득 점수) :  1 인덱스 :  2
# negative? 테스트 :  22 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  22 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  22 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  16 비교단어 :  급락 등장 빈도(획득점수) :  1 인덱스 :  153
# negative? 테스트 :  19 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  19 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  19 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  16 비교단어 :  경신 등장 빈도(획득 점수) :  1 인덱스 :  6
# negative? 테스트 :  23 비교단어 :  논란 등장 빈도(획득점수) :  1 인덱스 :  142
# negative? 테스트 :  7 비교단어 :  논란 등장 빈도(획득점수) :  1 인덱스 :  142
# positive? 테스트 :  18 비교단어 :  해결 등장 빈도(획득 점수) :  1 인덱스 :  43
# negative? 테스트 :  24 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  24 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  24 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  19 비교단어 :  부정적 등장 빈도(획득점수) :  1 인덱스 :  105
# negative? 테스트 :  29 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  29 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  29 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  12 비교단어 :  여파 등장 빈도(획득점수) :  1 인덱스 :  115
# negative? 테스트 :  12 비교단어 :  여파 등장 빈도(획득점수) :  1 인덱스 :  186
# positive? 테스트 :  18 비교단어 :  호황 등장 빈도(획득 점수) :  1 인덱스 :  44
# negative? 테스트 :  11 비교단어 :  논란 등장 빈도(획득점수) :  1 인덱스 :  142
# negative? 테스트 :  21 비교단어 :  직격탄 등장 빈도(획득점수) :  1 인덱스 :  175
# positive? 테스트 :  19 비교단어 :  가치 등장 빈도(획득 점수) :  1 인덱스 :  0
# negative? 테스트 :  12 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  12 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  12 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  14 비교단어 :  급락 등장 빈도(획득점수) :  1 인덱스 :  153
# negative? 테스트 :  25 비교단어 :  문제 등장 빈도(획득점수) :  1 인덱스 :  174
# negative? 테스트 :  14 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  14 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  14 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  4 비교단어 :  호황 등장 빈도(획득 점수) :  1 인덱스 :  44
# negative? 테스트 :  20 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  20 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  20 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  5 비교단어 :  호황 등장 빈도(획득 점수) :  1 인덱스 :  44
# positive? 테스트 :  30 비교단어 :  돌파 등장 빈도(획득 점수) :  1 인덱스 :  52
# negative? 테스트 :  17 비교단어 :  논란 등장 빈도(획득점수) :  1 인덱스 :  142
# positive? 테스트 :  9 비교단어 :  기부 등장 빈도(획득 점수) :  1 인덱스 :  80
# negative? 테스트 :  16 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  16 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  16 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  32 비교단어 :  매각 등장 빈도(획득점수) :  1 인덱스 :  212
# positive? 테스트 :  13 비교단어 :  호황 등장 빈도(획득 점수) :  1 인덱스 :  44
# negative? 테스트 :  3 비교단어 :  논란 등장 빈도(획득점수) :  1 인덱스 :  142
# positive? 테스트 :  17 비교단어 :  확보 등장 빈도(획득 점수) :  1 인덱스 :  45
# positive? 테스트 :  14 비교단어 :  가치 등장 빈도(획득 점수) :  1 인덱스 :  0
# negative? 테스트 :  8 비교단어 :  충격 등장 빈도(획득점수) :  1 인덱스 :  132
# negative? 테스트 :  21 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  21 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  21 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  19 비교단어 :  가치 등장 빈도(획득 점수) :  1 인덱스 :  0
# negative? 테스트 :  17 비교단어 :  둔화 등장 빈도(획득점수) :  1 인덱스 :  99
# positive? 테스트 :  21 비교단어 :  주목 등장 빈도(획득 점수) :  1 인덱스 :  50
# positive? 테스트 :  20 비교단어 :  성공 등장 빈도(획득 점수) :  1 인덱스 :  18
# negative? 테스트 :  32 비교단어 :  실패 등장 빈도(획득점수) :  1 인덱스 :  111
# negative? 테스트 :  9 비교단어 :  우려 등장 빈도(획득점수) :  1 인덱스 :  190
# positive? 테스트 :  24 비교단어 :  주목 등장 빈도(획득 점수) :  1 인덱스 :  50
# positive? 테스트 :  9 비교단어 :  호황 등장 빈도(획득 점수) :  1 인덱스 :  44
# negative? 테스트 :  3 비교단어 :  논란 등장 빈도(획득점수) :  1 인덱스 :  142
# positive? 테스트 :  14 비교단어 :  수상 등장 빈도(획득 점수) :  1 인덱스 :  54
# negative? 테스트 :  20 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  20 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  20 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  17 비교단어 :  1위 등장 빈도(획득 점수) :  1 인덱스 :  62
# positive? 테스트 :  30 비교단어 :  개선 등장 빈도(획득 점수) :  1 인덱스 :  3
# positive? 테스트 :  42 비교단어 :  돌파 등장 빈도(획득 점수) :  1 인덱스 :  52
# positive? 테스트 :  11 비교단어 :  인기 등장 빈도(획득 점수) :  1 인덱스 :  56
# positive? 테스트 :  11 비교단어 :  인기 등장 빈도(획득 점수) :  1 인덱스 :  71
# negative? 테스트 :  10 비교단어 :  우려 등장 빈도(획득점수) :  1 인덱스 :  190
# negative? 테스트 :  17 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  24 비교단어 :  논란 등장 빈도(획득점수) :  1 인덱스 :  142
# negative? 테스트 :  17 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  17 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  23 비교단어 :  주목 등장 빈도(획득 점수) :  1 인덱스 :  50
# negative? 테스트 :  16 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  16 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  16 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  8 비교단어 :  연기 등장 빈도(획득점수) :  1 인덱스 :  116
# negative? 테스트 :  16 비교단어 :  급락 등장 빈도(획득점수) :  1 인덱스 :  153
# negative? 테스트 :  20 비교단어 :  매각 등장 빈도(획득점수) :  1 인덱스 :  212
# positive? 테스트 :  31 비교단어 :  추진 등장 빈도(획득 점수) :  1 인덱스 :  39
# positive? 테스트 :  4 비교단어 :  호황 등장 빈도(획득 점수) :  1 인덱스 :  44
# positive? 테스트 :  29 비교단어 :  증가 등장 빈도(획득 점수) :  1 인덱스 :  78
# positive? 테스트 :  9 비교단어 :  1위 등장 빈도(획득 점수) :  1 인덱스 :  62
# positive? 테스트 :  20 비교단어 :  대박 등장 빈도(획득 점수) :  1 인덱스 :  59
# negative? 테스트 :  25 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  25 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  25 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  24 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  24 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  24 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  29 비교단어 :  1위 등장 빈도(획득 점수) :  1 인덱스 :  62
# negative? 테스트 :  0 비교단어 :  결국 등장 빈도(획득점수) :  1 인덱스 :  94
# negative? 테스트 :  13 비교단어 :  매각 등장 빈도(획득점수) :  1 인덱스 :  212
# negative? 테스트 :  9 비교단어 :  우려 등장 빈도(획득점수) :  1 인덱스 :  190
# positive? 테스트 :  5 비교단어 :  호황 등장 빈도(획득 점수) :  1 인덱스 :  44
# negative? 테스트 :  11 비교단어 :  우려 등장 빈도(획득점수) :  1 인덱스 :  190
# negative? 테스트 :  24 비교단어 :  우려 등장 빈도(획득점수) :  1 인덱스 :  190
# negative? 테스트 :  15 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  15 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  15 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  14 비교단어 :  경신 등장 빈도(획득 점수) :  1 인덱스 :  6
# positive? 테스트 :  10 비교단어 :  이끄는 등장 빈도(획득 점수) :  1 인덱스 :  28
# negative? 테스트 :  16 비교단어 :  지연 등장 빈도(획득점수) :  1 인덱스 :  128
# negative? 테스트 :  13 비교단어 :  매각 등장 빈도(획득점수) :  1 인덱스 :  212
# positive? 테스트 :  14 비교단어 :  수상 등장 빈도(획득 점수) :  1 인덱스 :  54
# positive? 테스트 :  36 비교단어 :  1위 등장 빈도(획득 점수) :  1 인덱스 :  62
# positive? 테스트 :  10 비교단어 :  활력 등장 빈도(획득 점수) :  1 인덱스 :  46
# positive? 테스트 :  19 비교단어 :  수혜 등장 빈도(획득 점수) :  1 인덱스 :  19
# negative? 테스트 :  22 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  22 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  22 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  24 비교단어 :  주목 등장 빈도(획득 점수) :  1 인덱스 :  50
# negative? 테스트 :  8 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  8 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  8 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  4 비교단어 :  호황 등장 빈도(획득 점수) :  1 인덱스 :  44
# positive? 테스트 :  25 비교단어 :  증가 등장 빈도(획득 점수) :  1 인덱스 :  78
# negative? 테스트 :  18 비교단어 :  리스크 등장 빈도(획득점수) :  1 인덱스 :  151
# negative? 테스트 :  8 비교단어 :  충격 등장 빈도(획득점수) :  1 인덱스 :  132
# negative? 테스트 :  21 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  5 비교단어 :  급락 등장 빈도(획득점수) :  1 인덱스 :  153
# negative? 테스트 :  21 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  21 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  14 비교단어 :  실패 등장 빈도(획득점수) :  1 인덱스 :  111
# negative? 테스트 :  11 비교단어 :  매각 등장 빈도(획득점수) :  1 인덱스 :  212
# negative? 테스트 :  9 비교단어 :  적발 등장 빈도(획득점수) :  1 인덱스 :  162
# negative? 테스트 :  9 비교단어 :  적발 등장 빈도(획득점수) :  1 인덱스 :  198
# negative? 테스트 :  9 비교단어 :  적발 등장 빈도(획득점수) :  1 인덱스 :  208
# positive? 테스트 :  30 비교단어 :  개선 등장 빈도(획득 점수) :  1 인덱스 :  3
# positive? 테스트 :  14 비교단어 :  돌파 등장 빈도(획득 점수) :  1 인덱스 :  52
# positive? 테스트 :  10 비교단어 :  최고 등장 빈도(획득 점수) :  1 인덱스 :  84
# positive? 테스트 :  2 비교단어 :  인기 등장 빈도(획득 점수) :  1 인덱스 :  56
# positive? 테스트 :  2 비교단어 :  인기 등장 빈도(획득 점수) :  1 인덱스 :  71
# positive? 테스트 :  16 비교단어 :  호황 등장 빈도(획득 점수) :  1 인덱스 :  44
# negative? 테스트 :  11 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  11 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  11 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  12 비교단어 :  증대 등장 빈도(획득 점수) :  1 인덱스 :  36
# negative? 테스트 :  26 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  26 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  26 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  37 비교단어 :  개선 등장 빈도(획득 점수) :  1 인덱스 :  3
# positive? 테스트 :  17 비교단어 :  가치 등장 빈도(획득 점수) :  1 인덱스 :  0
# positive? 테스트 :  21 비교단어 :  해결 등장 빈도(획득 점수) :  1 인덱스 :  43
# positive? 테스트 :  32 비교단어 :  적극 등장 빈도(획득 점수) :  1 인덱스 :  32
# negative? 테스트 :  23 비교단어 :  반토막 등장 빈도(획득점수) :  1 인덱스 :  170
# negative? 테스트 :  23 비교단어 :  반토막 등장 빈도(획득점수) :  1 인덱스 :  204
# negative? 테스트 :  3 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  3 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  3 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  8 비교단어 :  급감 등장 빈도(획득점수) :  1 인덱스 :  189
# negative? 테스트 :  19 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  19 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  19 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  2 비교단어 :  주의 등장 빈도(획득점수) :  1 인덱스 :  125
# negative? 테스트 :  16 비교단어 :  실패 등장 빈도(획득점수) :  1 인덱스 :  111
# negative? 테스트 :  10 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  10 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  10 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  10 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  10 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  10 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  5 비교단어 :  충격 등장 빈도(획득점수) :  1 인덱스 :  132
# negative? 테스트 :  29 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  29 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  29 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  25 비교단어 :  체결 등장 빈도(획득 점수) :  1 인덱스 :  77
# positive? 테스트 :  17 비교단어 :  가치 등장 빈도(획득 점수) :  1 인덱스 :  0
# positive? 테스트 :  20 비교단어 :  실현 등장 빈도(획득 점수) :  1 인덱스 :  21
# positive? 테스트 :  29 비교단어 :  증가 등장 빈도(획득 점수) :  1 인덱스 :  78
# negative? 테스트 :  13 비교단어 :  연기 등장 빈도(획득점수) :  1 인덱스 :  116
# negative? 테스트 :  13 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  13 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  13 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  12 비교단어 :  확보 등장 빈도(획득 점수) :  1 인덱스 :  45
# negative? 테스트 :  2 비교단어 :  주의 등장 빈도(획득점수) :  1 인덱스 :  125
# negative? 테스트 :  15 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  15 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  15 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  3 비교단어 :  급락 등장 빈도(획득점수) :  1 인덱스 :  153
# positive? 테스트 :  23 비교단어 :  체결 등장 빈도(획득 점수) :  1 인덱스 :  77
# negative? 테스트 :  20 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  20 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  20 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  17 비교단어 :  체결 등장 빈도(획득 점수) :  1 인덱스 :  77
# positive? 테스트 :  12 비교단어 :  돌파 등장 빈도(획득 점수) :  1 인덱스 :  52
# negative? 테스트 :  23 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  23 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  23 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  17 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  17 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  17 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  18 비교단어 :  매각 등장 빈도(획득점수) :  1 인덱스 :  212
# negative? 테스트 :  21 비교단어 :  연기 등장 빈도(획득점수) :  1 인덱스 :  116
# negative? 테스트 :  11 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  11 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  11 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  18 비교단어 :  빨간불 등장 빈도(획득점수) :  1 인덱스 :  164
# positive? 테스트 :  20 비교단어 :  해결 등장 빈도(획득 점수) :  1 인덱스 :  43
# negative? 테스트 :  18 비교단어 :  문제 등장 빈도(획득점수) :  1 인덱스 :  174
# positive? 테스트 :  29 비교단어 :  돌파 등장 빈도(획득 점수) :  1 인덱스 :  52
# positive? 테스트 :  1 비교단어 :  인기 등장 빈도(획득 점수) :  1 인덱스 :  56
# positive? 테스트 :  1 비교단어 :  인기 등장 빈도(획득 점수) :  1 인덱스 :  71
# negative? 테스트 :  24 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  24 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  24 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  29 비교단어 :  차질 등장 빈도(획득점수) :  1 인덱스 :  130
# negative? 테스트 :  20 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  20 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  20 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  20 비교단어 :  급락 등장 빈도(획득점수) :  1 인덱스 :  153
# negative? 테스트 :  19 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  19 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  19 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  15 비교단어 :  경신 등장 빈도(획득 점수) :  1 인덱스 :  6
# positive? 테스트 :  8 비교단어 :  트렌드 등장 빈도(획득 점수) :  1 인덱스 :  73
# positive? 테스트 :  13 비교단어 :  경신 등장 빈도(획득 점수) :  1 인덱스 :  6
# negative? 테스트 :  10 비교단어 :  중단 등장 빈도(획득점수) :  1 인덱스 :  191
# positive? 테스트 :  17 비교단어 :  수혜 등장 빈도(획득 점수) :  1 인덱스 :  19
# negative? 테스트 :  10 비교단어 :  중단 등장 빈도(획득점수) :  1 인덱스 :  191
# negative? 테스트 :  15 비교단어 :  급락 등장 빈도(획득점수) :  1 인덱스 :  153
# positive? 테스트 :  17 비교단어 :  체결 등장 빈도(획득 점수) :  1 인덱스 :  77
# negative? 테스트 :  17 비교단어 :  여파 등장 빈도(획득점수) :  1 인덱스 :  115
# negative? 테스트 :  14 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  14 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  17 비교단어 :  여파 등장 빈도(획득점수) :  1 인덱스 :  186
# negative? 테스트 :  14 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  28 비교단어 :  돌파 등장 빈도(획득 점수) :  1 인덱스 :  52
# negative? 테스트 :  30 비교단어 :  둔화 등장 빈도(획득점수) :  1 인덱스 :  99
# negative? 테스트 :  8 비교단어 :  여파 등장 빈도(획득점수) :  1 인덱스 :  115
# negative? 테스트 :  5 비교단어 :  급락 등장 빈도(획득점수) :  1 인덱스 :  153
# negative? 테스트 :  8 비교단어 :  여파 등장 빈도(획득점수) :  1 인덱스 :  186
# positive? 테스트 :  26 비교단어 :  체결 등장 빈도(획득 점수) :  1 인덱스 :  77
# negative? 테스트 :  15 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  15 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  15 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  34 비교단어 :  1위 등장 빈도(획득 점수) :  1 인덱스 :  62
# positive? 테스트 :  17 비교단어 :  주목 등장 빈도(획득 점수) :  1 인덱스 :  50
# positive? 테스트 :  9 비교단어 :  실현 등장 빈도(획득 점수) :  1 인덱스 :  21
# negative? 테스트 :  5 비교단어 :  주의 등장 빈도(획득점수) :  1 인덱스 :  125
# negative? 테스트 :  18 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  18 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  18 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  7 비교단어 :  경신 등장 빈도(획득 점수) :  1 인덱스 :  6
# negative? 테스트 :  25 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  25 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  25 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  8 비교단어 :  충격 등장 빈도(획득점수) :  1 인덱스 :  132
# negative? 테스트 :  34 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  5 비교단어 :  급락 등장 빈도(획득점수) :  1 인덱스 :  153
# negative? 테스트 :  34 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  34 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  33 비교단어 :  최고 등장 빈도(획득 점수) :  1 인덱스 :  84
# negative? 테스트 :  12 비교단어 :  여파 등장 빈도(획득점수) :  1 인덱스 :  115
# negative? 테스트 :  9 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  9 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  12 비교단어 :  여파 등장 빈도(획득점수) :  1 인덱스 :  186
# negative? 테스트 :  9 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  19 비교단어 :  강세 등장 빈도(획득 점수) :  1 인덱스 :  2
# negative? 테스트 :  4 비교단어 :  결국 등장 빈도(획득점수) :  1 인덱스 :  94
# negative? 테스트 :  17 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  17 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  17 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  8 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  8 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  8 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  8 비교단어 :  급감 등장 빈도(획득점수) :  1 인덱스 :  189
# negative? 테스트 :  4 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  4 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  4 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  11 비교단어 :  개선 등장 빈도(획득 점수) :  1 인덱스 :  3
# positive? 테스트 :  11 비교단어 :  개선된 등장 빈도(획득 점수) :  1 인덱스 :  4
# negative? 테스트 :  12 비교단어 :  훼손 등장 빈도(획득점수) :  1 인덱스 :  140
# negative? 테스트 :  20 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  20 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  20 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  29 비교단어 :  진출 등장 빈도(획득 점수) :  1 인덱스 :  75
# positive? 테스트 :  30 비교단어 :  최고 등장 빈도(획득 점수) :  1 인덱스 :  84
# negative? 테스트 :  7 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  7 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  7 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  24 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  24 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  24 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  35 비교단어 :  증가 등장 빈도(획득 점수) :  1 인덱스 :  78
# negative? 테스트 :  8 비교단어 :  충격 등장 빈도(획득점수) :  1 인덱스 :  132
# negative? 테스트 :  12 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  12 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  12 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  11 비교단어 :  실패 등장 빈도(획득점수) :  1 인덱스 :  111
# negative? 테스트 :  21 비교단어 :  리스크 등장 빈도(획득점수) :  1 인덱스 :  151
# negative? 테스트 :  20 비교단어 :  빨간불 등장 빈도(획득점수) :  1 인덱스 :  164
# positive? 테스트 :  25 비교단어 :  장점 등장 빈도(획득 점수) :  1 인덱스 :  31
# negative? 테스트 :  7 비교단어 :  리스크 등장 빈도(획득점수) :  1 인덱스 :  151
# positive? 테스트 :  29 비교단어 :  최고 등장 빈도(획득 점수) :  1 인덱스 :  84
# positive? 테스트 :  29 비교단어 :  돌파 등장 빈도(획득 점수) :  1 인덱스 :  52
# positive? 테스트 :  17 비교단어 :  최고 등장 빈도(획득 점수) :  1 인덱스 :  84
# positive? 테스트 :  14 비교단어 :  수상 등장 빈도(획득 점수) :  1 인덱스 :  54
# positive? 테스트 :  32 비교단어 :  증가 등장 빈도(획득 점수) :  1 인덱스 :  78
# negative? 테스트 :  15 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  15 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  15 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  8 비교단어 :  불똥 등장 빈도(획득점수) :  1 인덱스 :  177
# negative? 테스트 :  2 비교단어 :  리스크 등장 빈도(획득점수) :  1 인덱스 :  151
# positive? 테스트 :  27 비교단어 :  증가 등장 빈도(획득 점수) :  1 인덱스 :  78
# negative? 테스트 :  17 비교단어 :  급락 등장 빈도(획득점수) :  1 인덱스 :  153
# negative? 테스트 :  8 비교단어 :  우려 등장 빈도(획득점수) :  1 인덱스 :  190
# negative? 테스트 :  6 비교단어 :  리스크 등장 빈도(획득점수) :  1 인덱스 :  151
# negative? 테스트 :  9 비교단어 :  우려 등장 빈도(획득점수) :  1 인덱스 :  190
# positive? 테스트 :  27 비교단어 :  활성화 등장 빈도(획득 점수) :  1 인덱스 :  47
# negative? 테스트 :  7 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  7 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  7 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  21 비교단어 :  여파 등장 빈도(획득점수) :  1 인덱스 :  115
# negative? 테스트 :  21 비교단어 :  여파 등장 빈도(획득점수) :  1 인덱스 :  186
# negative? 테스트 :  17 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  17 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  17 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  10 비교단어 :  돌파 등장 빈도(획득 점수) :  1 인덱스 :  52
# positive? 테스트 :  31 비교단어 :  강세 등장 빈도(획득 점수) :  1 인덱스 :  2
# negative? 테스트 :  4 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  4 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  4 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  12 비교단어 :  우려 등장 빈도(획득점수) :  1 인덱스 :  190
# positive? 테스트 :  11 비교단어 :  주목 등장 빈도(획득 점수) :  1 인덱스 :  50
# negative? 테스트 :  25 비교단어 :  우려 등장 빈도(획득점수) :  1 인덱스 :  190
# negative? 테스트 :  0 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  0 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  0 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  20 비교단어 :  출시 등장 빈도(획득 점수) :  1 인덱스 :  63
# negative? 테스트 :  29 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  29 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  29 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  5 비교단어 :  반토막 등장 빈도(획득점수) :  1 인덱스 :  170
# negative? 테스트 :  5 비교단어 :  반토막 등장 빈도(획득점수) :  1 인덱스 :  204
# positive? 테스트 :  16 비교단어 :  돌파 등장 빈도(획득 점수) :  1 인덱스 :  52
# negative? 테스트 :  27 비교단어 :  실패 등장 빈도(획득점수) :  1 인덱스 :  111
# negative? 테스트 :  33 비교단어 :  우려 등장 빈도(획득점수) :  1 인덱스 :  190
# negative? 테스트 :  9 비교단어 :  우려 등장 빈도(획득점수) :  1 인덱스 :  190
# positive? 테스트 :  7 비교단어 :  강세 등장 빈도(획득 점수) :  1 인덱스 :  2
# positive? 테스트 :  7 비교단어 :  추천 등장 빈도(획득 점수) :  1 인덱스 :  40
# negative? 테스트 :  6 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  6 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  6 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  11 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  11 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  11 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  23 비교단어 :  1위 등장 빈도(획득 점수) :  1 인덱스 :  62
# negative? 테스트 :  9 비교단어 :  우려 등장 빈도(획득점수) :  1 인덱스 :  190
# negative? 테스트 :  10 비교단어 :  여파 등장 빈도(획득점수) :  1 인덱스 :  115
# negative? 테스트 :  7 비교단어 :  급락 등장 빈도(획득점수) :  1 인덱스 :  153
# negative? 테스트 :  10 비교단어 :  여파 등장 빈도(획득점수) :  1 인덱스 :  186
# negative? 테스트 :  9 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  9 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  9 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  17 비교단어 :  강세 등장 빈도(획득 점수) :  1 인덱스 :  2
# positive? 테스트 :  30 비교단어 :  돌파 등장 빈도(획득 점수) :  1 인덱스 :  52
# positive? 테스트 :  21 비교단어 :  실현 등장 빈도(획득 점수) :  1 인덱스 :  21
# negative? 테스트 :  12 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  12 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  12 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  19 비교단어 :  우려 등장 빈도(획득점수) :  1 인덱스 :  190
# negative? 테스트 :  8 비교단어 :  여파 등장 빈도(획득점수) :  1 인덱스 :  115
# negative? 테스트 :  8 비교단어 :  여파 등장 빈도(획득점수) :  1 인덱스 :  186
# negative? 테스트 :  10 비교단어 :  우려 등장 빈도(획득점수) :  1 인덱스 :  190
# positive? 테스트 :  24 비교단어 :  증가 등장 빈도(획득 점수) :  1 인덱스 :  78
# positive? 테스트 :  25 비교단어 :  실현 등장 빈도(획득 점수) :  1 인덱스 :  21
# positive? 테스트 :  12 비교단어 :  성공 등장 빈도(획득 점수) :  1 인덱스 :  18
# positive? 테스트 :  33 비교단어 :  돌파 등장 빈도(획득 점수) :  1 인덱스 :  52
# positive? 테스트 :  20 비교단어 :  성공 등장 빈도(획득 점수) :  1 인덱스 :  18
# positive? 테스트 :  34 비교단어 :  돌파 등장 빈도(획득 점수) :  1 인덱스 :  52
# negative? 테스트 :  11 비교단어 :  리스크 등장 빈도(획득점수) :  1 인덱스 :  151
# positive? 테스트 :  24 비교단어 :  개선 등장 빈도(획득 점수) :  1 인덱스 :  3
# positive? 테스트 :  18 비교단어 :  출시 등장 빈도(획득 점수) :  1 인덱스 :  63
# negative? 테스트 :  22 비교단어 :  충격 등장 빈도(획득점수) :  1 인덱스 :  132
# negative? 테스트 :  11 비교단어 :  충격 등장 빈도(획득점수) :  1 인덱스 :  132
# negative? 테스트 :  11 비교단어 :  충격 등장 빈도(획득점수) :  1 인덱스 :  132
# negative? 테스트 :  34 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  34 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  34 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  21 비교단어 :  급감 등장 빈도(획득점수) :  1 인덱스 :  189
# positive? 테스트 :  9 비교단어 :  돌파 등장 빈도(획득 점수) :  1 인덱스 :  52
# negative? 테스트 :  12 비교단어 :  여파 등장 빈도(획득점수) :  1 인덱스 :  115
# negative? 테스트 :  29 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  29 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  12 비교단어 :  여파 등장 빈도(획득점수) :  1 인덱스 :  186
# negative? 테스트 :  29 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  24 비교단어 :  리스크 등장 빈도(획득점수) :  1 인덱스 :  151
# negative? 테스트 :  33 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  33 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  33 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  32 비교단어 :  강세 등장 빈도(획득 점수) :  1 인덱스 :  2
# negative? 테스트 :  14 비교단어 :  우려 등장 빈도(획득점수) :  1 인덱스 :  190
# negative? 테스트 :  25 비교단어 :  둔화 등장 빈도(획득점수) :  1 인덱스 :  99
# negative? 테스트 :  15 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  15 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  15 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  30 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  30 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  30 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  18 비교단어 :  논란 등장 빈도(획득점수) :  1 인덱스 :  142
# negative? 테스트 :  5 비교단어 :  우려 등장 빈도(획득점수) :  1 인덱스 :  190
# positive? 테스트 :  17 비교단어 :  돌파 등장 빈도(획득 점수) :  1 인덱스 :  52
# negative? 테스트 :  8 비교단어 :  여파 등장 빈도(획득점수) :  1 인덱스 :  115
# negative? 테스트 :  8 비교단어 :  여파 등장 빈도(획득점수) :  1 인덱스 :  186
# negative? 테스트 :  16 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  16 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  16 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  27 비교단어 :  개선 등장 빈도(획득 점수) :  1 인덱스 :  3
# negative? 테스트 :  6 비교단어 :  한숨 등장 빈도(획득점수) :  1 인덱스 :  176
# negative? 테스트 :  11 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  11 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  11 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  11 비교단어 :  불똥 등장 빈도(획득점수) :  1 인덱스 :  177
# negative? 테스트 :  20 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  20 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  20 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  18 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  10 비교단어 :  리스크 등장 빈도(획득점수) :  1 인덱스 :  151
# negative? 테스트 :  18 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  18 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  19 비교단어 :  증가 등장 빈도(획득 점수) :  1 인덱스 :  78
# negative? 테스트 :  4 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  4 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  4 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  11 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  11 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  11 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  22 비교단어 :  호황 등장 빈도(획득 점수) :  1 인덱스 :  44
# negative? 테스트 :  11 비교단어 :  하락 등장 빈도(획득점수) :  2 인덱스 :  137
# negative? 테스트 :  11 비교단어 :  하락 등장 빈도(획득점수) :  2 인덱스 :  154
# negative? 테스트 :  11 비교단어 :  하락 등장 빈도(획득점수) :  2 인덱스 :  202
# negative? 테스트 :  23 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  23 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  23 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  5 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  5 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  5 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  23 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  23 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  23 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  4 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  4 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  4 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  22 비교단어 :  급락 등장 빈도(획득점수) :  1 인덱스 :  153
# negative? 테스트 :  21 비교단어 :  급락 등장 빈도(획득점수) :  1 인덱스 :  153
# negative? 테스트 :  13 비교단어 :  직격탄 등장 빈도(획득점수) :  1 인덱스 :  175
# negative? 테스트 :  21 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  21 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  17 비교단어 :  우려 등장 빈도(획득점수) :  1 인덱스 :  190
# negative? 테스트 :  21 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  14 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  14 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  14 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  12 비교단어 :  여파 등장 빈도(획득점수) :  1 인덱스 :  115
# negative? 테스트 :  9 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  9 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  12 비교단어 :  여파 등장 빈도(획득점수) :  1 인덱스 :  186
# negative? 테스트 :  9 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  13 비교단어 :  급락 등장 빈도(획득점수) :  1 인덱스 :  153
# negative? 테스트 :  12 비교단어 :  우려 등장 빈도(획득점수) :  1 인덱스 :  190
# negative? 테스트 :  8 비교단어 :  불똥 등장 빈도(획득점수) :  1 인덱스 :  177
# negative? 테스트 :  15 비교단어 :  퇴출 등장 빈도(획득점수) :  1 인덱스 :  192
# negative? 테스트 :  9 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  9 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  9 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  9 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  9 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  9 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  27 비교단어 :  출시 등장 빈도(획득 점수) :  1 인덱스 :  63
# positive? 테스트 :  8 비교단어 :  강세 등장 빈도(획득 점수) :  1 인덱스 :  2
# negative? 테스트 :  9 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  9 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  9 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  29 비교단어 :  우려 등장 빈도(획득점수) :  1 인덱스 :  190
# positive? 테스트 :  9 비교단어 :  호황 등장 빈도(획득 점수) :  1 인덱스 :  44
# negative? 테스트 :  13 비교단어 :  우려 등장 빈도(획득점수) :  1 인덱스 :  190
# negative? 테스트 :  15 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  15 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  15 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  33 비교단어 :  진출 등장 빈도(획득 점수) :  1 인덱스 :  75
# negative? 테스트 :  12 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  12 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  12 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  9 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  9 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  9 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  13 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  13 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  13 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  14 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  14 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  14 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  25 비교단어 :  우려 등장 빈도(획득점수) :  1 인덱스 :  190
# negative? 테스트 :  15 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  15 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  15 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  13 비교단어 :  여파 등장 빈도(획득점수) :  1 인덱스 :  115
# negative? 테스트 :  10 비교단어 :  급락 등장 빈도(획득점수) :  1 인덱스 :  153
# negative? 테스트 :  13 비교단어 :  여파 등장 빈도(획득점수) :  1 인덱스 :  186
# positive? 테스트 :  7 비교단어 :  호황 등장 빈도(획득 점수) :  1 인덱스 :  44
# positive? 테스트 :  19 비교단어 :  증가 등장 빈도(획득 점수) :  1 인덱스 :  78
# negative? 테스트 :  8 비교단어 :  여파 등장 빈도(획득점수) :  1 인덱스 :  115
# negative? 테스트 :  5 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  5 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  8 비교단어 :  여파 등장 빈도(획득점수) :  1 인덱스 :  186
# negative? 테스트 :  5 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  5 비교단어 :  호황 등장 빈도(획득 점수) :  1 인덱스 :  44
# negative? 테스트 :  13 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  13 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  13 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  14 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  14 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  14 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  28 비교단어 :  둔화 등장 빈도(획득점수) :  1 인덱스 :  99
# positive? 테스트 :  23 비교단어 :  강세 등장 빈도(획득 점수) :  1 인덱스 :  2
# negative? 테스트 :  15 비교단어 :  둔화 등장 빈도(획득점수) :  1 인덱스 :  99
# positive? 테스트 :  19 비교단어 :  강세 등장 빈도(획득 점수) :  1 인덱스 :  2
# positive? 테스트 :  18 비교단어 :  경신 등장 빈도(획득 점수) :  1 인덱스 :  6
# positive? 테스트 :  29 비교단어 :  돌파 등장 빈도(획득 점수) :  1 인덱스 :  52
# positive? 테스트 :  14 비교단어 :  최고 등장 빈도(획득 점수) :  1 인덱스 :  84
# negative? 테스트 :  21 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  21 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  21 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  31 비교단어 :  문제 등장 빈도(획득점수) :  1 인덱스 :  174
# negative? 테스트 :  14 비교단어 :  우려 등장 빈도(획득점수) :  1 인덱스 :  190
# positive? 테스트 :  13 비교단어 :  인기 등장 빈도(획득 점수) :  1 인덱스 :  56
# positive? 테스트 :  13 비교단어 :  인기 등장 빈도(획득 점수) :  1 인덱스 :  71
# negative? 테스트 :  7 비교단어 :  급락 등장 빈도(획득점수) :  1 인덱스 :  153
# negative? 테스트 :  14 비교단어 :  급락 등장 빈도(획득점수) :  1 인덱스 :  153
# negative? 테스트 :  15 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  15 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  15 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  9 비교단어 :  최고 등장 빈도(획득 점수) :  1 인덱스 :  84
# negative? 테스트 :  15 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  15 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  15 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  8 비교단어 :  충격 등장 빈도(획득점수) :  1 인덱스 :  132
# negative? 테스트 :  15 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  15 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  15 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  24 비교단어 :  추진 등장 빈도(획득 점수) :  1 인덱스 :  39
# negative? 테스트 :  11 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  11 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  11 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  22 비교단어 :  최고 등장 빈도(획득 점수) :  1 인덱스 :  84
# negative? 테스트 :  32 비교단어 :  급락 등장 빈도(획득점수) :  1 인덱스 :  153
# negative? 테스트 :  8 비교단어 :  충격 등장 빈도(획득점수) :  1 인덱스 :  132
# negative? 테스트 :  20 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  20 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  20 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  15 비교단어 :  증가 등장 빈도(획득 점수) :  1 인덱스 :  78
# negative? 테스트 :  24 비교단어 :  둔화 등장 빈도(획득점수) :  1 인덱스 :  99
# positive? 테스트 :  4 비교단어 :  호황 등장 빈도(획득 점수) :  1 인덱스 :  44
# positive? 테스트 :  10 비교단어 :  돌파 등장 빈도(획득 점수) :  1 인덱스 :  52
# positive? 테스트 :  17 비교단어 :  최고 등장 빈도(획득 점수) :  1 인덱스 :  84
# negative? 테스트 :  17 비교단어 :  급락 등장 빈도(획득점수) :  1 인덱스 :  153
# positive? 테스트 :  25 비교단어 :  1위 등장 빈도(획득 점수) :  1 인덱스 :  62
# positive? 테스트 :  18 비교단어 :  최고 등장 빈도(획득 점수) :  1 인덱스 :  84
# negative? 테스트 :  21 비교단어 :  우려 등장 빈도(획득점수) :  1 인덱스 :  190
# negative? 테스트 :  25 비교단어 :  논란 등장 빈도(획득점수) :  1 인덱스 :  142
# negative? 테스트 :  26 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  26 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  26 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  33 비교단어 :  주목 등장 빈도(획득 점수) :  1 인덱스 :  50
# negative? 테스트 :  15 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  15 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  15 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  23 비교단어 :  돌파 등장 빈도(획득 점수) :  1 인덱스 :  52
# negative? 테스트 :  23 비교단어 :  급락 등장 빈도(획득점수) :  1 인덱스 :  153
# positive? 테스트 :  25 비교단어 :  주목 등장 빈도(획득 점수) :  1 인덱스 :  50
# negative? 테스트 :  16 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  16 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  16 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  15 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  15 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  15 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  16 비교단어 :  1위 등장 빈도(획득 점수) :  1 인덱스 :  62
# positive? 테스트 :  19 비교단어 :  실현 등장 빈도(획득 점수) :  1 인덱스 :  21
# positive? 테스트 :  10 비교단어 :  돌파 등장 빈도(획득 점수) :  1 인덱스 :  52
# ...
# negative? 테스트 :  15 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  11 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  11 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  11 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  15 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  15 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  15 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  10 비교단어 :  우려 등장 빈도(획득점수) :  1 인덱스 :  190
# positive? 테스트 :  14 비교단어 :  주목 등장 빈도(획득 점수) :  1 인덱스 :  50
# positive? 테스트 :  14 비교단어 :  주목 등장 빈도(획득 점수) :  1 인덱스 :  50
# negative? 테스트 :  11 비교단어 :  우려 등장 빈도(획득점수) :  1 인덱스 :  190
# negative? 테스트 :  21 비교단어 :  급락 등장 빈도(획득점수) :  1 인덱스 :  153
# negative? 테스트 :  27 비교단어 :  소송 등장 빈도(획득점수) :  1 인덱스 :  201
# negative? 테스트 :  30 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  30 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  30 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  30 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  30 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  30 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  11 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  11 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  11 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  7 비교단어 :  성공 등장 빈도(획득 점수) :  1 인덱스 :  18
# negative? 테스트 :  18 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  18 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  18 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  18 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  18 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  18 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  17 비교단어 :  둔화 등장 빈도(획득점수) :  1 인덱스 :  99
# negative? 테스트 :  20 비교단어 :  우려 등장 빈도(획득점수) :  1 인덱스 :  190
# positive? 테스트 :  18 비교단어 :  강세 등장 빈도(획득 점수) :  1 인덱스 :  2
# negative? 테스트 :  18 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  18 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  18 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  18 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  18 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  18 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  23 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  23 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  23 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  23 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  23 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  23 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  10 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  10 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  10 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  27 비교단어 :  급락 등장 빈도(획득점수) :  1 인덱스 :  153
# negative? 테스트 :  21 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  21 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  21 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  14 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  14 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  14 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  19 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  19 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  19 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  24 비교단어 :  출시 등장 빈도(획득 점수) :  1 인덱스 :  63
# positive? 테스트 :  24 비교단어 :  출시 등장 빈도(획득 점수) :  1 인덱스 :  63
# negative? 테스트 :  18 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  18 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  18 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  19 비교단어 :  강세 등장 빈도(획득 점수) :  1 인덱스 :  2
# positive? 테스트 :  19 비교단어 :  강세 등장 빈도(획득 점수) :  1 인덱스 :  2
# negative? 테스트 :  13 비교단어 :  차질 등장 빈도(획득점수) :  1 인덱스 :  130
# negative? 테스트 :  25 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  3 비교단어 :  리스크 등장 빈도(획득점수) :  1 인덱스 :  151
# negative? 테스트 :  25 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  25 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  26 비교단어 :  성공 등장 빈도(획득 점수) :  1 인덱스 :  18
# positive? 테스트 :  26 비교단어 :  강세 등장 빈도(획득 점수) :  1 인덱스 :  2
# negative? 테스트 :  17 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  17 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  17 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  10 비교단어 :  대박 등장 빈도(획득 점수) :  1 인덱스 :  59
# negative? 테스트 :  4 비교단어 :  눈물 등장 빈도(획득점수) :  1 인덱스 :  146
# negative? 테스트 :  18 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  18 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  18 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  25 비교단어 :  돌파 등장 빈도(획득 점수) :  1 인덱스 :  52
# negative? 테스트 :  22 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  22 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  22 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  15 비교단어 :  진출 등장 빈도(획득 점수) :  1 인덱스 :  75
# positive? 테스트 :  8 비교단어 :  기부 등장 빈도(획득 점수) :  1 인덱스 :  80
# positive? 테스트 :  24 비교단어 :  강세 등장 빈도(획득 점수) :  1 인덱스 :  2
# negative? 테스트 :  30 비교단어 :  문제 등장 빈도(획득점수) :  1 인덱스 :  174
# positive? 테스트 :  21 비교단어 :  강세 등장 빈도(획득 점수) :  1 인덱스 :  2
# negative? 테스트 :  15 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  15 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  15 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  14 비교단어 :  진출 등장 빈도(획득 점수) :  1 인덱스 :  75
# negative? 테스트 :  8 비교단어 :  둔화 등장 빈도(획득점수) :  1 인덱스 :  99
# negative? 테스트 :  21 비교단어 :  급락 등장 빈도(획득점수) :  1 인덱스 :  153
# negative? 테스트 :  11 비교단어 :  우려 등장 빈도(획득점수) :  1 인덱스 :  190
# negative? 테스트 :  8 비교단어 :  둔화 등장 빈도(획득점수) :  1 인덱스 :  99
# negative? 테스트 :  11 비교단어 :  우려 등장 빈도(획득점수) :  1 인덱스 :  190
# negative? 테스트 :  29 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  29 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  29 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  14 비교단어 :  진출 등장 빈도(획득 점수) :  1 인덱스 :  75
# negative? 테스트 :  8 비교단어 :  둔화 등장 빈도(획득점수) :  1 인덱스 :  99
# negative? 테스트 :  21 비교단어 :  급락 등장 빈도(획득점수) :  1 인덱스 :  153
# negative? 테스트 :  11 비교단어 :  우려 등장 빈도(획득점수) :  1 인덱스 :  190
# negative? 테스트 :  8 비교단어 :  둔화 등장 빈도(획득점수) :  1 인덱스 :  99
# negative? 테스트 :  11 비교단어 :  우려 등장 빈도(획득점수) :  1 인덱스 :  190
# negative? 테스트 :  29 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  29 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  29 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  29 비교단어 :  강세 등장 빈도(획득 점수) :  1 인덱스 :  2
# positive? 테스트 :  12 비교단어 :  진출 등장 빈도(획득 점수) :  1 인덱스 :  75
# positive? 테스트 :  33 비교단어 :  체결 등장 빈도(획득 점수) :  1 인덱스 :  77
# positive? 테스트 :  10 비교단어 :  대박 등장 빈도(획득 점수) :  1 인덱스 :  59
# positive? 테스트 :  34 비교단어 :  수상 등장 빈도(획득 점수) :  1 인덱스 :  54
# positive? 테스트 :  28 비교단어 :  체결 등장 빈도(획득 점수) :  1 인덱스 :  77
# positive? 테스트 :  15 비교단어 :  진출 등장 빈도(획득 점수) :  1 인덱스 :  75
# negative? 테스트 :  18 비교단어 :  충격 등장 빈도(획득점수) :  1 인덱스 :  132
# negative? 테스트 :  25 비교단어 :  급락 등장 빈도(획득점수) :  1 인덱스 :  153
# negative? 테스트 :  0 비교단어 :  우려 등장 빈도(획득점수) :  1 인덱스 :  190
# positive? 테스트 :  26 비교단어 :  최고 등장 빈도(획득 점수) :  1 인덱스 :  84
# positive? 테스트 :  21 비교단어 :  1위 등장 빈도(획득 점수) :  1 인덱스 :  62
# positive? 테스트 :  27 비교단어 :  강세 등장 빈도(획득 점수) :  1 인덱스 :  2
# negative? 테스트 :  25 비교단어 :  우려 등장 빈도(획득점수) :  1 인덱스 :  190
# positive? 테스트 :  25 비교단어 :  적극 등장 빈도(획득 점수) :  1 인덱스 :  32
# positive? 테스트 :  7 비교단어 :  1위 등장 빈도(획득 점수) :  1 인덱스 :  62
# positive? 테스트 :  19 비교단어 :  1위 등장 빈도(획득 점수) :  1 인덱스 :  62
# negative? 테스트 :  24 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  24 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  24 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  26 비교단어 :  출시 등장 빈도(획득 점수) :  1 인덱스 :  63
# negative? 테스트 :  22 비교단어 :  급락 등장 빈도(획득점수) :  1 인덱스 :  153
# negative? 테스트 :  16 비교단어 :  악화 등장 빈도(획득점수) :  1 인덱스 :  112
# positive? 테스트 :  19 비교단어 :  1위 등장 빈도(획득 점수) :  1 인덱스 :  62
# negative? 테스트 :  24 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  24 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  24 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  26 비교단어 :  출시 등장 빈도(획득 점수) :  1 인덱스 :  63
# negative? 테스트 :  22 비교단어 :  급락 등장 빈도(획득점수) :  1 인덱스 :  153
# negative? 테스트 :  16 비교단어 :  악화 등장 빈도(획득점수) :  1 인덱스 :  112
# negative? 테스트 :  22 비교단어 :  급락 등장 빈도(획득점수) :  1 인덱스 :  153
# negative? 테스트 :  16 비교단어 :  악화 등장 빈도(획득점수) :  1 인덱스 :  112
# positive? 테스트 :  28 비교단어 :  기부 등장 빈도(획득 점수) :  1 인덱스 :  80
# positive? 테스트 :  17 비교단어 :  성공 등장 빈도(획득 점수) :  1 인덱스 :  18
# negative? 테스트 :  0 비교단어 :  우려 등장 빈도(획득점수) :  1 인덱스 :  190
# positive? 테스트 :  19 비교단어 :  출시 등장 빈도(획득 점수) :  1 인덱스 :  63
# positive? 테스트 :  25 비교단어 :  1위 등장 빈도(획득 점수) :  1 인덱스 :  62
# negative? 테스트 :  30 비교단어 :  우려 등장 빈도(획득점수) :  1 인덱스 :  190
# positive? 테스트 :  16 비교단어 :  장점 등장 빈도(획득 점수) :  1 인덱스 :  31
# positive? 테스트 :  24 비교단어 :  돌파 등장 빈도(획득 점수) :  1 인덱스 :  52
# negative? 테스트 :  26 비교단어 :  급락 등장 빈도(획득점수) :  1 인덱스 :  153
# negative? 테스트 :  17 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  17 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  17 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  18 비교단어 :  초라한 등장 빈도(획득점수) :  1 인덱스 :  131
# positive? 테스트 :  25 비교단어 :  1위 등장 빈도(획득 점수) :  1 인덱스 :  62
# negative? 테스트 :  10 비교단어 :  한숨 등장 빈도(획득점수) :  1 인덱스 :  176
# positive? 테스트 :  14 비교단어 :  수혜 등장 빈도(획득 점수) :  1 인덱스 :  19
# positive? 테스트 :  22 비교단어 :  주목 등장 빈도(획득 점수) :  1 인덱스 :  50
# positive? 테스트 :  25 비교단어 :  순항 등장 빈도(획득 점수) :  1 인덱스 :  60
# positive? 테스트 :  25 비교단어 :  순항 등장 빈도(획득 점수) :  1 인덱스 :  91
# negative? 테스트 :  19 비교단어 :  급락 등장 빈도(획득점수) :  1 인덱스 :  153
# negative? 테스트 :  22 비교단어 :  급락 등장 빈도(획득점수) :  1 인덱스 :  153
# negative? 테스트 :  20 비교단어 :  논란 등장 빈도(획득점수) :  1 인덱스 :  142
# positive? 테스트 :  20 비교단어 :  성공 등장 빈도(획득 점수) :  1 인덱스 :  18
# positive? 테스트 :  18 비교단어 :  출시 등장 빈도(획득 점수) :  1 인덱스 :  63
# positive? 테스트 :  11 비교단어 :  진출 등장 빈도(획득 점수) :  1 인덱스 :  75
# positive? 테스트 :  5 비교단어 :  주목 등장 빈도(획득 점수) :  1 인덱스 :  50
# positive? 테스트 :  14 비교단어 :  열풍 등장 빈도(획득 점수) :  1 인덱스 :  57
# positive? 테스트 :  33 비교단어 :  최고 등장 빈도(획득 점수) :  1 인덱스 :  84
# positive? 테스트 :  25 비교단어 :  돌파 등장 빈도(획득 점수) :  1 인덱스 :  52
# positive? 테스트 :  17 비교단어 :  1위 등장 빈도(획득 점수) :  1 인덱스 :  62
# negative? 테스트 :  4 비교단어 :  우려 등장 빈도(획득점수) :  1 인덱스 :  190
# positive? 테스트 :  18 비교단어 :  최고 등장 빈도(획득 점수) :  1 인덱스 :  84
# positive? 테스트 :  18 비교단어 :  최고 등장 빈도(획득 점수) :  1 인덱스 :  84
# negative? 테스트 :  25 비교단어 :  급락 등장 빈도(획득점수) :  1 인덱스 :  153
# positive? 테스트 :  8 비교단어 :  강세 등장 빈도(획득 점수) :  1 인덱스 :  2
# negative? 테스트 :  6 비교단어 :  연기 등장 빈도(획득점수) :  1 인덱스 :  116
# positive? 테스트 :  34 비교단어 :  강세 등장 빈도(획득 점수) :  1 인덱스 :  2
# positive? 테스트 :  20 비교단어 :  적극 등장 빈도(획득 점수) :  1 인덱스 :  32
# positive? 테스트 :  15 비교단어 :  출시 등장 빈도(획득 점수) :  1 인덱스 :  63
# positive? 테스트 :  2 비교단어 :  대박 등장 빈도(획득 점수) :  1 인덱스 :  59
# positive? 테스트 :  28 비교단어 :  개선 등장 빈도(획득 점수) :  1 인덱스 :  3
# positive? 테스트 :  30 비교단어 :  트렌드 등장 빈도(획득 점수) :  1 인덱스 :  73
# positive? 테스트 :  9 비교단어 :  출시 등장 빈도(획득 점수) :  1 인덱스 :  63
# positive? 테스트 :  12 비교단어 :  돌파 등장 빈도(획득 점수) :  1 인덱스 :  52
# negative? 테스트 :  13 비교단어 :  급락 등장 빈도(획득점수) :  1 인덱스 :  153
# negative? 테스트 :  27 비교단어 :  울상 등장 빈도(획득점수) :  1 인덱스 :  187
# negative? 테스트 :  13 비교단어 :  급락 등장 빈도(획득점수) :  1 인덱스 :  153
# negative? 테스트 :  27 비교단어 :  울상 등장 빈도(획득점수) :  1 인덱스 :  187
# positive? 테스트 :  13 비교단어 :  주목 등장 빈도(획득 점수) :  1 인덱스 :  50
# positive? 테스트 :  17 비교단어 :  1위 등장 빈도(획득 점수) :  1 인덱스 :  62
# positive? 테스트 :  5 비교단어 :  이끄는 등장 빈도(획득 점수) :  1 인덱스 :  28
# positive? 테스트 :  8 비교단어 :  최고 등장 빈도(획득 점수) :  1 인덱스 :  84
# positive? 테스트 :  7 비교단어 :  주목 등장 빈도(획득 점수) :  1 인덱스 :  50
# positive? 테스트 :  24 비교단어 :  출시 등장 빈도(획득 점수) :  1 인덱스 :  63
# negative? 테스트 :  5 비교단어 :  우려 등장 빈도(획득점수) :  1 인덱스 :  190
# positive? 테스트 :  24 비교단어 :  출시 등장 빈도(획득 점수) :  1 인덱스 :  63
# negative? 테스트 :  5 비교단어 :  우려 등장 빈도(획득점수) :  1 인덱스 :  190
# negative? 테스트 :  20 비교단어 :  문제 등장 빈도(획득점수) :  1 인덱스 :  174
# positive? 테스트 :  16 비교단어 :  강세 등장 빈도(획득 점수) :  1 인덱스 :  2
# negative? 테스트 :  18 비교단어 :  급락 등장 빈도(획득점수) :  1 인덱스 :  153
# positive? 테스트 :  13 비교단어 :  출시 등장 빈도(획득 점수) :  1 인덱스 :  63
# positive? 테스트 :  17 비교단어 :  경신 등장 빈도(획득 점수) :  1 인덱스 :  6
# positive? 테스트 :  13 비교단어 :  최고 등장 빈도(획득 점수) :  1 인덱스 :  84
# positive? 테스트 :  16 비교단어 :  최고 등장 빈도(획득 점수) :  1 인덱스 :  84
# positive? 테스트 :  15 비교단어 :  1위 등장 빈도(획득 점수) :  1 인덱스 :  62
# positive? 테스트 :  25 비교단어 :  최고 등장 빈도(획득 점수) :  1 인덱스 :  84
# positive? 테스트 :  20 비교단어 :  1위 등장 빈도(획득 점수) :  1 인덱스 :  62
# negative? 테스트 :  23 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  23 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  23 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  14 비교단어 :  돌파 등장 빈도(획득 점수) :  1 인덱스 :  52
# negative? 테스트 :  26 비교단어 :  정체 등장 빈도(획득점수) :  1 인덱스 :  123
# negative? 테스트 :  14 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  14 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  14 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  24 비교단어 :  강세 등장 빈도(획득 점수) :  1 인덱스 :  2
# negative? 테스트 :  17 비교단어 :  급락 등장 빈도(획득점수) :  1 인덱스 :  153
# positive? 테스트 :  29 비교단어 :  1위 등장 빈도(획득 점수) :  1 인덱스 :  62
# positive? 테스트 :  3 비교단어 :  1위 등장 빈도(획득 점수) :  1 인덱스 :  62
# positive? 테스트 :  24 비교단어 :  최고 등장 빈도(획득 점수) :  1 인덱스 :  84
# negative? 테스트 :  30 비교단어 :  주의 등장 빈도(획득점수) :  1 인덱스 :  125
# negative? 테스트 :  0 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  0 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  0 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  28 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  28 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  28 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  16 비교단어 :  수상 등장 빈도(획득 점수) :  1 인덱스 :  54
# negative? 테스트 :  22 비교단어 :  우려 등장 빈도(획득점수) :  1 인덱스 :  190
# negative? 테스트 :  11 비교단어 :  연기 등장 빈도(획득점수) :  1 인덱스 :  116
# negative? 테스트 :  15 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  15 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  15 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  9 비교단어 :  수혜 등장 빈도(획득 점수) :  1 인덱스 :  19
# positive? 테스트 :  11 비교단어 :  수혜 등장 빈도(획득 점수) :  1 인덱스 :  19
# negative? 테스트 :  29 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  29 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  29 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# negative? 테스트 :  31 비교단어 :  급락 등장 빈도(획득점수) :  1 인덱스 :  153
# negative? 테스트 :  6 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  6 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  6 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  19 비교단어 :  주목 등장 빈도(획득 점수) :  1 인덱스 :  50
# negative? 테스트 :  12 비교단어 :  연기 등장 빈도(획득점수) :  1 인덱스 :  116
# negative? 테스트 :  23 비교단어 :  둔화 등장 빈도(획득점수) :  1 인덱스 :  99
# positive? 테스트 :  16 비교단어 :  1위 등장 빈도(획득 점수) :  1 인덱스 :  62
# positive? 테스트 :  17 비교단어 :  오픈 등장 빈도(획득 점수) :  1 인덱스 :  65
# positive? 테스트 :  21 비교단어 :  대박 등장 빈도(획득 점수) :  1 인덱스 :  59
# positive? 테스트 :  29 비교단어 :  1위 등장 빈도(획득 점수) :  1 인덱스 :  62
# positive? 테스트 :  14 비교단어 :  돌파 등장 빈도(획득 점수) :  1 인덱스 :  52
# negative? 테스트 :  28 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  30 비교단어 :  리스크 등장 빈도(획득점수) :  1 인덱스 :  151
# negative? 테스트 :  28 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  28 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  22 비교단어 :  최고 등장 빈도(획득 점수) :  1 인덱스 :  84
# negative? 테스트 :  4 비교단어 :  논란 등장 빈도(획득점수) :  1 인덱스 :  142
# positive? 테스트 :  27 비교단어 :  열풍 등장 빈도(획득 점수) :  1 인덱스 :  57
# positive? 테스트 :  22 비교단어 :  돌파 등장 빈도(획득 점수) :  1 인덱스 :  52
# positive? 테스트 :  22 비교단어 :  돌파 등장 빈도(획득 점수) :  1 인덱스 :  52
# positive? 테스트 :  11 비교단어 :  최고 등장 빈도(획득 점수) :  1 인덱스 :  84
# positive? 테스트 :  22 비교단어 :  돌파 등장 빈도(획득 점수) :  1 인덱스 :  52
# positive? 테스트 :  11 비교단어 :  최고 등장 빈도(획득 점수) :  1 인덱스 :  84
# positive? 테스트 :  30 비교단어 :  최고 등장 빈도(획득 점수) :  1 인덱스 :  84
# negative? 테스트 :  15 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  137
# negative? 테스트 :  15 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  154
# negative? 테스트 :  15 비교단어 :  하락 등장 빈도(획득점수) :  1 인덱스 :  202
# positive? 테스트 :  10 비교단어 :  최고 등장 빈도(획득 점수) :  1 인덱스 :  84
# positive? 테스트 :  34 비교단어 :  체결 등장 빈도(획득 점수) :  1 인덱스 :  77
# negative? 테스트 :  34 비교단어 :  급락 등장 빈도(획득점수) :  1 인덱스 :  153
# negative? 테스트 :  4 비교단어 :  충격 등장 빈도(획득점수) :  1 인덱스 :  132

# %%
my_df
# Out:
#                                         title  label  pos  neg
# 0              SK하이닉스 우수 엔지니어 60세 넘어도 일할 수 있다      0    0    0
# 1       오션브릿지 SK하이닉스와 12억 규모 반도체 장비제조 공급계약 체결      1    1    0
# 2                       SK하이닉스 우수 엔지니어 정년 없앤다      0    0    0
# 3         클릭 e종목SK하이닉스 내년 반도체 수요 증가율 상저하고목표가↓      1    1    0
# 4                   클릭 e종목SK하이닉스 4Q영업익 전망치 하향      0    0    0
# ...                                       ...    ...  ...  ...
# 70579    미국 중국 동시 악재라니동학개미 악소리 난다 연휴 뒤 코스피 급락     -1    0    1
# 70580            디지털 강자 매경 카카오 블록체인 클레이튼과 손잡다      0    0    0
# 70581    코스피 외국인 기관 쌍끌이 매수840포인트↑ 313364 장 마감      0    0    0
# 70582  휴마시스 셀트리온과 273억원 규모 코로나19 항원진단키트 공급 계약      0    0    0
# 70583                    中헝다 충격 방어주로 떠오르는 바이오     -1    0    1
#
# [70584 rows x 4 columns]

# %%
my_df.label.value_counts()
# Out:
#  0    51463
#  1    10927
# -1     8194
# Name: label, dtype: int64

# %%
my_df.to_csv('./data/title_labeling_total.csv', index=False)

# %%
my_df.title[0]
# Out:
# 'SK하이닉스 우수 엔지니어 60세 넘어도 일할 수 있다'

# %%
하이닉스 --> 하이닉스 좋다 --> 기사 긍정 --> 기사의 분류결과 <- 을 앙상블을하는 거
하이닉스 --> 긍정판단 --> 주식이 올르거라고 판단한 거라 볼수 있다 <- 기사들마다 정확도를 낼때 쓸수있는 변수


하이닉스 --> 감성사전 구축 (레이블 : 주식등락) --> 주식등락이랑 비교를 하면서 정확도를 본것

보 팅(LSTM,머신러닝) + 기사긍부정 + 강화학습 --> 분류

# %%
import FinanceDataReader as fdr
