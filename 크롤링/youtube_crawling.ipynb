# %%
from selenium import webdriver
from bs4 import BeautifulSoup as bs
import pandas as pd
from selenium.webdriver.common.keys import Keys
import time


keyword = '삼성전자'
url = 'https://www.youtube.com/c/hkwowtv/search?query={}'.format(keyword)

chrome_path = './webdriver/chromedriver.exe'
driver = webdriver.Chrome(chrome_path)
driver.get(url)
soup = bs(driver.page_source, 'html.parser')
driver.close()

name = soup.select('a#video-title')
video_url = soup.select('a#video-title')
view = soup.select('a#video-title')

name_list = []
url_list = []
view_list = []

for i in range(len(name)):
    name_list.append(name[i].text.strip())
    view_list.append(view[i].get('aria-label').split()[-1])
for i in video_url:
    url_list.append('{}{}'.format('https://www.youtube.com',i.get('href')))

youtubeDic = {
    '제목': name_list,
    '주소': url_list,
    '조회수': view_list
}

youtubeDf = pd.DataFrame(youtubeDic)

# %%
youtubeDf
# Out:
#                                                    제목  \
# 0   동학개미들의 ‘7대 궁금증’ 풀이 “이제 외국인이 삼성전자를 본격 매수할까요?” /...
# 1   삼성전자·SK하이닉스 급락 떨어지는 칼날 잡아라? / 삼성전자, SK하이닉스, 원달...
# 2         외국인, 삼성전자 매수 계속될까? 9월 대내외 일정과 현안 ‘관건’ / 한상춘
# 3   삼성전자 3분기 실적나오면 오를까? 조기 테이퍼링과 반도체 업황 우려에 힘 못쓰는 ...
# 4   반도체의 위기설 삼전 흔드는 외국인, 과감한 매수는 아직까지 NO!(이진우)/  삼...
# 5   이재용 부회장 나온다 삼성전자 10만원 간다고? / 삼성전자, 삼성생명, 호텔신라 ...
# 6   삼성전자 실적발표 어닝 서프라이즈 그럼에도 불구하고 애태우는 주가(노근창)/ 주식경...
# 7   삼성전자 8만전자 돌파..삼성전자, SK하이닉스 주가 매력 여전 / 반도체 / 소부...
# 8   반도체 다운 사이클 삼성전자도 '급락' 침체되는 D램, 계속되는 우려(한상춘)/ 주...
# 9   삼성전자, SK하이닉스를 보는 엇갈린 전망..반도체 수퍼사이클 끝났나 / 삼성전자 ...
# 10  삼성전자,SK하이닉스 여전히 싸다? 7월 이후 '큰 손' 들어온다 / 반도체IT /...
# 11  외국인 반도체 거친 매도... 변동성 이길 전략은? / 삼성전자, SK하이닉스, 에...
# 12  위기의 삼성전자? 슈퍼사이클은 유효 메모리반도체 이익 못 따라오는 주가(노근창)/ ...
# 13  이틀 연속 하락 장세.. 삼성전자 반등 필요하다  / 퇴근길 꼭 봐야할 내일장 공략...
# 14  삼성전자·SK하이닉스 반등 시작됐나? / 삼성전자, SK하이닉스, DB하이텍 / 이...
# 15                   삼성전자 “코로나 위기, 반도체로 넘었다” / 한국경제TV
# ...

# %%
soup_1 = bs('https://www.youtube.com/watch?v=GE8zhn_kmFc', 'html.parser')

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.youtube.com/watch?v=GE8zhn_kmFc'
response = requests.get('https://www.youtube.com/watch?v=GE8zhn_kmFc')
response.text
# Out:
# '<!DOCTYPE html><html style="font-size: 10px;font-family: Roboto, Arial, sans-serif;" lang="ko-KR" system-icons typography typography-spacing><head><meta http-equiv="X-UA-Compatible" content="IE=edge"/><script nonce="xxMeAHeBb8028f/YhKxCnw">var ytcfg={d:function(){return window.yt&&yt.config_||ytcfg.data_||(ytcfg.data_={})},get:function(k,o){return k in ytcfg.d()?ytcfg.d()[k]:o},set:function(){var a=arguments;if(a.length>1)ytcfg.d()[a[0]]=a[1];else for(var k in a[0])ytcfg.d()[k]=a[0][k]}};\nwindow.ytcfg.set(\'EMERGENCY_BASE_URL\', \'\\/error_204?t\\x3djserror\\x26level\\x3dERROR\\x26client.name\\x3d1\\x26client.version\\x3d2.20210903.05.01\');</script><script nonce="xxMeAHeBb8028f/YhKxCnw">(function(){window.yterr=window.yterr||true;window.unhandledErrorMessages={};window.unhandledErrorCount=0;\nwindow.onerror=function(msg,url,line,columnNumber,error){var err;if(error)err=error;else{err=new Error;err.stack="";err.message=msg;err.fileName=url;err.lineNumber=line;if(!isNaN(columnNumber
# ...

# %%
soup = BeautifulSoup(response.text, 'html.parser')
a =soup.select_one('#info-text')
soup.find('span',{'class':'date style-scope ytd-video-secondary-info-renderer'})
# Out:
# <span itemprop="author" itemscope="" itemtype="http://schema.org/Person"><link href="http://www.youtube.com/user/hkwowtv" itemprop="url"/><link content="한국경제TV" itemprop="name"/></span>

# %%
soup.get_text()
# Out:
# '동학개미들의 ‘7대 궁금증’ 풀이 “이제 외국인이 삼성전자를 본격 매수할까요?” / 한상춘 - YouTube정보보도자료저작권문의하기크리에이터광고개발자약관개인정보처리방침정책 및 안전YouTube 작동의 원리새로운 기능 테스트하기© 2021 Google LLCCEO: 선다 피차이 주소: 1600 Amphitheatre Parkway, Mountain View, CA 94043, USA. 전화: 080-822-1450(무료)'

# %%
soup.find('span',{'class':'date style-scope ytd-video-secondary-info-renderer'})

# %%
from urllib.request import urlopen

# %%
html = urlopen(url)
bsob = BeautifulSoup(html, 'html.parser')

# %%
bsob.get_text()
# Out:
# '동학개미들의 ‘7대 궁금증’ 풀이 “이제 외국인이 삼성전자를 본격 매수할까요?” / 한상춘 - YouTube정보보도자료저작권문의하기크리에이터광고개발자약관개인정보처리방침정책 및 안전YouTube 작동의 원리새로운 기능 테스트하기© 2021 Google LLCCEO: 선다 피차이 주소: 1600 Amphitheatre Parkway, Mountain View, CA 94043, USA. 전화: 080-822-1450(무료)'
