# %%
from selenium import webdriver
from bs4 import BeautifulSoup as bs
import pandas as pd
from selenium.webdriver.common.keys import Keys
import time


keyword = '삼성전자'
url = 'https://www.youtube.com/c/hkwowtv/search?query={}'.format(keyword)

driver = webdriver.Chrome('./chromedriver/chromedriver')
driver.get(url)
soup = bs(driver.page_source, 'html.parser')
driver.close()

name = soup.select('a#video-title')
video_url = soup.select('a#video-title')
view = soup.select('a#video-title')

name_list = []
url_list = []
view_list = []

for i in range(len(name)):
    name_list.append(name[i].text.strip())
    view_list.append(view[i].get('aria-label').split()[-1])
for i in video_url:
    url_list.append('{}{}'.format('https://www.youtube.com',i.get('href')))

youtubeDic = {
    '제목': name_list,
    '주소': url_list,
    '조회수': view_list
}

youtubeDf = pd.DataFrame(youtubeDic)

# %%
youtubeDf
# Out:
#                                                    제목  \
# 0   동학개미들의 ‘7대 궁금증’ 풀이 “이제 외국인이 삼성전자를 본격 매수할까요?” /...
# 1         외국인, 삼성전자 매수 계속될까? 9월 대내외 일정과 현안 ‘관건’ / 한상춘
# 2   삼성전자·SK하이닉스 급락 떨어지는 칼날 잡아라? / 삼성전자, SK하이닉스, 원달...
# 3   삼성전자 3분기 실적나오면 오를까? 조기 테이퍼링과 반도체 업황 우려에 힘 못쓰는 ...
# 4   반도체의 위기설 삼전 흔드는 외국인, 과감한 매수는 아직까지 NO!(이진우)/  삼...
# 5   이재용 부회장 나온다 삼성전자 10만원 간다고? / 삼성전자, 삼성생명, 호텔신라 ...
# 6   삼성전자 실적발표 어닝 서프라이즈 그럼에도 불구하고 애태우는 주가(노근창)/ 주식경...
# 7   삼성전자 8만전자 돌파..삼성전자, SK하이닉스 주가 매력 여전 / 반도체 / 소부...
# 8   반도체 다운 사이클 삼성전자도 '급락' 침체되는 D램, 계속되는 우려(한상춘)/ 주...
# 9   삼성전자, SK하이닉스를 보는 엇갈린 전망..반도체 수퍼사이클 끝났나 / 삼성전자 ...
# 10  삼성전자,SK하이닉스 여전히 싸다? 7월 이후 '큰 손' 들어온다 / 반도체IT /...
# 11  외국인 반도체 거친 매도... 변동성 이길 전략은? / 삼성전자, SK하이닉스, 에...
# 12  위기의 삼성전자? 슈퍼사이클은 유효 메모리반도체 이익 못 따라오는 주가(노근창)/ ...
# 13  이틀 연속 하락 장세.. 삼성전자 반등 필요하다  / 퇴근길 꼭 봐야할 내일장 공략...
# 14  [경제전쟁 꾼 26] 사대천왕 인사이트, '절대 건드리면 안 되는 것' vs '지금...
# 15  삼성전자·SK하이닉스 반등 시작됐나? / 삼성전자, SK하이닉스, DB하이텍 / 이...
# 16                   삼성전자 “코로나 위기, 반도체로 넘었다” / 한국경제TV
