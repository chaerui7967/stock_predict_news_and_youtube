# %% [markdown]
# <a href="https://colab.research.google.com/github/chaerui7967/stock_predict_news_and_youtube/blob/master/youtube_%EC%9E%90%EB%A7%89.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# --------- youtube__ 자막가져오기--

# %%
! pip install pytube
# Out:
# Collecting pytube
#   Downloading pytube-11.0.1-py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 3.0 MB/s
# Installing collected packages: pytube
# Successfully installed pytube-11.0.1

# %%
from pytube import YouTube

# %%
video_url = 'https://www.youtube.com/watch?v=ECSeCI7n2zw'
yt = YouTube(video_url)

# %%
yt.initial_data
# Out:
# {'contents': {'twoColumnWatchNextResults': {'autoplay': {'autoplay': {'countDownSecs': 5,
#      'sets': [{'autoplayVideo': {'clickTrackingParams': 'CC8Q4ZIBIhMIgIm6-Zfi8gIVibnECh3fGQLSMgxyZWxhdGVkLWF1dG9IvLaf94jBp5IQmgEFCAMQ-B0=',
#         'commandMetadata': {'webCommandMetadata': {'rootVe': 3832,
#           'url': '/watch?v=DuuuiNCzLzM&pp=QAFIAQ%3D%3D',
#           'webPageType': 'WEB_PAGE_TYPE_WATCH'}},
#         'watchEndpoint': {'params': 'EAEYAdoBAggB',
#          'playerParams': 'QAFIAQ%3D%3D',
#          'videoId': 'DuuuiNCzLzM',
#          'watchEndpointSupportedPrefetchConfig': {'prefetchHintConfig': {'countdownUiRelativeSecondsPrefetchCondition': -3,
#            'prefetchPriority': 0}}}},
#        'mode': 'NORMAL'}],
#      'trackingParams': 'CC8Q4ZIBIhMIgIm6-Zfi8gIVibnECh3fGQLS'}},
#    'results': {'results': {'contents': [{'videoPrimaryInfoRenderer': {'dateText': {'simpleText': 'Aug 31, 2021'},
#         'sentimentBar': {'sentimentBarRenderer': {'likeStatus': 'INDIFFERENT',
#           'percentIfDisliked': 97,
#           'percentIfIndifferent': 97,
#           'percentIfLiked': 97,
#           'tooltip': '7,388 / 186'}},
#         'superTitleLink': {'runs': [{'loggingDirectives': {'trackingParams': 'CKIBEKW3AyITCICJuvmX4vICFYm5xAod3xkC0g==',
#             'visibility': {'types': '12'}},
#            'navigationEndpoint': {'browseEndpoint': {'browseId': 'FEhashtag',
#              'params': '6gUJCgd47IS464yA'},
#             'clickTrackingParams': 'CKIBEKW3AyITCICJuvmX4vICFYm5xAod3xkC0g==',
#             'commandMetadata': {'webCommandMetadata': {'apiUrl': '/youtubei/v1/browse',
#               'rootVe': 6827,
#               'url': '/hashtag/x%EC%84%B8%EB%8C%80',
#               'webPageType': 'WEB_PAGE_TYPE_BROWSE'}}},
#            'text': '#X세대'},
#           {'text': ' '},
#           {'loggingDirectives': {'trackingParams': 'CKEBEKW3AyITCICJuvmX4vICFYm5xAod3xkC0g==',
#             'visibility': {'types': '12'}},
#            'navigationEndpoint': {'browseEndpoint': {'browseId': 'FEhashtag',
#              'params': '6gUKCghteuyEuOuMgA%3D%3D'},
#             'clickTrackingParams': 'CKEBEKW3AyITCICJuvmX4vICFYm5xAod3xkC0g==',
#             'commandMetadata': {'webCommandMetadata': {'apiUrl': '/youtubei/v1/browse',
#               'rootVe': 6827,
#               'url': '/hashtag/mz%EC%84%B8%EB%8C%80',
#               'webPageType': 'WEB_PAGE_TYPE_BROWSE'}}},
#            'text': '#MZ세대'}]},
#         'title': {'runs': [{'text': 'MZ세대의 요청 : M과 Z를 묶지 말아주세요.'}]},
#         'trackingParams': 'CKABEMyrARgAIhMIgIm6-Zfi8gIVibnECh3fGQLS',
#         'videoActions': {'menuRenderer': {'accessibility': {'accessibilityData': {'label': 'More actions'}},
#           'items': [{'menuNavigationItemRenderer': {'icon': {'iconType': 'FLAG'},
#              'navigationEndpoint': {'clickTrackingParams': 'CKABEMyrARgAIhMIgIm6-Zfi8gIVibnECh3fGQLS',
#               'commandMetadata': {'webCommandMetadata': {'ignoreNavigation': True}},
#               'modalEndpoint': {'modal': {'modalWithTitleAndButtonRenderer': {'button': {'buttonRenderer': {'isDisabled': False,
#                    'navigationEndpoint': {'clickTrackingParams': 'CKsBEPBbIhMIgIm6-Zfi8gIVibnECh3fGQLS',
#                     'commandMetadata': {'webCommandMetadata': {'rootVe': 83769,
#                       'url': 'https://accounts.google.com/ServiceLogin?service=youtube&uilel=3&passive=true&continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Faction_handle_signin%3Dtrue%26app%3Ddesktop%26hl%3Den%26next%3Dhttps%253A%252F%252Fwww.youtube.com%252Fwatch%253Fv%253DECSeCI7n2zw&hl=en',
#                       'webPageType': 'WEB_PAGE_TYPE_UNKNOWN'}},
#                     'signInEndpoint': {'hack': True}},
#                    'size': 'SIZE_DEFAULT',
#                    'style': 'STYLE_BLUE_TEXT',
#                    'text': {'simpleText': 'Sign in'},
#                    'trackingParams': 'CKsBEPBbIhMIgIm6-Zfi8gIVibnECh3fGQLS'}},
#                  'content': {'runs': [{'text': 'Sign in to report inappropriate content.'}]},
#                  'title': {'runs': [{'text': 'Need to report the video?'}]}}}}},
#              'text': {'runs': [{'text': 'Report'}]},
#              'trackingParams': 'CKABEMyrARgAIhMIgIm6-Zfi8gIVibnECh3fGQLS'}},
#            {'menuServiceItemRenderer': {'icon': {'iconType': 'SUBTITLES'},
#              'serviceEndpoint': {'clickTrackingParams': 'CKABEMyrARgAIhMIgIm6-Zfi8gIVibnECh3fGQLS',
#               'commandMetadata': {'webCommandMetadata': {'sendPost': True}},
#               'signalServiceEndpoint': {'actions': [{'changeEngagementPanelVisibilityAction': {'targetId': 'engagement-panel-transcript',
#                   'visibility': 'ENGAGEMENT_PANEL_VISIBILITY_EXPANDED'},
#                  'clickTrackingParams': 'CKABEMyrARgAIhMIgIm6-Zfi8gIVibnECh3fGQLS'}],
#                'signal': 'CLIENT_SIGNAL'}},
#              'text': {'runs': [{'text': 'Open transcript'}]},
#              'trackingParams': 'CKABEMyrARgAIhMIgIm6-Zfi8gIVibnECh3fGQLS'}}],
#           'topLevelButtons': [{'toggleButtonRenderer': {'accessibility': {'label': 'like this video along with 7,388 other people'},
#              'accessibilityData': {'accessibilityData': {'label': 'like this video along with 7,388 other people'}},
#              'defaultIcon': {'iconType': 'LIKE'},
#              'defaultNavigationEndpoint': {'clickTrackingParams': 'CKkBEJhNGAIiEwiAibr5l-LyAhWJucQKHd8ZAtI=',
#               'commandMetadata': {'webCommandMetadata': {'ignoreNavigation': True}},
#               'modalEndpoint': {'modal': {'modalWithTitleAndButtonRenderer': {'button': {'buttonRenderer': {'isDisabled': False,
#                    'navigationEndpoint': {'clickTrackingParams': 'CKoBEPqGBCITCICJuvmX4vICFYm5xAod3xkC0g==',
#                     'commandMetadata': {'webCommandMetadata': {'rootVe': 83769,
#                       'url': 'https://accounts.google.com/ServiceLogin?service=youtube&uilel=3&passive=true&continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Faction_handle_signin%3Dtrue%26app%3Ddesktop%26hl%3Den%26next%3D%252Fwatch%253Fv%253DECSeCI7n2zw&hl=en&ec=66426',
#                       'webPageType': 'WEB_PAGE_TYPE_UNKNOWN'}},
#                     'signInEndpoint': {'idamTag': '66426',
#                      'nextEndpoint': {'clickTrackingParams': 'CKoBEPqGBCITCICJuvmX4vICFYm5xAod3xkC0g==',
#                       'commandMetadata': {'webCommandMetadata': {'rootVe': 3832,
#                         'url': '/watch?v=ECSeCI7n2zw',
#                         'webPageType': 'WEB_PAGE_TYPE_WATCH'}},
#                       'watchEndpoint': {'videoId': 'ECSeCI7n2zw',
#                        'watchEndpointSupportedOnesieConfig': {'html5PlaybackOnesieConfig': {'commonConfig': {'url': 'https://r4---sn-q4fl6ner.googlevideo.com/initplayback?source=youtube&orc=1&oeis=1&c=WEB&oad=3200&ovd=3200&oaad=11000&oavd=11000&ocs=700&oewis=1&oputc=1&ofpcc=1&msp=1&odeak=1&odepv=1&osfc=1&ip=34.125.200.94&id=10249e088ee7db3c&initcwndbps=4102500&mt=1630650540&oweuc='}}}}}}},
#                    'size': 'SIZE_DEFAULT',
#                    'style': 'STYLE_BLUE_TEXT',
#                    'text': {'simpleText': 'Sign in'},
#                    'trackingParams': 'CKoBEPqGBCITCICJuvmX4vICFYm5xAod3xkC0g=='}},
#                  'content': {'simpleText': 'Sign in to make your opinion count.'},
#                  'title': {'simpleText': 'Like this video?'}}}}},
#              'defaultText': {'accessibility': {'accessibilityData': {'label': '7,388 likes'}},
#               'simpleText': '7.3K'},
#              'defaultTooltip': 'I like this',
#              'isDisabled': False,
#              'isToggled': False,
#              'style': {'styleType': 'STYLE_TEXT'},
#              'targetId': 'watch-like',
#              'toggleButtonSupportedData': {'toggleButtonIdData': {'id': 'TOGGLE_BUTTON_ID_TYPE_LIKE'}},
#              'toggledStyle': {'styleType': 'STYLE_DEFAULT_ACTIVE'},
#              'toggledText': {'accessibility': {'accessibilityData': {'label': '7,389 likes'}},
#               'simpleText': '7.3K'},
#              'toggledTooltip': 'Unlike',
#              'trackingParams': 'CKkBEJhNGAIiEwiAibr5l-LyAhWJucQKHd8ZAtI='}},
#            {'toggleButtonRenderer': {'accessibility': {'label': 'dislike this video along with 186 other people'},
#              'accessibilityData': {'accessibilityData': {'label': 'dislike this video along with 186 other people'}},
#              'defaultIcon': {'iconType': 'DISLIKE'},
#              'defaultNavigationEndpoint': {'clickTrackingParams': 'CKcBEJhNGAMiEwiAibr5l-LyAhWJucQKHd8ZAtI=',
#               'commandMetadata': {'webCommandMetadata': {'ignoreNavigation': True}},
#               'modalEndpoint': {'modal': {'modalWithTitleAndButtonRenderer': {'button': {'buttonRenderer': {'isDisabled': False,
#                    'navigationEndpoint': {'clickTrackingParams': 'CKgBEPmGBCITCICJuvmX4vICFYm5xAod3xkC0g==',
#                     'commandMetadata': {'webCommandMetadata': {'rootVe': 83769,
#                       'url': 'https://accounts.google.com/ServiceLogin?service=youtube&uilel=3&passive=true&continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Faction_handle_signin%3Dtrue%26app%3Ddesktop%26hl%3Den%26next%3D%252Fwatch%253Fv%253DECSeCI7n2zw&hl=en&ec=66425',
#                       'webPageType': 'WEB_PAGE_TYPE_UNKNOWN'}},
#                     'signInEndpoint': {'idamTag': '66425',
#                      'nextEndpoint': {'clickTrackingParams': 'CKgBEPmGBCITCICJuvmX4vICFYm5xAod3xkC0g==',
#                       'commandMetadata': {'webCommandMetadata': {'rootVe': 3832,
#                         'url': '/watch?v=ECSeCI7n2zw',
#                         'webPageType': 'WEB_PAGE_TYPE_WATCH'}},
#                       'watchEndpoint': {'videoId': 'ECSeCI7n2zw',
#                        'watchEndpointSupportedOnesieConfig': {'html5PlaybackOnesieConfig': {'commonConfig': {'url': 'https://r4---sn-q4fl6ner.googlevideo.com/initplayback?source=youtube&orc=1&oeis=1&c=WEB&oad=3200&ovd=3200&oaad=11000&oavd=11000&ocs=700&oewis=1&oputc=1&ofpcc=1&msp=1&odeak=1&odepv=1&osfc=1&ip=34.125.200.94&id=10249e088ee7db3c&initcwndbps=4102500&mt=1630650540&oweuc='}}}}}}},
#                    'size': 'SIZE_DEFAULT',
#                    'style': 'STYLE_BLUE_TEXT',
#                    'text': {'simpleText': 'Sign in'},
#                    'trackingParams': 'CKgBEPmGBCITCICJuvmX4vICFYm5xAod3xkC0g=='}},
#                  'content': {'simpleText': 'Sign in to make your opinion count.'},
#                  'title': {'simpleText': "Don't like this video?"}}}}},
#              'defaultText': {'accessibility': {'accessibilityData': {'label': '186 dislikes'}},
#               'simpleText': '186'},
#              'defaultTooltip': 'I dislike this',
#              'isDisabled': False,
#              'isToggled': False,
#              'style': {'styleType': 'STYLE_TEXT'},
#              'targetId': 'watch-dislike',
#              'toggleButtonSupportedData': {'toggleButtonIdData': {'id': 'TOGGLE_BUTTON_ID_TYPE_DISLIKE'}},
#              'toggledStyle': {'styleType': 'STYLE_DEFAULT_ACTIVE'},
#              'toggledText': {'accessibility': {'accessibilityData': {'label': '187 dislikes'}},
#               'simpleText': '187'},
#              'toggledTooltip': 'I dislike this',
#              'trackingParams': 'CKcBEJhNGAMiEwiAibr5l-LyAhWJucQKHd8ZAtI='}},
#            {'buttonRenderer': {'accessibilityData': {'accessibilityData': {'label': 'Share'}},
#              'icon': {'iconType': 'SHARE'},
#              'isDisabled': False,
#              'serviceEndpoint': {'clickTrackingParams': 'CKUBEOWWARgEIhMIgIm6-Zfi8gIVibnECh3fGQLS',
#               'commandMetadata': {'webCommandMetadata': {'apiUrl': '/youtubei/v1/share/get_share_panel',
#                 'sendPost': True}},
#               'shareEntityServiceEndpoint': {'commands': [{'clickTrackingParams': 'CKUBEOWWARgEIhMIgIm6-Zfi8gIVibnECh3fGQLS',
#                  'openPopupAction': {'beReused': True,
#                   'popup': {'unifiedSharePanelRenderer': {'showLoadingSpinner': True,
#                     'trackingParams': 'CKYBEI5iIhMIgIm6-Zfi8gIVibnECh3fGQLS'}},
#                   'popupType': 'DIALOG'}}],
#                'serializedShareEntity': 'CgtFQ1NlQ0k3bjJ6dw%3D%3D'}},
#              'size': 'SIZE_DEFAULT',
#              'style': 'STYLE_DEFAULT',
#              'text': {'runs': [{'text': 'Share'}]},
#              'tooltip': 'Share',
#              'trackingParams': 'CKUBEOWWARgEIhMIgIm6-Zfi8gIVibnECh3fGQLS'}},
#            {'buttonRenderer': {'accessibility': {'label': 'Save to'},
#              'accessibilityData': {'accessibilityData': {'label': 'Save to playlist'}},
#              'icon': {'iconType': 'PLAYLIST_ADD'},
#              'isDisabled': False,
#              'navigationEndpoint': {'clickTrackingParams': 'CKMBEPBbGAUiEwiAibr5l-LyAhWJucQKHd8ZAtI=',
#               'commandMetadata': {'webCommandMetadata': {'ignoreNavigation': True}},
#               'modalEndpoint': {'modal': {'modalWithTitleAndButtonRenderer': {'button': {'buttonRenderer': {'isDisabled': False,
#                    'navigationEndpoint': {'clickTrackingParams': 'CKQBEPuGBCITCICJuvmX4vICFYm5xAod3xkC0g==',
#                     'commandMetadata': {'webCommandMetadata': {'rootVe': 83769,
#                       'url': 'https://accounts.google.com/ServiceLogin?service=youtube&uilel=3&passive=true&continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Faction_handle_signin%3Dtrue%26app%3Ddesktop%26hl%3Den%26next%3D%252Fwatch%253Fv%253DECSeCI7n2zw&hl=en&ec=66427',
#                       'webPageType': 'WEB_PAGE_TYPE_UNKNOWN'}},
#                     'signInEndpoint': {'idamTag': '66427',
#                      'nextEndpoint': {'clickTrackingParams': 'CKQBEPuGBCITCICJuvmX4vICFYm5xAod3xkC0g==',
#                       'commandMetadata': {'webCommandMetadata': {'rootVe': 3832,
#                         'url': '/watch?v=ECSeCI7n2zw',
#                         'webPageType': 'WEB_PAGE_TYPE_WATCH'}},
#                       'watchEndpoint': {'videoId': 'ECSeCI7n2zw',
#                        'watchEndpointSupportedOnesieConfig': {'html5PlaybackOnesieConfig': {'commonConfig': {'url': 'https://r4---sn-q4fl6ner.googlevideo.com/initplayback?source=youtube&orc=1&oeis=1&c=WEB&oad=3200&ovd=3200&oaad=11000&oavd=11000&ocs=700&oewis=1&oputc=1&ofpcc=1&msp=1&odeak=1&odepv=1&osfc=1&ip=34.125.200.94&id=10249e088ee7db3c&initcwndbps=4102500&mt=1630650540&oweuc='}}}}}}},
#                    'size': 'SIZE_DEFAULT',
#                    'style': 'STYLE_BLUE_TEXT',
#                    'text': {'simpleText': 'Sign in'},
#                    'trackingParams': 'CKQBEPuGBCITCICJuvmX4vICFYm5xAod3xkC0g=='}},
#                  'content': {'runs': [{'text': 'Sign in to add this video to a playlist.'}]},
#                  'title': {'runs': [{'text': 'Want to watch this again later?'}]}}}}},
#              'size': 'SIZE_DEFAULT',
#              'style': 'STYLE_DEFAULT',
#              'text': {'runs': [{'text': 'Save'}]},
#              'tooltip': 'Save',
#              'trackingParams': 'CKMBEPBbGAUiEwiAibr5l-LyAhWJucQKHd8ZAtI='}}],
#           'trackingParams': 'CKABEMyrARgAIhMIgIm6-Zfi8gIVibnECh3fGQLS'}},
#         'viewCount': {'videoViewCountRenderer': {'shortViewCount': {'simpleText': '397K views'},
#           'viewCount': {'simpleText': '397,471 views'}}}}},
#       {'videoSecondaryInfoRenderer': {'defaultExpanded': False,
#         'description': {'runs': [{'text': '어렵고 딱딱한 경제,시사,금융 이야기를\n쉽고 유쾌하게 풀어내는 \n경제/시사/이슈/잡썰 토크방송입니다.\n\n'},
#           {'loggingDirectives': {'trackingParams': 'CJ4BENzXBCITCICJuvmX4vICFYm5xAod3xkC0g==',
#             'visibility': {'types': '12'}},
#            'navigationEndpoint': {'browseEndpoint': {'browseId': 'FEhashtag',
#              'params': '6gUJCgd47IS464yA'},
#             'clickTrackingParams': 'CJ4BENzXBCITCICJuvmX4vICFYm5xAod3xkC0g==',
#             'commandMetadata': {'webCommandMetadata': {'apiUrl': '/youtubei/v1/browse',
#               'rootVe': 6827,
#               'url': '/hashtag/x%EC%84%B8%EB%8C%80',
#               'webPageType': 'WEB_PAGE_TYPE_BROWSE'}}},
#            'text': '#X세대'},
#           {'text': ' '},
#           {'loggingDirectives': {'trackingParams': 'CJ0BENzXBCITCICJuvmX4vICFYm5xAod3xkC0g==',
#             'visibility': {'types': '12'}},
#            'navigationEndpoint': {'browseEndpoint': {'browseId': 'FEhashtag',
#              'params': '6gUKCghteuyEuOuMgA%3D%3D'},
#             'clickTrackingParams': 'CJ0BENzXBCITCICJuvmX4vICFYm5xAod3xkC0g==',
#             'commandMetadata': {'webCommandMetadata': {'apiUrl': '/youtubei/v1/browse',
#               'rootVe': 6827,
#               'url': '/hashtag/mz%EC%84%B8%EB%8C%80',
#               'webPageType': 'WEB_PAGE_TYPE_BROWSE'}}},
#            'text': '#MZ세대'}]},
#         'descriptionCollapsedLines': 3,
#         'metadataRowContainer': {'metadataRowContainerRenderer': {'collapsedItemCount': 0,
#           'trackingParams': 'CJoBEM2rARgBIhMIgIm6-Zfi8gIVibnECh3fGQLS'}},
#         'owner': {'videoOwnerRenderer': {'navigationEndpoint': {'browseEndpoint': {'browseId': 'UCsJ6RuBiTVWRX156FVbeaGg',
#             'canonicalBaseUrl': '/channel/UCsJ6RuBiTVWRX156FVbeaGg'},
#            'clickTrackingParams': 'CJ8BEOE5IhMIgIm6-Zfi8gIVibnECh3fGQLS',
#            'commandMetadata': {'webCommandMetadata': {'apiUrl': '/youtubei/v1/browse',
#              'rootVe': 3611,
#              'url': '/channel/UCsJ6RuBiTVWRX156FVbeaGg',
#              'webPageType': 'WEB_PAGE_TYPE_CHANNEL'}}},
#           'subscriberCountText': {'accessibility': {'accessibilityData': {'label': '1.69 million subscribers'}},
#            'simpleText': '1.69M subscribers'},
#           'subscriptionButton': {'type': 'FREE'},
#           'thumbnail': {'thumbnails': [{'height': 48,
#              'url': 'https://yt3.ggpht.com/ytc/AKedOLQaiBQGZkfMmM4XqsvWYRZUjUOk1cqZ_13vWIPe=s48-c-k-c0x00ffffff-no-rj',
#              'width': 48},
#             {'height': 88,
#              'url': 'https://yt3.ggpht.com/ytc/AKedOLQaiBQGZkfMmM4XqsvWYRZUjUOk1cqZ_13vWIPe=s88-c-k-c0x00ffffff-no-rj',
#              'width': 88},
#             {'height': 176,
#              'url': 'https://yt3.ggpht.com/ytc/AKedOLQaiBQGZkfMmM4XqsvWYRZUjUOk1cqZ_13vWIPe=s176-c-k-c0x00ffffff-no-rj',
#              'width': 176}]},
#           'title': {'runs': [{'navigationEndpoint': {'browseEndpoint': {'browseId': 'UCsJ6RuBiTVWRX156FVbeaGg',
#                'canonicalBaseUrl': '/channel/UCsJ6RuBiTVWRX156FVbeaGg'},
#               'clickTrackingParams': 'CJ8BEOE5IhMIgIm6-Zfi8gIVibnECh3fGQLS',
#               'commandMetadata': {'webCommandMetadata': {'apiUrl': '/youtubei/v1/browse',
#                 'rootVe': 3611,
#                 'url': '/channel/UCsJ6RuBiTVWRX156FVbeaGg',
#                 'webPageType': 'WEB_PAGE_TYPE_CHANNEL'}}},
#              'text': '슈카월드'}]},
#           'trackingParams': 'CJ8BEOE5IhMIgIm6-Zfi8gIVibnECh3fGQLS'}},
#         'showLessText': {'simpleText': 'Show less'},
#         'showMoreText': {'simpleText': 'Show more'},
#         'subscribeButton': {'buttonRenderer': {'isDisabled': False,
#           'navigationEndpoint': {'clickTrackingParams': 'CJsBEPBbIhMIgIm6-Zfi8gIVibnECh3fGQLS',
#            'commandMetadata': {'webCommandMetadata': {'ignoreNavigation': True}},
#            'modalEndpoint': {'modal': {'modalWithTitleAndButtonRenderer': {'button': {'buttonRenderer': {'isDisabled': False,
#                 'navigationEndpoint': {'clickTrackingParams': 'CJwBEP2GBCITCICJuvmX4vICFYm5xAod3xkC0jIJc3Vic2NyaWJl',
#                  'commandMetadata': {'webCommandMetadata': {'rootVe': 83769,
#                    'url': 'https://accounts.google.com/ServiceLogin?service=youtube&uilel=3&passive=true&continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Faction_handle_signin%3Dtrue%26app%3Ddesktop%26hl%3Den%26next%3D%252Fwatch%253Fv%253DECSeCI7n2zw%26continue_action%&hl=en&ec=66429',
#                    'webPageType': 'WEB_PAGE_TYPE_UNKNOWN'}},
#                  'signInEndpoint': {'continueAction': '',
#                   'idamTag': '66429',
#                   'nextEndpoint': {'clickTrackingParams': 'CJwBEP2GBCITCICJuvmX4vICFYm5xAod3xkC0g==',
#                    'commandMetadata': {'webCommandMetadata': {'rootVe': 3832,
#                      'url': '/watch?v=ECSeCI7n2zw',
#                      'webPageType': 'WEB_PAGE_TYPE_WATCH'}},
#                    'watchEndpoint': {'videoId': 'ECSeCI7n2zw',
#                     'watchEndpointSupportedOnesieConfig': {'html5PlaybackOnesieConfig': {'commonConfig': {'url': 'https://r4---sn-q4fl6ner.googlevideo.com/initplayback?source=youtube&orc=1&oeis=1&c=WEB&oad=3200&ovd=3200&oaad=11000&oavd=11000&ocs=700&oewis=1&oputc=1&ofpcc=1&msp=1&odeak=1&odepv=1&osfc=1&ip=34.125.200.94&id=10249e088ee7db3c&initcwndbps=4102500&mt=1630650540&oweuc='}}}}}}},
#                 'size': 'SIZE_DEFAULT',
#                 'style': 'STYLE_BLUE_TEXT',
#                 'text': {'simpleText': 'Sign in'},
#                 'trackingParams': 'CJwBEP2GBCITCICJuvmX4vICFYm5xAod3xkC0g=='}},
#               'content': {'simpleText': 'Sign in to subscribe to this channel.'},
#               'title': {'simpleText': 'Want to subscribe to this channel?'}}}}},
#           'size': 'SIZE_DEFAULT',
#           'style': 'STYLE_DESTRUCTIVE',
#           'targetId': 'watch-subscribe',
#           'text': {'runs': [{'text': 'Subscribe'}]},
#           'trackingParams': 'CJsBEPBbIhMIgIm6-Zfi8gIVibnECh3fGQLS'}},
#         'trackingParams': 'CJoBEM2rARgBIhMIgIm6-Zfi8gIVibnECh3fGQLS'}},
#       {'itemSectionRenderer': {'contents': [{'commentsEntryPointHeaderRenderer': {'commentCount': {'simpleText': '2K'},
#            'headerText': {'runs': [{'text': 'Comments'}]},
#            'teaserAvatar': {'accessibility': {'accessibilityData': {'label': 'Kookhwan Kim'}},
#             'thumbnails': [{'height': 48,
#               'url': 'https://yt3.ggpht.com/ytc/AKedOLRDMZKs7r_wpdPN63XVfIc1tyGWlv7_2j-P4w=s48-c-k-c0x00ffffff-no-rj',
#               'width': 48},
#              {'height': 88,
#               'url': 'https://yt3.ggpht.com/ytc/AKedOLRDMZKs7r_wpdPN63XVfIc1tyGWlv7_2j-P4w=s88-c-k-c0x00ffffff-no-rj',
#               'width': 88},
#              {'height': 176,
#               'url': 'https://yt3.ggpht.com/ytc/AKedOLRDMZKs7r_wpdPN63XVfIc1tyGWlv7_2j-P4w=s176-c-k-c0x00ffffff-no-rj',
#               'width': 176}]},
#            'teaserContent': {'simpleText': 'MZ세대는 장년층이 이해 안 되는 젊은이를 속 편하게 묶어부르는 말이라고 생각해요. 바바리안과 비슷한 의미'},
#            'trackingParams': 'CJkBEMTgBBgAIhMIgIm6-Zfi8gIVibnECh3fGQLS'}}],
#         'sectionIdentifier': 'comments-entry-point',
#         'trackingParams': 'CJgBELsvGAIiEwiAibr5l-LyAhWJucQKHd8ZAtI='}},
#       {'itemSectionRenderer': {'contents': [{'continuationItemRenderer': {'continuationEndpoint': {'clickTrackingParams': 'CJcBELsvGAMiEwiAibr5l-LyAhWJucQKHd8ZAtI=',
#             'commandMetadata': {'webCommandMetadata': {'apiUrl': '/youtubei/v1/next',
#               'sendPost': True}},
#             'continuationCommand': {'request': 'CONTINUATION_REQUEST_TYPE_WATCH_NEXT',
#              'token': 'Eg0SC0VDU2VDSTduMnp3GAYyJSIRIgtFQ1NlQ0k3bjJ6dzAAeAJCEGNvbW1lbnRzLXNlY3Rpb24%3D'}},
#            'trigger': 'CONTINUATION_TRIGGER_ON_ITEM_SHOWN'}}],
#         'sectionIdentifier': 'comment-item-section',
#         'targetId': 'comments-section',
#         'trackingParams': 'CJcBELsvGAMiEwiAibr5l-LyAhWJucQKHd8ZAtI='}}],
#      'trackingParams': 'CJYBELovIhMIgIm6-Zfi8gIVibnECh3fGQLS'}},
#    'secondaryResults': {'secondaryResults': {'results': [{'compactVideoRenderer': {'accessibility': {'accessibilityData': {'label': '내 경험이 자식에게 유전이 될까 - 20 minutes - Go to channel - 슈카월드 - 229K views - 18 hours ago - play video'}},
#         'badges': [{'metadataBadgeRenderer': {'label': 'New',
#            'style': 'BADGE_STYLE_TYPE_SIMPLE',
#            'trackingParams': 'CJEBEKQwGAAiEwiAibr5l-LyAhWJucQKHd8ZAtI='}}],
#         'channelThumbnail': {'thumbnails': [{'height': 68,
#            'url': 'https://yt3.ggpht.com/ytc/AKedOLQaiBQGZkfMmM4XqsvWYRZUjUOk1cqZ_13vWIPe=s68-c-k-c0x00ffffff-no-rj',
#            'width': 68}]},
#         'lengthText': {'accessibility': {'accessibilityData': {'label': '20 minutes, 58 seconds'}},
#          'simpleText': '20:58'},
#         'longBylineText': {'runs': [{'navigationEndpoint': {'browseEndpoint': {'browseId': 'UCsJ6RuBiTVWRX156FVbeaGg',
#              'canonicalBaseUrl': '/c/슈카월드'},
#             'clickTrackingParams': 'CJEBEKQwGAAiEwiAibr5l-LyAhWJucQKHd8ZAtIyBnJlbG1mdQ==',
#             'commandMetadata': {'webCommandMetadata': {'apiUrl': '/youtubei/v1/browse',
#               'rootVe': 3611,
#               'url': '/c/%EC%8A%88%EC%B9%B4%EC%9B%94%EB%93%9C',
#               'webPageType': 'WEB_PAGE_TYPE_CHANNEL'}}},
#            'text': '슈카월드'}]},
#         'menu': {'menuRenderer': {'accessibility': {'accessibilityData': {'label': 'Action menu'}},
#           'items': [{'menuServiceItemRenderer': {'icon': {'iconType': 'ADD_TO_QUEUE_TAIL'},
#              'serviceEndpoint': {'clickTrackingParams': 'CJQBEP6YBBgFIhMIgIm6-Zfi8gIVibnECh3fGQLS',
#               'commandMetadata': {'webCommandMetadata': {'sendPost': True}},
#               'signalServiceEndpoint': {'actions': [{'addToPlaylistCommand': {'listType': 'PLAYLIST_EDIT_LIST_TYPE_QUEUE',
#                   'onCreateListCommand': {'clickTrackingParams': 'CJQBEP6YBBgFIhMIgIm6-Zfi8gIVibnECh3fGQLS',
#                    'commandMetadata': {'webCommandMetadata': {'apiUrl': '/youtubei/v1/playlist/create',
#                      'sendPost': True}},
#                    'createPlaylistServiceEndpoint': {'params': 'CAQ%3D',
#                     'videoIds': ['DuuuiNCzLzM']}},
#                   'openListPanel': True,
#                   'openMiniplayer': False,
#                   'videoId': 'DuuuiNCzLzM',
#                   'videoIds': ['DuuuiNCzLzM']},
#                  'clickTrackingParams': 'CJQBEP6YBBgFIhMIgIm6-Zfi8gIVibnECh3fGQLS'},
#                 {'clickTrackingParams': 'CJQBEP6YBBgFIhMIgIm6-Zfi8gIVibnECh3fGQLS',
#                  'openPopupAction': {'popup': {'notificationActionRenderer': {'responseText': {'simpleText': 'Added to queue'},
#                     'trackingParams': 'CJUBELlqIhMIgIm6-Zfi8gIVibnECh3fGQLS'}},
#                   'popupType': 'TOAST'}}],
#                'signal': 'CLIENT_SIGNAL'}},
#              'text': {'runs': [{'text': 'Add to queue'}]},
#              'trackingParams': 'CJQBEP6YBBgFIhMIgIm6-Zfi8gIVibnECh3fGQLS'}}],
#           'targetId': 'watch-related-menu-button',
#           'trackingParams': 'CJEBEKQwGAAiEwiAibr5l-LyAhWJucQKHd8ZAtI='}},
#         'navigationEndpoint': {'clickTrackingParams': 'CJEBEKQwGAAiEwiAibr5l-LyAhWJucQKHd8ZAtIyBnJlbG1mdUi8tp_3iMGnkhCaAQUIARD4HQ==',
#          'commandMetadata': {'webCommandMetadata': {'rootVe': 3832,
#            'url': '/watch?v=DuuuiNCzLzM',
#            'webPageType': 'WEB_PAGE_TYPE_WATCH'}},
#          'watchEndpoint': {'nofollow': True,
#           'videoId': 'DuuuiNCzLzM',
#           'watchEndpointSupportedOnesieConfig': {'html5PlaybackOnesieConfig': {'commonConfig': {'url': 'https://r3---sn-q4fl6nsl.googlevideo.com/initplayback?source=youtube&orc=1&oeis=1&c=WEB&oad=3200&ovd=3200&oaad=11000&oavd=11000&ocs=700&oewis=1&oputc=1&ofpcc=1&msp=1&odeak=1&odepv=1&osfc=1&ip=34.125.200.94&id=0eebae88d0b32f33&initcwndbps=4102500&mt=1630650540&oweuc='}}}}},
#         'publishedTimeText': {'simpleText': '18 hours ago'},
#         'shortBylineText': {'runs': [{'navigationEndpoint': {'browseEndpoint': {'browseId': 'UCsJ6RuBiTVWRX156FVbeaGg',
#              'canonicalBaseUrl': '/c/슈카월드'},
#             'clickTrackingParams': 'CJEBEKQwGAAiEwiAibr5l-LyAhWJucQKHd8ZAtIyBnJlbG1mdQ==',
#             'commandMetadata': {'webCommandMetadata': {'apiUrl': '/youtubei/v1/browse',
#               'rootVe': 3611,
#               'url': '/c/%EC%8A%88%EC%B9%B4%EC%9B%94%EB%93%9C',
#               'webPageType': 'WEB_PAGE_TYPE_CHANNEL'}}},
#            'text': '슈카월드'}]},
#         'shortViewCountText': {'accessibility': {'accessibilityData': {'label': '229K views'}},
#          'simpleText': '229K views'},
#         'thumbnail': {'thumbnails': [{'height': 94,
#            'url': 'https://i.ytimg.com/vi/DuuuiNCzLzM/hqdefault.jpg?sqp=-oaymwEiCKgBEF5IWvKriqkDFQgBFQAAAAAYASUAAMhCPQCAokN4AQ==&rs=AOn4CLDYtvWcevfvBOYhm2UrOg6Mn_3BtQ',
#            'width': 168},
#           {'height': 188,
#            'url': 'https://i.ytimg.com/vi/DuuuiNCzLzM/hqdefault.jpg?sqp=-oaymwEjCNACELwBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLC4OoIvNeqxv3VXjGzZMxQOrsqmUg',
#            'width': 336}]},
#         'thumbnailOverlays': [{'thumbnailOverlayTimeStatusRenderer': {'style': 'DEFAULT',
#            'text': {'accessibility': {'accessibilityData': {'label': '20 minutes, 58 seconds'}},
#             'simpleText': '20:58'}}},
#          {'thumbnailOverlayToggleButtonRenderer': {'isToggled': False,
#            'toggledAccessibility': {'accessibilityData': {'label': 'Added'}},
#            'toggledIcon': {'iconType': 'CHECK'},
#            'toggledServiceEndpoint': {'clickTrackingParams': 'CJMBEPnnAxgCIhMIgIm6-Zfi8gIVibnECh3fGQLS',
#             'commandMetadata': {'webCommandMetadata': {'apiUrl': '/youtubei/v1/browse/edit_playlist',
#               'sendPost': True}},
#             'playlistEditEndpoint': {'actions': [{'action': 'ACTION_REMOVE_VIDEO_BY_VIDEO_ID',
#                'removedVideoId': 'DuuuiNCzLzM'}],
#              'playlistId': 'WL'}},
#            'toggledTooltip': 'Added',
#            'trackingParams': 'CJMBEPnnAxgCIhMIgIm6-Zfi8gIVibnECh3fGQLS',
#            'untoggledAccessibility': {'accessibilityData': {'label': 'Watch later'}},
#            'untoggledIcon': {'iconType': 'WATCH_LATER'},
#            'untoggledServiceEndpoint': {'clickTrackingParams': 'CJMBEPnnAxgCIhMIgIm6-Zfi8gIVibnECh3fGQLS',
#             'commandMetadata': {'webCommandMetadata': {'apiUrl': '/youtubei/v1/browse/edit_playlist',
#               'sendPost': True}},
#             'playlistEditEndpoint': {'actions': [{'action': 'ACTION_ADD_VIDEO',
#                'addedVideoId': 'DuuuiNCzLzM'}],
#              'playlistId': 'WL'}},
#            'untoggledTooltip': 'Watch later'}},
#          {'thumbnailOverlayToggleButtonRenderer': {'toggledAccessibility': {'accessibilityData': {'label': 'Added'}},
#            'toggledIcon': {'iconType': 'PLAYLIST_ADD_CHECK'},
#            'toggledTooltip': 'Added',
#            'trackingParams': 'CJIBEMfsBBgDIhMIgIm6-Zfi8gIVibnECh3fGQLS',
#            'untoggledAccessibility': {'accessibilityData': {'label': 'Add to queue'}},
#            'untoggledIcon': {'iconType': 'ADD_TO_QUEUE_TAIL'},
#            'untoggledServiceEndpoint': {'clickTrackingParams': 'CJIBEMfsBBgDIhMIgIm6-Zfi8gIVibnECh3fGQLS',
#             'commandMetadata': {'webCommandMetadata': {'sendPost': True}},
#             'signalServiceEndpoint': {'actions': [{'addToPlaylistCommand': {'listType': 'PLAYLIST_EDIT_LIST_TYPE_QUEUE',
#                 'onCreateListCommand': {'clickTrackingParams': 'CJIBEMfsBBgDIhMIgIm6-Zfi8gIVibnECh3fGQLS',
#                  'commandMetadata': {'webCommandMetadata': {'apiUrl': '/youtubei/v1/playlist/create',
#                    'sendPost': True}},
#                  'createPlaylistServiceEndpoint': {'params': 'CAQ%3D',
#                   'videoIds': ['DuuuiNCzLzM']}},
#                 'openListPanel': True,
#                 'openMiniplayer': False,
#                 'videoId': 'DuuuiNCzLzM',
#                 'videoIds': ['DuuuiNCzLzM']},
#                'clickTrackingParams': 'CJIBEMfsBBgDIhMIgIm6-Zfi8gIVibnECh3fGQLS'}],
#              'signal': 'CLIENT_SIGNAL'}},
#            'untoggledTooltip': 'Add to queue'}},
#          {'thumbnailOverlayNowPlayingRenderer': {'text': {'runs': [{'text': 'Now playing'}]}}}],
#         'title': {'accessibility': {'accessibilityData': {'label': '내 경험이 자식에게 유전이 될까 by 슈카월드 18 hours ago 20 minutes 229,819 views'}},
#          'simpleText': '내 경험이 자식에게 유전이 될까'},
#         'trackingParams': 'CJEBEKQwGAAiEwiAibr5l-LyAhWJucQKHd8ZAtJAs97MhY3R6_UO',
#         'videoId': 'DuuuiNCzLzM',
#         'viewCountText': {'simpleText': '229,819 views'}}},
#       {'compactVideoRenderer': {'accessibility': {'accessibilityData': {'label': '정부는 돈을 뿌리고, 중앙은행은 돈을 흡수하는 기묘한 현상 - 22 minutes - Go to channel - 슈카월드 - 390K views - 1 day ago - play video'}},
#         'badges': [{'metadataBadgeRenderer': {'label': 'New',
#            'style': 'BADGE_STYLE_TYPE_SIMPLE',
#            'trackingParams': 'CIwBEKQwGAEiEwiAibr5l-LyAhWJucQKHd8ZAtI='}}],
#         'channelThumbnail': {'thumbnails': [{'height': 68,
#            'url': 'https://yt3.ggpht.com/ytc/AKedOLQaiBQGZkfMmM4XqsvWYRZUjUOk1cqZ_13vWIPe=s68-c-k-c0x00ffffff-no-rj',
#            'width': 68}]},
#         'lengthText': {'accessibility': {'accessibilityData': {'label': '22 minutes, 31 seconds'}},
#          'simpleText': '22:31'},
#         'longBylineText': {'runs': [{'navigationEndpoint': {'browseEndpoint': {'browseId': 'UCsJ6RuBiTVWRX156FVbeaGg',
#              'canonicalBaseUrl': '/c/슈카월드'},
#             'clickTrackingParams': 'CIwBEKQwGAEiEwiAibr5l-LyAhWJucQKHd8ZAtIyBnJlbG1mdQ==',
#             'commandMetadata': {'webCommandMetadata': {'apiUrl': '/youtubei/v1/browse',
#               'rootVe': 3611,
#               'url': '/c/%EC%8A%88%EC%B9%B4%EC%9B%94%EB%93%9C',
#               'webPageType': 'WEB_PAGE_TYPE_CHANNEL'}}},
#            'text': '슈카월드'}]},
#         'menu': {'menuRenderer': {'accessibility': {'accessibilityData': {'label': 'Action menu'}},
#           'items': [{'menuServiceItemRenderer': {'icon': {'iconType': 'ADD_TO_QUEUE_TAIL'},
#              'serviceEndpoint': {'clickTrackingParams': 'CI8BEP6YBBgFIhMIgIm6-Zfi8gIVibnECh3fGQLS',
#               'commandMetadata': {'webCommandMetadata': {'sendPost': True}},
#               'signalServiceEndpoint': {'actions': [{'addToPlaylistCommand': {'listType': 'PLAYLIST_EDIT_LIST_TYPE_QUEUE',
#                   'onCreateListCommand': {'clickTrackingParams': 'CI8BEP6YBBgFIhMIgIm6-Zfi8gIVibnECh3fGQLS',
#                    'commandMetadata': {'webCommandMetadata': {'apiUrl': '/youtubei/v1/playlist/create',
#                      'sendPost': True}},
#                    'createPlaylistServiceEndpoint': {'params': 'CAQ%3D',
#                     'videoIds': ['a3SnUIMd2Jc']}},
#                   'openListPanel': True,
#                   'openMiniplayer': False,
#                   'videoId': 'a3SnUIMd2Jc',
#                   'videoIds': ['a3SnUIMd2Jc']},
#                  'clickTrackingParams': 'CI8BEP6YBBgFIhMIgIm6-Zfi8gIVibnECh3fGQLS'},
#                 {'clickTrackingParams': 'CI8BEP6YBBgFIhMIgIm6-Zfi8gIVibnECh3fGQLS',
#                  'openPopupAction': {'popup': {'notificationActionRenderer': {'responseText': {'simpleText': 'Added to queue'},
#                     'trackingParams': 'CJABELlqIhMIgIm6-Zfi8gIVibnECh3fGQLS'}},
#                   'popupType': 'TOAST'}}],
#                'signal': 'CLIENT_SIGNAL'}},
#              'text': {'runs': [{'text': 'Add to queue'}]},
#              'trackingParams': 'CI8BEP6YBBgFIhMIgIm6-Zfi8gIVibnECh3fGQLS'}}],
#           'trackingParams': 'CIwBEKQwGAEiEwiAibr5l-LyAhWJucQKHd8ZAtI='}},
#         'navigationEndpoint': {'clickTrackingParams': 'CIwBEKQwGAEiEwiAibr5l-LyAhWJucQKHd8ZAtIyBnJlbG1mdUi8tp_3iMGnkhCaAQUIARD4HQ==',
#          'commandMetadata': {'webCommandMetadata': {'rootVe': 3832,
#            'url': '/watch?v=a3SnUIMd2Jc',
#            'webPageType': 'WEB_PAGE_TYPE_WATCH'}},
#          'watchEndpoint': {'nofollow': True,
#           'videoId': 'a3SnUIMd2Jc',
#           'watchEndpointSupportedOnesieConfig': {'html5PlaybackOnesieConfig': {'commonConfig': {'url': 'https://r5---sn-q4fl6nsd.googlevideo.com/initplayback?source=youtube&orc=1&oeis=1&c=WEB&oad=3200&ovd=3200&oaad=11000&oavd=11000&ocs=700&oewis=1&oputc=1&ofpcc=1&msp=1&odeak=1&odepv=1&osfc=1&ip=34.125.200.94&id=6b74a750831dd897&initcwndbps=4102500&mt=1630650540&oweuc='}}}}},
#         'publishedTimeText': {'simpleText': '1 day ago'},
#         'shortBylineText': {'runs': [{'navigationEndpoint': {'browseEndpoint': {'browseId': 'UCsJ6RuBiTVWRX156FVbeaGg',
#              'canonicalBaseUrl': '/c/슈카월드'},
#             'clickTrackingParams': 'CIwBEKQwGAEiEwiAibr5l-LyAhWJucQKHd8ZAtIyBnJlbG1mdQ==',
#             'commandMetadata': {'webCommandMetadata': {'apiUrl': '/youtubei/v1/browse',
#               'rootVe': 3611,
#               'url': '/c/%EC%8A%88%EC%B9%B4%EC%9B%94%EB%93%9C',
#               'webPageType': 'WEB_PAGE_TYPE_CHANNEL'}}},
#            'text': '슈카월드'}]},
#         'shortViewCountText': {'accessibility': {'accessibilityData': {'label': '390K views'}},
#          'simpleText': '390K views'},
#         'thumbnail': {'thumbnails': [{'height': 94,
#            'url': 'https://i.ytimg.com/vi/a3SnUIMd2Jc/hqdefault.jpg?sqp=-oaymwEiCKgBEF5IWvKriqkDFQgBFQAAAAAYASUAAMhCPQCAokN4AQ==&rs=AOn4CLCanLsqG_LJaBQrmB124STqCEg4FA',
#            'width': 168},
#           {'height': 188,
#            'url': 'https://i.ytimg.com/vi/a3SnUIMd2Jc/hqdefault.jpg?sqp=-oaymwEjCNACELwBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLDr8MfQpZvL5RFPXC2B0UJ0Onurtw',
#            'width': 336}]},
#         'thumbnailOverlays': [{'thumbnailOverlayTimeStatusRenderer': {'style': 'DEFAULT',
#            'text': {'accessibility': {'accessibilityData': {'label': '22 minutes, 31 seconds'}},
#             'simpleText': '22:31'}}},
#          {'thumbnailOverlayToggleButtonRenderer': {'isToggled': False,
#            'toggledAccessibility': {'accessibilityData': {'label': 'Added'}},
#            'toggledIcon': {'iconType': 'CHECK'},
#            'toggledServiceEndpoint': {'clickTrackingParams': 'CI4BEPnnAxgCIhMIgIm6-Zfi8gIVibnECh3fGQLS',
#             'commandMetadata': {'webCommandMetadata': {'apiUrl': '/youtubei/v1/browse/edit_playlist',
#               'sendPost': True}},
#             'playlistEditEndpoint': {'actions': [{'action': 'ACTION_REMOVE_VIDEO_BY_VIDEO_ID',
#                'removedVideoId': 'a3SnUIMd2Jc'}],
#              'playlistId': 'WL'}},
#            'toggledTooltip': 'Added',
#            'trackingParams': 'CI4BEPnnAxgCIhMIgIm6-Zfi8gIVibnECh3fGQLS',
#            'untoggledAccessibility': {'accessibilityData': {'label': 'Watch later'}},
#            'untoggledIcon': {'iconType': 'WATCH_LATER'},
#            'untoggledServiceEndpoint': {'clickTrackingParams': 'CI4BEPnnAxgCIhMIgIm6-Zfi8gIVibnECh3fGQLS',
#             'commandMetadata': {'webCommandMetadata': {'apiUrl': '/youtubei/v1/browse/edit_playlist',
#               'sendPost': True}},
#             'playlistEditEndpoint': {'actions': [{'action': 'ACTION_ADD_VIDEO',
#                'addedVideoId': 'a3SnUIMd2Jc'}],
#              'playlistId': 'WL'}},
#            'untoggledTooltip': 'Watch later'}},
#          {'thumbnailOverlayToggleButtonRenderer': {'toggledAccessibility': {'accessibilityData': {'label': 'Added'}},
#            'toggledIcon': {'iconType': 'PLAYLIST_ADD_CHECK'},
#            'toggledTooltip': 'Added',
#            'trackingParams': 'CI0BEMfsBBgDIhMIgIm6-Zfi8gIVibnECh3fGQLS',
#            'untoggledAccessibility': {'accessibilityData': {'label': 'Add to queue'}},
#            'untoggledIcon': {'iconType': 'ADD_TO_QUEUE_TAIL'},
#            'untoggledServiceEndpoint': {'clickTrackingParams': 'CI0BEMfsBBgDIhMIgIm6-Zfi8gIVibnECh3fGQLS',
#             'commandMetadata': {'webCommandMetadata': {'sendPost': True}},
#             'signalServiceEndpoint': {'actions': [{'addToPlaylistCommand': {'listType': 'PLAYLIST_EDIT_LIST_TYPE_QUEUE',
#                 'onCreateListCommand': {'clickTrackingParams': 'CI0BEMfsBBgDIhMIgIm6-Zfi8gIVibnECh3fGQLS',
#                  'commandMetadata': {'webCommandMetadata': {'apiUrl': '/youtubei/v1/playlist/create',
#                    'sendPost': True}},
#                  'createPlaylistServiceEndpoint': {'params': 'CAQ%3D',
#                   'videoIds': ['a3SnUIMd2Jc']}},
#                 'openListPanel': True,
#                 'openMiniplayer': False,
#                 'videoId': 'a3SnUIMd2Jc',
#                 'videoIds': ['a3SnUIMd2Jc']},
#                'clickTrackingParams': 'CI0BEMfsBBgDIhMIgIm6-Zfi8gIVibnECh3fGQLS'}],
#              'signal': 'CLIENT_SIGNAL'}},
#            'untoggledTooltip': 'Add to queue'}},
#          {'thumbnailOverlayNowPlayingRenderer': {'text': {'runs': [{'text': 'Now playing'}]}}}],
#         'title': {'accessibility': {'accessibilityData': {'label': '정부는 돈을 뿌리고, 중앙은행은 돈을 흡수하는 기묘한 현상 by 슈카월드 1 day ago 22 minutes 390,189 views'}},
#          'simpleText': '정부는 돈을 뿌리고, 중앙은행은 돈을 흡수하는 기묘한 현상'},
#         'trackingParams': 'CIwBEKQwGAEiEwiAibr5l-LyAhWJucQKHd8ZAtJAl7H3mIjqqbpr',
#         'videoId': 'a3SnUIMd2Jc',
#         'viewCountText': {'simpleText': '390,189 views'}}},
#       {'compactVideoRenderer': {'accessibility': {'accessibilityData': {'label': '은행들이 1층 버리고 2층으로 올라가는 진짜 이유는... (ft. 핀크) - 38 minutes - Go to channel - 신사임당 - 4.7K views - 34 minutes ago - play video'}},
#         'badges': [{'metadataBadgeRenderer': {'label': 'New',
#            'style': 'BADGE_STYLE_TYPE_SIMPLE',
#            'trackingParams': 'CIcBEKQwGAIiEwiAibr5l-LyAhWJucQKHd8ZAtI='}}],
#         'channelThumbnail': {'thumbnails': [{'height': 68,
#            'url': 'https://yt3.ggpht.com/ytc/AKedOLS4ur4hLCdtoRGgypukJomdeewH47wASke2gWAu5g=s68-c-k-c0x00ffffff-no-rj',
#            'width': 68}]},
#         'lengthText': {'accessibility': {'accessibilityData': {'label': '38 minutes, 27 seconds'}},
#          'simpleText': '38:27'},
#         'longBylineText': {'runs': [{'navigationEndpoint': {'browseEndpoint': {'browseId': 'UCaJdckl6MBdDPDf75Ec_bJA',
#              'canonicalBaseUrl': '/c/신사임당_korea'},
#             'clickTrackingParams': 'CIcBEKQwGAIiEwiAibr5l-LyAhWJucQKHd8ZAtIyB3JlbGF0ZWQ=',
#             'commandMetadata': {'webCommandMetadata': {'apiUrl': '/youtubei/v1/browse',
#               'rootVe': 3611,
#               'url': '/c/%EC%8B%A0%EC%82%AC%EC%9E%84%EB%8B%B9_korea',
#               'webPageType': 'WEB_PAGE_TYPE_CHANNEL'}}},
#            'text': '신사임당'}]},
#         'menu': {'menuRenderer': {'accessibility': {'accessibilityData': {'label': 'Action menu'}},
#           'items': [{'menuServiceItemRenderer': {'icon': {'iconType': 'ADD_TO_QUEUE_TAIL'},
#              'serviceEndpoint': {'clickTrackingParams': 'CIoBEP6YBBgGIhMIgIm6-Zfi8gIVibnECh3fGQLS',
#               'commandMetadata': {'webCommandMetadata': {'sendPost': True}},
#               'signalServiceEndpoint': {'actions': [{'addToPlaylistCommand': {'listType': 'PLAYLIST_EDIT_LIST_TYPE_QUEUE',
#                   'onCreateListCommand': {'clickTrackingParams': 'CIoBEP6YBBgGIhMIgIm6-Zfi8gIVibnECh3fGQLS',
#                    'commandMetadata': {'webCommandMetadata': {'apiUrl': '/youtubei/v1/playlist/create',
#                      'sendPost': True}},
#                    'createPlaylistServiceEndpoint': {'params': 'CAQ%3D',
#                     'videoIds': ['Hj0hLpRIj-E']}},
#                   'openListPanel': True,
#                   'openMiniplayer': False,
#                   'videoId': 'Hj0hLpRIj-E',
#                   'videoIds': ['Hj0hLpRIj-E']},
#                  'clickTrackingParams': 'CIoBEP6YBBgGIhMIgIm6-Zfi8gIVibnECh3fGQLS'},
#                 {'clickTrackingParams': 'CIoBEP6YBBgGIhMIgIm6-Zfi8gIVibnECh3fGQLS',
#                  'openPopupAction': {'popup': {'notificationActionRenderer': {'responseText': {'simpleText': 'Added to queue'},
#                     'trackingParams': 'CIsBELlqIhMIgIm6-Zfi8gIVibnECh3fGQLS'}},
#                   'popupType': 'TOAST'}}],
#                'signal': 'CLIENT_SIGNAL'}},
#              'text': {'runs': [{'text': 'Add to queue'}]},
#              'trackingParams': 'CIoBEP6YBBgGIhMIgIm6-Zfi8gIVibnECh3fGQLS'}}],
#           'trackingParams': 'CIcBEKQwGAIiEwiAibr5l-LyAhWJucQKHd8ZAtI='}},
#         'navigationEndpoint': {'clickTrackingParams': 'CIcBEKQwGAIiEwiAibr5l-LyAhWJucQKHd8ZAtIyB3JlbGF0ZWRIvLaf94jBp5IQmgEFCAEQ-B0=',
#          'commandMetadata': {'webCommandMetadata': {'rootVe': 3832,
#            'url': '/watch?v=Hj0hLpRIj-E',
#            'webPageType': 'WEB_PAGE_TYPE_WATCH'}},
#          'watchEndpoint': {'nofollow': True,
#           'videoId': 'Hj0hLpRIj-E',
#           'watchEndpointSupportedOnesieConfig': {'html5PlaybackOnesieConfig': {'commonConfig': {'url': 'https://r5---sn-q4fl6nsr.googlevideo.com/initplayback?source=youtube&orc=1&oeis=1&c=WEB&oad=3200&ovd=3200&oaad=11000&oavd=11000&ocs=700&oewis=1&oputc=1&ofpcc=1&msp=1&odeak=1&odepv=1&osfc=1&ip=34.125.200.94&id=1e3d212e94488fe1&initcwndbps=4102500&mt=1630650540&oweuc='}}}}},
#         'ownerBadges': [{'metadataBadgeRenderer': {'accessibilityData': {'label': 'Verified'},
#            'icon': {'iconType': 'CHECK_CIRCLE_THICK'},
#            'style': 'BADGE_STYLE_TYPE_VERIFIED',
#            'tooltip': 'Verified',
#            'trackingParams': 'CIcBEKQwGAIiEwiAibr5l-LyAhWJucQKHd8ZAtI='}}],
#         'publishedTimeText': {'simpleText': '34 minutes ago'},
#         'shortBylineText': {'runs': [{'navigationEndpoint': {'browseEndpoint': {'browseId': 'UCaJdckl6MBdDPDf75Ec_bJA',
#              'canonicalBaseUrl': '/c/신사임당_korea'},
#             'clickTrackingParams': 'CIcBEKQwGAIiEwiAibr5l-LyAhWJucQKHd8ZAtIyB3JlbGF0ZWQ=',
#             'commandMetadata': {'webCommandMetadata': {'apiUrl': '/youtubei/v1/browse',
#               'rootVe': 3611,
#               'url': '/c/%EC%8B%A0%EC%82%AC%EC%9E%84%EB%8B%B9_korea',
#               'webPageType': 'WEB_PAGE_TYPE_CHANNEL'}}},
#            'text': '신사임당'}]},
#         'shortViewCountText': {'accessibility': {'accessibilityData': {'label': '4.7K views'}},
#          'simpleText': '4.7K views'},
#         'thumbnail': {'thumbnails': [{'height': 94,
#            'url': 'https://i.ytimg.com/vi/Hj0hLpRIj-E/hqdefault.jpg?sqp=-oaymwEiCKgBEF5IWvKriqkDFQgBFQAAAAAYASUAAMhCPQCAokN4AQ==&rs=AOn4CLB_-vd_UkoJ0N0jG4m-FGoDPWFKWw',
#            'width': 168},
#           {'height': 188,
#            'url': 'https://i.ytimg.com/vi/Hj0hLpRIj-E/hqdefault.jpg?sqp=-oaymwEjCNACELwBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLD99sZvLvFvba49tN8FfKXPzGp1wg',
#            'width': 336}]},
#         'thumbnailOverlays': [{'thumbnailOverlayTimeStatusRenderer': {'style': 'DEFAULT',
#            'text': {'accessibility': {'accessibilityData': {'label': '38 minutes, 27 seconds'}},
#             'simpleText': '38:27'}}},
#          {'thumbnailOverlayToggleButtonRenderer': {'isToggled': False,
#            'toggledAccessibility': {'accessibilityData': {'label': 'Added'}},
#            'toggledIcon': {'iconType': 'CHECK'},
#            'toggledServiceEndpoint': {'clickTrackingParams': 'CIkBEPnnAxgDIhMIgIm6-Zfi8gIVibnECh3fGQLS',
#             'commandMetadata': {'webCommandMetadata': {'apiUrl': '/youtubei/v1/browse/edit_playlist',
#               'sendPost': True}},
#             'playlistEditEndpoint': {'actions': [{'action': 'ACTION_REMOVE_VIDEO_BY_VIDEO_ID',
#                'removedVideoId': 'Hj0hLpRIj-E'}],
#              'playlistId': 'WL'}},
#            'toggledTooltip': 'Added',
#            'trackingParams': 'CIkBEPnnAxgDIhMIgIm6-Zfi8gIVibnECh3fGQLS',
#            'untoggledAccessibility': {'accessibilityData': {'label': 'Watch later'}},
#            'untoggledIcon': {'iconType': 'WATCH_LATER'},
#            'untoggledServiceEndpoint': {'clickTrackingParams': 'CIkBEPnnAxgDIhMIgIm6-Zfi8gIVibnECh3fGQLS',
#             'commandMetadata': {'webCommandMetadata': {'apiUrl': '/youtubei/v1/browse/edit_playlist',
#               'sendPost': True}},
#             'playlistEditEndpoint': {'actions': [{'action': 'ACTION_ADD_VIDEO',
#                'addedVideoId': 'Hj0hLpRIj-E'}],
#              'playlistId': 'WL'}},
#            'untoggledTooltip': 'Watch later'}},
#          {'thumbnailOverlayToggleButtonRenderer': {'toggledAccessibility': {'accessibilityData': {'label': 'Added'}},
#            'toggledIcon': {'iconType': 'PLAYLIST_ADD_CHECK'},
#            'toggledTooltip': 'Added',
#            'trackingParams': 'CIgBEMfsBBgEIhMIgIm6-Zfi8gIVibnECh3fGQLS',
#            'untoggledAccessibility': {'accessibilityData': {'label': 'Add to queue'}},
#            'untoggledIcon': {'iconType': 'ADD_TO_QUEUE_TAIL'},
#            'untoggledServiceEndpoint': {'clickTrackingParams': 'CIgBEMfsBBgEIhMIgIm6-Zfi8gIVibnECh3fGQLS',
#             'commandMetadata': {'webCommandMetadata': {'sendPost': True}},
# ...
#        'signal': 'CLIENT_SIGNAL'}},
#      'trackingParams': 'CAcQvIYDIhMIgIm6-Zfi8gIVibnECh3fGQLS'}},
#    'forwardButton': {'buttonRenderer': {'command': {'clickTrackingParams': 'CAYQvYYDIhMIgIm6-Zfi8gIVibnECh3fGQLS',
#       'commandMetadata': {'webCommandMetadata': {'sendPost': True}},
#       'signalServiceEndpoint': {'actions': [{'clickTrackingParams': 'CAYQvYYDIhMIgIm6-Zfi8gIVibnECh3fGQLS',
#          'signalAction': {'signal': 'HISTORY_FORWARD'}}],
#        'signal': 'CLIENT_SIGNAL'}},
#      'trackingParams': 'CAYQvYYDIhMIgIm6-Zfi8gIVibnECh3fGQLS'}},
#    'hotkeyDialog': {'hotkeyDialogRenderer': {'dismissButton': {'buttonRenderer': {'isDisabled': False,
#        'size': 'SIZE_DEFAULT',
#        'style': 'STYLE_BLUE_TEXT',
#        'text': {'runs': [{'text': 'Dismiss'}]},
#        'trackingParams': 'CAkQ8FsiEwiAibr5l-LyAhWJucQKHd8ZAtI='}},
#      'sections': [{'hotkeyDialogSectionRenderer': {'options': [{'hotkeyDialogSectionOptionRenderer': {'hotkey': 'k',
#            'label': {'runs': [{'text': 'Toggle play/pause'}]}}},
#          {'hotkeyDialogSectionOptionRenderer': {'hotkey': 'j',
#            'label': {'runs': [{'text': 'Rewind 10 seconds'}]}}},
#          {'hotkeyDialogSectionOptionRenderer': {'hotkey': 'l',
#            'label': {'runs': [{'text': 'Fast forward 10 seconds'}]}}},
#          {'hotkeyDialogSectionOptionRenderer': {'hotkey': 'P (SHIFT+p)',
#            'label': {'runs': [{'text': 'Previous video'}]}}},
#          {'hotkeyDialogSectionOptionRenderer': {'hotkey': 'N (SHIFT+n)',
#            'label': {'runs': [{'text': 'Next video'}]}}},
#          {'hotkeyDialogSectionOptionRenderer': {'hotkey': ',',
#            'hotkeyAccessibilityLabel': {'accessibilityData': {'label': 'Comma'}},
#            'label': {'runs': [{'text': 'Previous frame (while paused)'}]}}},
#          {'hotkeyDialogSectionOptionRenderer': {'hotkey': '.',
#            'hotkeyAccessibilityLabel': {'accessibilityData': {'label': 'Period'}},
#            'label': {'runs': [{'text': 'Next frame (while paused)'}]}}},
#          {'hotkeyDialogSectionOptionRenderer': {'hotkey': '< (SHIFT+,)',
#            'hotkeyAccessibilityLabel': {'accessibilityData': {'label': 'Less than or SHIFT + comma'}},
#            'label': {'runs': [{'text': 'Decrease playback rate'}]}}},
#          {'hotkeyDialogSectionOptionRenderer': {'hotkey': '> (SHIFT+.)',
#            'hotkeyAccessibilityLabel': {'accessibilityData': {'label': 'Greater than or SHIFT + period'}},
#            'label': {'runs': [{'text': 'Increase playback rate'}]}}},
#          {'hotkeyDialogSectionOptionRenderer': {'hotkey': '0..9',
#            'label': {'runs': [{'text': 'Seek to specific point in the video (7 advances to 70% of duration)'}]}}},
#          {'hotkeyDialogSectionOptionRenderer': {'hotkey': 'CONTROL + ←',
#            'label': {'runs': [{'text': 'Seek to previous chapter'}]}}},
#          {'hotkeyDialogSectionOptionRenderer': {'hotkey': 'CONTROL + →',
#            'label': {'runs': [{'text': 'Seek to next chapter'}]}}}],
#         'title': {'runs': [{'text': 'Playback'}]}}},
#       {'hotkeyDialogSectionRenderer': {'options': [{'hotkeyDialogSectionOptionRenderer': {'hotkey': 'f',
#            'label': {'runs': [{'text': 'Toggle full screen'}]}}},
#          {'hotkeyDialogSectionOptionRenderer': {'hotkey': 't',
#            'label': {'runs': [{'text': 'Toggle theater mode'}]}}},
#          {'hotkeyDialogSectionOptionRenderer': {'hotkey': 'i',
#            'label': {'runs': [{'text': 'Toggle miniplayer'}]}}},
#          {'hotkeyDialogSectionOptionRenderer': {'hotkey': 'ESCAPE',
#            'label': {'runs': [{'text': 'Close miniplayer or current dialog'}]}}},
#          {'hotkeyDialogSectionOptionRenderer': {'hotkey': 'm',
#            'label': {'runs': [{'text': 'Toggle mute'}]}}}],
#         'title': {'runs': [{'text': 'General'}]}}},
#       {'hotkeyDialogSectionRenderer': {'options': [{'hotkeyDialogSectionOptionRenderer': {'hotkey': 'c',
#            'label': {'runs': [{'text': 'If the video supports captions, toggle captions ON/OFF'}]}}},
#          {'hotkeyDialogSectionOptionRenderer': {'hotkey': 'o',
#            'label': {'runs': [{'text': 'Rotate through different text opacity levels'}]}}},
#          {'hotkeyDialogSectionOptionRenderer': {'hotkey': 'w',
#            'label': {'runs': [{'text': 'Rotate through different window opacity levels'}]}}},
#          {'hotkeyDialogSectionOptionRenderer': {'hotkey': '+',
#            'label': {'runs': [{'text': 'Rotate through font sizes (increasing)'}]}}},
#          {'hotkeyDialogSectionOptionRenderer': {'hotkey': '-',
#            'hotkeyAccessibilityLabel': {'accessibilityData': {'label': 'Minus'}},
#            'label': {'runs': [{'text': 'Rotate through font sizes (decreasing)'}]}}}],
#         'title': {'runs': [{'text': 'Subtitles and closed captions'}]}}},
#       {'hotkeyDialogSectionRenderer': {'options': [{'hotkeyDialogSectionOptionRenderer': {'hotkey': 'w',
#            'label': {'runs': [{'text': 'Pan up'}]}}},
#          {'hotkeyDialogSectionOptionRenderer': {'hotkey': 'a',
#            'label': {'runs': [{'text': 'Pan left'}]}}},
#          {'hotkeyDialogSectionOptionRenderer': {'hotkey': 's',
#            'label': {'runs': [{'text': 'Pan down'}]}}},
#          {'hotkeyDialogSectionOptionRenderer': {'hotkey': 'd',
#            'label': {'runs': [{'text': 'Pan right'}]}}},
#          {'hotkeyDialogSectionOptionRenderer': {'hotkey': '+ on numpad or ]',
#            'hotkeyAccessibilityLabel': {'accessibilityData': {'label': 'Plus on number pad or right bracket'}},
#            'label': {'runs': [{'text': 'Zoom in'}]}}},
#          {'hotkeyDialogSectionOptionRenderer': {'hotkey': '- on numpad or [',
#            'hotkeyAccessibilityLabel': {'accessibilityData': {'label': 'Minus on number pad or left bracket'}},
#            'label': {'runs': [{'text': 'Zoom out'}]}}}],
#         'title': {'runs': [{'text': 'Spherical Videos'}]}}}],
#      'title': {'runs': [{'text': 'Keyboard shortcuts'}]},
#      'trackingParams': 'CAgQteYDIhMIgIm6-Zfi8gIVibnECh3fGQLS'}},
#    'logo': {'topbarLogoRenderer': {'endpoint': {'browseEndpoint': {'browseId': 'FEwhat_to_watch'},
#       'clickTrackingParams': 'CBkQsV4iEwiAibr5l-LyAhWJucQKHd8ZAtI=',
#       'commandMetadata': {'webCommandMetadata': {'apiUrl': '/youtubei/v1/browse',
#         'rootVe': 3854,
#         'url': '/',
#         'webPageType': 'WEB_PAGE_TYPE_BROWSE'}}},
#      'iconImage': {'iconType': 'YOUTUBE_LOGO'},
#      'overrideEntityKey': 'EgZ0b3BiYXIg9QEoAQ%3D%3D',
#      'tooltipText': {'runs': [{'text': 'YouTube Home'}]},
#      'trackingParams': 'CBkQsV4iEwiAibr5l-LyAhWJucQKHd8ZAtI='}},
#    'searchbox': {'fusionSearchboxRenderer': {'clearButton': {'buttonRenderer': {'accessibilityData': {'accessibilityData': {'label': 'Clear search query'}},
#        'icon': {'iconType': 'CLOSE'},
#        'isDisabled': False,
#        'size': 'SIZE_DEFAULT',
#        'style': 'STYLE_DEFAULT',
#        'trackingParams': 'CBgQ8FsiEwiAibr5l-LyAhWJucQKHd8ZAtI='}},
#      'config': {'webSearchboxConfig': {'focusSearchbox': True,
#        'hasOnscreenKeyboard': False,
#        'requestDomain': 'us',
#        'requestLanguage': 'en'}},
#      'icon': {'iconType': 'SEARCH'},
#      'placeholderText': {'runs': [{'text': 'Search'}]},
#      'searchEndpoint': {'clickTrackingParams': 'CBcQ7VAiEwiAibr5l-LyAhWJucQKHd8ZAtI=',
#       'commandMetadata': {'webCommandMetadata': {'rootVe': 4724,
#         'url': '/results?search_query=',
#         'webPageType': 'WEB_PAGE_TYPE_SEARCH'}},
#       'searchEndpoint': {'query': ''}},
#      'trackingParams': 'CBcQ7VAiEwiAibr5l-LyAhWJucQKHd8ZAtI='}},
#    'topbarButtons': [{'topbarMenuButtonRenderer': {'accessibility': {'accessibilityData': {'label': 'YouTube apps'}},
#       'icon': {'iconType': 'APPS'},
#       'menuRenderer': {'multiPageMenuRenderer': {'sections': [{'multiPageMenuSectionRenderer': {'items': [{'compactLinkRenderer': {'icon': {'iconType': 'UNPLUGGED_LOGO'},
#               'navigationEndpoint': {'clickTrackingParams': 'CBYQ4MUCGAAiEwiAibr5l-LyAhWJucQKHd8ZAtI=',
#                'commandMetadata': {'webCommandMetadata': {'rootVe': 83769,
#                  'url': 'https://tv.youtube.com/?utm_source=youtube_web&utm_medium=ep&utm_campaign=home&ve=34273',
#                  'webPageType': 'WEB_PAGE_TYPE_UNKNOWN'}},
#                'urlEndpoint': {'target': 'TARGET_NEW_WINDOW',
#                 'url': 'https://tv.youtube.com/?utm_source=youtube_web&utm_medium=ep&utm_campaign=home&ve=34273'}},
#               'title': {'runs': [{'text': 'YouTube TV'}]},
#               'trackingParams': 'CBYQ4MUCGAAiEwiAibr5l-LyAhWJucQKHd8ZAtI='}}],
#            'trackingParams': 'CBUQ968BGAAiEwiAibr5l-LyAhWJucQKHd8ZAtI='}},
#          {'multiPageMenuSectionRenderer': {'items': [{'compactLinkRenderer': {'icon': {'iconType': 'YOUTUBE_MUSIC'},
#               'navigationEndpoint': {'clickTrackingParams': 'CBQQ4sUCGAAiEwiAibr5l-LyAhWJucQKHd8ZAtI=',
#                'commandMetadata': {'webCommandMetadata': {'rootVe': 83769,
#                  'url': 'https://music.youtube.com/',
#                  'webPageType': 'WEB_PAGE_TYPE_UNKNOWN'}},
#                'urlEndpoint': {'target': 'TARGET_NEW_WINDOW',
#                 'url': 'https://music.youtube.com'}},
#               'title': {'runs': [{'text': 'YouTube Music'}]},
#               'trackingParams': 'CBQQ4sUCGAAiEwiAibr5l-LyAhWJucQKHd8ZAtI='}},
#             {'compactLinkRenderer': {'icon': {'iconType': 'YOUTUBE_KIDS_ROUND'},
#               'navigationEndpoint': {'clickTrackingParams': 'CBMQ48UCGAEiEwiAibr5l-LyAhWJucQKHd8ZAtI=',
#                'commandMetadata': {'webCommandMetadata': {'rootVe': 83769,
#                  'url': 'https://www.youtubekids.com/?source=youtube_web',
#                  'webPageType': 'WEB_PAGE_TYPE_UNKNOWN'}},
#                'urlEndpoint': {'target': 'TARGET_NEW_WINDOW',
#                 'url': 'https://www.youtubekids.com?source=youtube_web'}},
#               'title': {'runs': [{'text': 'YouTube Kids'}]},
#               'trackingParams': 'CBMQ48UCGAEiEwiAibr5l-LyAhWJucQKHd8ZAtI='}}],
#            'trackingParams': 'CBIQ968BGAEiEwiAibr5l-LyAhWJucQKHd8ZAtI='}},
#          {'multiPageMenuSectionRenderer': {'items': [{'compactLinkRenderer': {'icon': {'iconType': 'YOUTUBE_ROUND'},
#               'navigationEndpoint': {'clickTrackingParams': 'CBEQ5MUCGAAiEwiAibr5l-LyAhWJucQKHd8ZAtI=',
#                'commandMetadata': {'webCommandMetadata': {'rootVe': 83769,
#                  'url': 'https://creatoracademy.youtube.com/page/education?utm_source=YouTube&utm_medium=YT%20Main&utm_campaign=YT%20Appsn',
#                  'webPageType': 'WEB_PAGE_TYPE_UNKNOWN'}},
#                'urlEndpoint': {'target': 'TARGET_NEW_WINDOW',
#                 'url': 'https://creatoracademy.youtube.com/page/education?utm_source=YouTube&utm_medium=YT%20Main&utm_campaign=YT%20Appsn'}},
#               'title': {'runs': [{'text': 'Creator Academy'}]},
#               'trackingParams': 'CBEQ5MUCGAAiEwiAibr5l-LyAhWJucQKHd8ZAtI='}},
#             {'compactLinkRenderer': {'icon': {'iconType': 'YOUTUBE_ROUND'},
#               'navigationEndpoint': {'clickTrackingParams': 'CBAQ5cUCGAEiEwiAibr5l-LyAhWJucQKHd8ZAtI=',
#                'commandMetadata': {'webCommandMetadata': {'rootVe': 83769,
#                  'url': 'https://artists.youtube.com/',
#                  'webPageType': 'WEB_PAGE_TYPE_UNKNOWN'}},
#                'urlEndpoint': {'target': 'TARGET_NEW_WINDOW',
#                 'url': 'https://artists.youtube.com/'}},
#               'title': {'runs': [{'text': 'YouTube for Artists'}]},
#               'trackingParams': 'CBAQ5cUCGAEiEwiAibr5l-LyAhWJucQKHd8ZAtI='}}],
#            'trackingParams': 'CA8Q968BGAIiEwiAibr5l-LyAhWJucQKHd8ZAtI='}}],
#         'style': 'MULTI_PAGE_MENU_STYLE_TYPE_YT_APPS',
#         'trackingParams': 'CA4Q_6sBIhMIgIm6-Zfi8gIVibnECh3fGQLS'}},
#       'style': 'STYLE_DEFAULT',
#       'targetId': 'topbar-apps',
#       'tooltip': 'YouTube apps',
#       'trackingParams': 'CA0Q_qsBGAAiEwiAibr5l-LyAhWJucQKHd8ZAtI='}},
#     {'topbarMenuButtonRenderer': {'accessibility': {'accessibilityData': {'label': 'Settings'}},
#       'icon': {'iconType': 'MORE_VERT'},
#       'menuRequest': {'clickTrackingParams': 'CAsQ_qsBGAEiEwiAibr5l-LyAhWJucQKHd8ZAtI=',
#        'commandMetadata': {'webCommandMetadata': {'apiUrl': '/youtubei/v1/account/account_menu',
#          'sendPost': True}},
#        'signalServiceEndpoint': {'actions': [{'clickTrackingParams': 'CAsQ_qsBGAEiEwiAibr5l-LyAhWJucQKHd8ZAtI=',
#           'openPopupAction': {'beReused': True,
#            'popup': {'multiPageMenuRenderer': {'showLoadingSpinner': True,
#              'style': 'MULTI_PAGE_MENU_STYLE_TYPE_SYSTEM',
#              'trackingParams': 'CAwQ_6sBIhMIgIm6-Zfi8gIVibnECh3fGQLS'}},
#            'popupType': 'DROPDOWN'}}],
#         'signal': 'GET_ACCOUNT_MENU'}},
#       'style': 'STYLE_DEFAULT',
#       'tooltip': 'Settings',
#       'trackingParams': 'CAsQ_qsBGAEiEwiAibr5l-LyAhWJucQKHd8ZAtI='}},
#     {'buttonRenderer': {'icon': {'iconType': 'AVATAR_LOGGED_OUT'},
#       'navigationEndpoint': {'clickTrackingParams': 'CAoQ1IAEGAIiEwiAibr5l-LyAhWJucQKHd8ZAtI=',
#        'commandMetadata': {'webCommandMetadata': {'rootVe': 83769,
#          'url': 'https://accounts.google.com/ServiceLogin?service=youtube&uilel=3&passive=true&continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Faction_handle_signin%3Dtrue%26app%3Ddesktop%26hl%3Den%26next%3Dhttps%253A%252F%252Fwww.youtube.com%252Fwatch%253Fv%253DECSeCI7n2zw&hl=en&ec=65620',
#          'webPageType': 'WEB_PAGE_TYPE_UNKNOWN'}},
#        'signInEndpoint': {'idamTag': '65620'}},
#       'size': 'SIZE_SMALL',
#       'style': 'STYLE_SUGGESTIVE',
#       'targetId': 'topbar-signin',
#       'text': {'runs': [{'text': 'Sign in'}]},
#       'trackingParams': 'CAoQ1IAEGAIiEwiAibr5l-LyAhWJucQKHd8ZAtI='}}],
#    'trackingParams': 'CAEQq6wBIhMIgIm6-Zfi8gIVibnECh3fGQLS',
#    'voiceSearchButton': {'buttonRenderer': {'accessibilityData': {'accessibilityData': {'label': 'Search with your voice'}},
#      'icon': {'iconType': 'MICROPHONE_ON'},
#      'isDisabled': False,
#      'serviceEndpoint': {'clickTrackingParams': 'CAIQ8FsiEwiAibr5l-LyAhWJucQKHd8ZAtI=',
#       'commandMetadata': {'webCommandMetadata': {'sendPost': True}},
#       'signalServiceEndpoint': {'actions': [{'clickTrackingParams': 'CAIQ8FsiEwiAibr5l-LyAhWJucQKHd8ZAtI=',
#          'openPopupAction': {'popup': {'voiceSearchDialogRenderer': {'connectionErrorHeader': {'runs': [{'text': 'No connection'}]},
#             'connectionErrorMicrophoneLabel': {'runs': [{'text': 'Check your connection and try again'}]},
#             'disabledHeader': {'runs': [{'text': 'Search with your voice'}]},
#             'disabledSubtext': {'runs': [{'text': 'To search by voice, go to your browser settings and allow access to microphone'}]},
#             'exampleQuery1': {'runs': [{'text': '"Play Dua Lipa"'}]},
#             'exampleQuery2': {'runs': [{'text': '"Show me my subscriptions"'}]},
#             'exitButton': {'buttonRenderer': {'accessibilityData': {'accessibilityData': {'label': 'Cancel'}},
#               'icon': {'iconType': 'CLOSE'},
#               'isDisabled': False,
#               'size': 'SIZE_DEFAULT',
#               'style': 'STYLE_DEFAULT',
#               'trackingParams': 'CAQQ8FsiEwiAibr5l-LyAhWJucQKHd8ZAtI='}},
#             'loadingHeader': {'runs': [{'text': 'Working...'}]},
#             'microphoneOffPromptHeader': {'runs': [{'text': 'Microphone off. Try again.'}]},
#             'permissionsHeader': {'runs': [{'text': 'Waiting for permission'}]},
#             'permissionsSubtext': {'runs': [{'text': 'Allow microphone access to enable voice input'}]},
#             'placeholderHeader': {'runs': [{'text': 'Listening...'}]},
#             'promptHeader': {'runs': [{'text': "Didn't hear that. Try again."}]},
#             'promptMicrophoneLabel': {'runs': [{'text': 'Tap microphone to try again'}]},
#             'trackingParams': 'CAMQ7q8FIhMIgIm6-Zfi8gIVibnECh3fGQLS'}},
#           'popupType': 'TOP_ALIGNED_DIALOG'}}],
#        'signal': 'CLIENT_SIGNAL'}},
#      'size': 'SIZE_DEFAULT',
#      'style': 'STYLE_DEFAULT',
#      'tooltip': 'Search with your voice',
#      'trackingParams': 'CAIQ8FsiEwiAibr5l-LyAhWJucQKHd8ZAtI='}}}},
#  'trackingParams': 'CAAQg2ciEwiAibr5l-LyAhWJucQKHd8ZAtI='}

# %%
dir(yt)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_age_restricted',
#  '_author',
#  '_embed_html',
#  '_fmt_streams',
#  '_initial_data',
#  '_js',
#  '_js_url',
#  '_metadata',
#  '_player_config_args',
#  '_publish_date',
#  '_title',
#  '_vid_info',
#  '_watch_html',
#  'age_restricted',
#  'allow_oauth_cache',
#  'author',
#  'bypass_age_gate',
#  'caption_tracks',
#  'captions',
#  'channel_id',
#  'channel_url',
#  'check_availability',
#  'description',
#  'embed_html',
#  'embed_url',
#  'fmt_streams',
#  'initial_data',
#  'js',
#  'js_url',
#  'keywords',
#  'length',
#  'metadata',
#  'publish_date',
#  'rating',
#  'register_on_complete_callback',
#  'register_on_progress_callback',
#  'stream_monostate',
#  'streaming_data',
#  'streams',
#  'thumbnail_url',
#  'title',
#  'use_oauth',
#  'vid_info',
#  'video_id',
#  'views',
#  'watch_html',
#  'watch_url']

# %%
print("[영상 제목]", yt.title)  # 영상제목
print("[영상 게시자]", yt.author) # 영상 게시자
print("[조회수]", yt.views)
print("[평균평점]", yt.rating) # 평균 평점
print("[영상길이(초)]", yt.length)
print("[연령제한여부]", yt.age_restricted)
print("[영상 설명]", yt.description) # 영상 설명
print("[썸네일URL]", yt.thumbnail_url) # 썸네일 url 주소
# Out:
# [영상 제목] MZ세대의 요청 : M과 Z를 묶지 말아주세요.
# [영상 게시자] 슈카월드
# [조회수] 397471
# [평균평점] 4.901769
# [영상길이(초)] 1243
# [연령제한여부] False
# [영상 설명] 어렵고 딱딱한 경제,시사,금융 이야기를
# 쉽고 유쾌하게 풀어내는
# 경제/시사/이슈/잡썰 토크방송입니다.
#
# #X세대 #MZ세대
# [썸네일URL] https://i.ytimg.com/vi/ECSeCI7n2zw/sddefault.jpg

# %%
yt.captions.all()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated function all (This object can be treated as a dictionary).
#   """Entry point for launching an IPython kernel.
# [<Caption lang="Korean (auto-generated)" code="a.ko">]

# %%
caption = yt.captions.get_by_language_code('a.ko')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   """Entry point for launching an IPython kernel.

# %%
caption.xml_captions
# Out:
# '<?xml version="1.0" encoding="utf-8" ?><timedtext format="3">\n<head>\n<ws id="0"/>\n<ws id="1" mh="2" ju="0" sd="3"/>\n<wp id="0"/>\n<wp id="1" ap="6" ah="20" av="100" rc="2" cc="40"/>\n</head>\n<body>\n<w t="0" id="1" wp="1" ws="1"/>\n<p t="0" d="3860" w="1"><s ac="232">아</s></p>\n<p t="280" d="3580" w="1" a="1">\n</p>\n<p t="290" d="3570" w="1">[음악]</p>\n<p t="4269" w="1" a="1">\n</p>\n<p t="4279" d="5030" w="1"><s ac="224">wr</s></p>\n<p t="6929" d="2380" w="1" a="1">\n</p>\n<p t="6939" d="3241" w="1"><s ac="252">여러분들</s><s t="391" ac="252"> 혹시</s><s t="651" ac="181"> 유튜버</s><s t="1651" ac="227"> 나</s><s t="1771" ac="167"> 스트림</s><s t="2161" ac="239"> 하고</s></p>\n<p t="9299" d="881" w="1" a="1">\n</p>\n<p t="9309" d="2731" w="1"><s ac="252">싶으십니까</s></p>\n<p t="10170" d="1870" w="1" a="1">\n</p>\n<p t="10180" d="4109" w="1"><s ac="147">유튜브에</s><s t="570" ac="222"> 스트리머</s><s t="1110" ac="222"> 뭐</s><s t="1289" ac="223"> 아니면</s><s t="1619" ac="216"> 하이트</s></p>\n<p t="12030" d="2259" w="1" a="1">\n</p>\n<p t="12040" d="4950" w="1"><s ac="207">뭐</s><s t="120" ac="231"> 등등</s><s t="450" ac="231"> 등등</s><s t="660" ac="172"> 뭐</s><s t="1140" ac="166"> 웹툰작가</s><s t="1499" ac="205"> 던</s><s t="1919" ac="233"> 모던</s></p>\n<p t="14279" d="2711" w="1" a="1">\n</p>\n<p t="14289" d="4410" w="1"><s ac="230">회사</s><s t="391" ac="239"> 때로</s><s t="660" ac="255"> 치고</s><s t="930" ac="248"> 나와서</s><s t="1321" ac="252"> 뭘</s><s t="1531" ac="249"> 해야지</s></p>\n<p t="16980" d="1719" w="1" a="1">\n</p>\n<p t="16990" d="4289" w="1"><s ac="251">제가</s><s t="240" ac="216"> 얼마전에</s><s t="570" ac="252"> 건강검진을</s><s t="1170" ac="246"> 받았는데요</s></p>\n<p t="18689" d="2590" w="1" a="1">\n</p>\n<p t="18699" d="6031" w="1"><s ac="237">지금</s><s t="660" ac="200"> 차두리</s><s t="1261" ac="202"> 형의</s><s t="1651" ac="244"> 나오더라구요</s><s t="2250" ac="255"> 거기에</s></p>\n<p t="21269" d="3461" w="1" a="1">\n</p>\n<p t="21279" d="5521" w="1"><s ac="252">그</s><s t="181" ac="237"> 간</s><s t="691" ac="236"> 때문이야</s><s t="1141" ac="0"> 간</s><s t="1641" ac="0"> 때문이야</s><s t="2641" ac="217"> 너</s><s t="3211" ac="243"> 지금</s></p>\n<p t="24720" d="2080" w="1" a="1">\n</p>\n<p t="24730" d="4770" w="1"><s ac="233">ct</s><s t="600" ac="252"> 촬영</s><s t="960" ac="252"> 받고</s><s t="1170" ac="247"> 있습니다</s><s t="1800" ac="246"> 건강</s></p>\n<p t="26790" d="2710" w="1" a="1">\n</p>\n<p t="26800" d="5610" w="1"><s ac="249">조심하시고요</s><s t="900" ac="252"> 회사</s><s t="1170" ac="206"> 다닐때는</s><s t="1739" ac="200"> 나와서</s></p>\n<p t="29490" d="2920" w="1" a="1">\n</p>\n<p t="29500" d="5160" w="1"><s ac="252">혼자</s><s t="330" ac="247"> 이런거</s><s t="930" ac="216"> 하면</s><s t="1140" ac="204"> 되게</s><s t="1619" ac="251"> 편하고</s><s t="2250" ac="233"> 그럴</s></p>\n<p t="32400" d="2260" w="1" a="1">\n</p>\n<p t="32410" d="4860" w="1"><s ac="255">거라고</s><s t="270" ac="236"> 생각하지만</s><s t="780" ac="241"> 나오시면</s><s t="1469" ac="129"> 일이</s><s t="1919" ac="124"> 2배</s></p>\n<p t="34650" d="2620" w="1" a="1">\n</p>\n<p t="34660" d="4469" w="1"><s ac="226">줘</s><s t="419" ac="146"> ep</s><s t="750" ac="247"> 2</s><s t="1110" ac="201"> 두</s><s t="1559" ac="200"> 배</s><s t="1739" ac="208"> 벽</s><s t="1890" ac="212"> 왠</s><s t="2100" ac="208"> 차가</s><s t="2309" ac="0"> 이</s></p>\n<p t="37260" d="1869" w="1" a="1">\n</p>\n<p t="37270" d="3870" w="1"><s ac="97">세</s><s t="150" ac="119"> 배</s><s t="269" ac="200"> 입니다</s><s t="359" ac="142"> 3배에</s><s t="839" ac="250"> 운</s><s t="1139" ac="245"> 없으면</s><s t="1319" ac="245"> 은</s></p>\n<p t="39119" d="2021" w="1" a="1">\n</p>\n<p t="39129" d="4050" w="1"><s ac="252">그</s><s t="61" ac="252"> 주</s><s t="270" ac="252"> 80시간</s><s t="1110" ac="247"> 뭐</s><s t="1500" ac="251"> 이렇게</s><s t="1741" ac="239"> 일할</s><s t="1890" ac="255"> 수</s></p>\n<p t="41130" d="2049" w="1" a="1">\n</p>\n<p t="41140" d="4079" w="1"><s ac="255">있어요</s><s t="509" ac="230"> 조심하셔야</s><s t="1050" ac="237"> 됩니다</s><s t="1169" ac="227"> 조심하세요</s></p>\n<p t="43169" d="2050" w="1" a="1">\n</ ...

# %%
import re

# %%
def cleanhtml(raw_html):
  cleanr = re.compile('<.*?>|&([a-z0-9]+|#[0-9]{1,6}|#x[0-9a-f]{1,6});')
  cleantext = re.sub(cleanr, '', raw_html)
  return cleantext

# %%
aa =str(caption.xml_captions)

# %%
text=str(cleanhtml(aa)).replace('\n','')

# %%
text
# Out:
# '아[음악]wr여러분들 혹시 유튜버 나 스트림 하고싶으십니까유튜브에 스트리머 뭐 아니면 하이트뭐 등등 등등 뭐 웹툰작가 던 모던회사 때로 치고 나와서 뭘 해야지제가 얼마전에 건강검진을 받았는데요지금 차두리 형의 나오더라구요 거기에그 간 때문이야 간 때문이야 너 지금ct 촬영 받고 있습니다 건강조심하시고요 회사 다닐때는 나와서혼자 이런거 하면 되게 편하고 그럴거라고 생각하지만 나오시면 일이 2배줘 ep 2 두 배 벽 왠 차가 이세 배 입니다 3배에 운 없으면 은그 주 80시간 뭐 이렇게 일할 수있어요 조심하셔야 됩니다 조심하세요건강이 나라로 가고 있기 때문에 야이렇게 살면 안 되겠다 그래서안되겠다 고 대학생 들한테 좀물어봤어요 스퀄 도 나 혼자 춤의 팬드니까 너희들은 마이 디어 없냐 고대학생들이 라 그러면은 주무 살에서25 사이죠 물어봤어요 뜬 박스를통해서 혹시 마인이 없냐 모종 내나바라 그랬더니 우리 대학생들이자기들은 얘기하고 싶다 직접 와서모셔놓고 할 수 없으니까 자기들은얘기하고 싶다 라는 주제를보내줬습니다 저 20대의 20살25살 생각은 모르니까 걔들은 이얘기를 처음 봤거든요 보면서 문득해야 했는데 음 여러분도 한번 공감이되던지 벗어 이에게 공감이 되면여러분들의 마음은 대학생 거고요공감이 안 되면 마음이 슈카 인겁니다 자 m 제트 세대의세계관이라는 것이 존재한 야 이게무슨 소리냐 하면 램제트 세대가 늘린2월 제 3 알아 그러잖아요 이게축대 후반 거의 한 16세 에서마우스 투자를 사이인데 왜 뭉뚱그려서한 세대 라고 얘기를 하냐 너희들은md 트 세대의 세계관이 라는게자기가 보기엔 별로 없는데 공통점이없는데 아파트 안아파 아빠다 삼촌인데 40대에서 10 때까지 있는걸왜 이렇게 뭉뚱그려 얘기 아냐 란이런 얘길 하더라구요 그래서 그런가밖에 그런거라 생각이 들어서찾아봤더니 mgx 한 편의 시 탈은게 오늘 거에요 직접적으로 태그 바쓰알겠어 알겠어 비아 델 미안해 내가부르고 난 이집 아이템이 하단 데서봤는데 이 세대를 좀 본거죠 유명한폰 데어 페이 부머 그러면 연령별로짜르면 1 어려우니까 그냥 간단하게들이 러프하게 연령별로 잘라보면60대 70대 줘 네이버 부모들 얘기많이 했던 그 시절 분당 값은 아55년생 형님들이 고 x 3 대해그리며 는 모 43 에서 54 하지만대충 40대 50대 중간 값은 안7인 한새 70년대 초 중반이 중간값이라고 할 수 있구요 밀레니엄세대는 26 에서 42세 니까 30대30에서 애와 딱딱 탈 7년 생을기준으로 다니기 미래엔 유리 라고 할수 있고 제트 세대는 10대의중반에서 20대 03 년생 와 봄3년새 축하 노래 축하 해야되지 해트보트 카 드립니다 18살 정도가 이제중 값이라고 할 수 있는데 알파 3들이 있어요 여기는 뭐 안 3왜냐하면 2010년 이후 태생이 니까예 몇몇 분들은 아직 기저귀를 차고있을 것 같고 몇몇 분들은 책가방105 초등학교 하고 있는 그러나이제 유치원에 그러나 알파 3 인데아직 본격 개 오리 새끼 어느새나니까 조금 더 클라라 조금 더 크며는 평이 달아 줄게 아직은 빼구요 좀더 크면 다루어 주고 그 중간에보면은 열두 살에서 42살 까지 니까이거 갭이 너무 넓은 거 아니냐 게30년 차이가 남 들어 여기 보면세대가 두 개의 6대 70대 아쉽 또입 때문에 우리는 도매 끔 이냐 이거죠 비슷한 끊고 쉽게 자로 빼야지이게 모두 매 꿈을 같이 먹는 건말이 안된다 라는 건데 대학생들의주장입니다 왜 우리를 한 묶음으로분야 기분이 가 놓다 냄새에 대해충분 7살 해서 42살 제트 3대열두 살에서 26살 대학생 분들이니까자기들은 여기죠 아이들은 제트 3텐데 음 제대하고 같이 부르게 기분이안 좋다 이거죠그쵸 야음 세대가 및 열에 대해저어지 아저씨들 하고 나하고 엮어 뭐이런 불만이 왔습니다 쳐다보지 그렇네뭐 그런거 같긴 해요 내가 뭐 20살고 이런데 40 사라고 세대가 같다그러면 좀 이상한거 아니냐 물건 푸마였는데 그래서 요즘엔 인터넷에서도짤로 이거 많이 돌아다니고 요 보면은너의 밀레니엄 3 대해 27세 마운트살 홍림 들의 아이돌은 누구 했냐면87년생 기준으로 10대 당시아이돌이 god 저는 처음 보지만어머님은 짜장면이 싫다고 하셨어 할것 같은 거미 너무 바싹 만들계시네요맞서 밴드 계시고 그 답에 소여시대에도 이런 분들이 줘 소녀시대의요즘 감은 이제 원로 아이돌 취급을받는지 그런 분들인데 나이는 점자워낙 빠르게 대비해서 그렇지 이스트당시 아이돌인데 밀레니엄 세대의기준으론 제트 3대 미수금 이제저한테 요 자료를 보내주신 분이 줘제트 3대 우리한테는 아이들이 그런분이 아니다 우리 10대 때아이돌들은 nct 하십니까 nct형님들의 그 않아 모르는알아보겠습니다 연령대 날 수 있죠맨시티 역시 무릎에 뜨죠 그렇지않았어요 역시 맨시티 아니구요 맨시티나오든 분들은 그 최소한 제트 생은아닙니다 맨시티는 는 애니 흐리거나엑셀 되고 모르죠 역시 역시 역시형들이 야 놀릴 줄 알았어요 즉시 절마지막 88g 모리조 개체 습니다저도 몰랐으니까 그리고 어떻게 아로진짜 솔직한 말로 오직 이거라도 안되지 2분들 물러 훌륭한 분들이고엄청 잘나가는 아이들이고 세계적인그룹이고 우리나라 최고의 인기를 꺾고지금 앨범 250만 장이 팔렸어요마셔야 됩니다 정말 잘 팔려요 예저도 공부하고 아까 얻은 되게 잘팔리는데 우리 모르잖아요 제트 3대해 아이들이랑 거지 s 파의 스파하십니까 그 뭐라 그러지 자기 아이도량으로 안 되고 자기 뭐냐 이거이거 즐길 게 아닌가요 팔찌 그거갖고 나오신 뭐 요즘엔 2010년대비 했고 역시 폭발적인 인기를캐릭터라 그래야 되나 괜히 캐릭터왔고 등장을 하신분들이 조 파괴적인인기를 끌고 있는데 테크로 며 s파고 lct 흔들 좋아하는 우리 제트세대와 지 우리 소녀시대를 좋아하는우리 m 세대를 묶었을 때 즉 4대가기분이 가 나쁘다는 거죠 형님들이 그하시는건 안전 이유를 알 수 있어요왜냐하면 형님들 같은 경우에는 x세대 게시자 x 세대 누구야 물음표말 느껴 온 거 보니까 형님들의아이디어를 죄라도 가보았습니다 아까보여 드렸지만 제트 3대 위해 m 3되고 m 세대 위해 xd 인데 액 3대형 님들이 많이 계시기 때문에형님들의 아이돌1972년생 기준으로 10대 당지어려서 17살에 닿았던 아이돌은 박람지금 선생님들께 박남현 선생님 다아시죠 역시 다 아시네 우리 표를없잖아요 와 크크 하는거 보니까 다시조 그룹 소방차 불거나 질문은아니구요 이 계속 뒤에 백 덤블링하시던 분이 있죠 손 자꾸 뒤로 하며는 2분이 뒤로 쿄 캐서 딱 한개하시던 분이 있고 그래서 다시 자크그 올라가는 겁니까 아떼 스파 웬cts 때는 물음표 지만 박남정선생님 소방차 선생님의 때는 다 왜이렇게 하니까 를 남자 없는 생 님뭐 이거 했던 선생님 아 죄송합니다더 9 자유 화면으로 봤습니다자료화면으로 형님들의 아이돌은 이런분들이 얻는데 자 문제는 저렇게보면은 방 남자선생님 소방차는 되게오래 된거 같고 이 애시 티나의스파는 굉장히 최근 거 같지만 사실은소방차와 god 가 12년 이구요차이가 얼마 안 나요 god 와lgt 가 대비 년도 기준으로17년차 에요 그러면 안 1 여긴 x대로 그러고 역이나 하나로 묶어버리면 당연한 하는 거죠 예이건 이 책에도 뭔데 여기는 뭐그렇고 여기 드냐 c 보엠 제트 3애니까 뭐가 어떻고 처가 좋고 뭐 그최근에 웬디스 에 뭐가 안 됐고 저게안 되고 요즘 젊은 놈들은 말이야그렇게 얘기를 하니까 이게 좀 그렇다는 불만이 접수 했죠 저한테 캐서말씀드리는 건데 책의 17년 27 여훨씬 더 어딜 이다 한마디로 그래서그 미드레이어 그건 뭐냐 그랬더니 딱요렇게 정리해봤습니다 벤 제대와 제트3대 우리글 공감대가 없고 공통점도우리가 보기엔 별로 없는거 같다 둔채 틀을 얘기하는 겁니다 제 얘기하는게 아니라 제트 세대가 이렇게얘기하는 거죠 우리는 공감대가 없고곰 토끼 별로 없는거 같은데 왜하나로 묶어서 어둠의 꿀의 게 아냐하나로 묶지 마라 md 트 3 4 란단어 맘에 들지 않는다 라고 전달 해오셨습니다 저위에 합니다 이해합니다5 소방차 아저씨와 그 지우지차이보다 지오디 시체 차이가 넓다는걸 보면 추미애 됐는데 자 그러면 그왜 mg 3 을 자꾸 묶어서 얘기하는거 아냐 뜬 이렇게 얘기를하시더라구요 아저씨 라고 해야지아저씨들이 왜 묶어서 얘기하는지 우린알 것 같아요 왜 보면 지금우리나라를 이끌어  ...

# %%
fw = open('0901_suka.txt', 'w')
fw.write(text)
fw.close()
